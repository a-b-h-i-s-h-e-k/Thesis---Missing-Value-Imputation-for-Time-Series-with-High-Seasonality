# %% [markdown]
# ### Enable importing modules from the parent project directory

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))  # Adds project root

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd  # Data manipulation and DataFrame support
import numpy as np  # Numerical computing with arrays
import math  # Basic mathematical functions
import matplotlib.pyplot as plt  # Plotting and visualization
from sklearn.metrics import mean_squared_error, mean_absolute_error  # Evaluation metrics
from statistics import mode  # Compute statistical mode
import folium  # Interactive maps (leaflet.js-based)
from folium.plugins import MarkerCluster  # Cluster markers on maps
from scipy.stats import pearsonr  # Pearson correlation calculation
from sklearn.preprocessing import StandardScaler  # Z-score normalization
from sklearn.preprocessing import MinMaxScaler  # Scale features to 0–1 range
from tqdm import tqdm  # Progress bars for loops
from prophet import Prophet  # Facebook Prophet time series forecasting
import random  # Random number generation
from sklearn.impute import SimpleImputer  # Basic missing value imputation
from typing import Dict  # Type hinting for dictionaries
import seaborn as sns  # Statistical data visualization
from sklearn.impute import SimpleImputer  # (Duplicate) Basic imputation again
from IPython.display import display, HTML  # Pretty HTML display in notebooks
from sklearn.decomposition import PCA  # Principal Component Analysis (dimensionality reduction)
from sklearn.preprocessing import StandardScaler  # (Duplicate) Z-score scaling
from statsmodels.tsa.holtwinters import ExponentialSmoothing  # Time series smoothing & forecasting
from sklearn.ensemble import RandomForestRegressor  # Random Forest for regression tasks
from sklearn.inspection import permutation_importance  # Feature importance via permutation
import warnings  # Control warning messages
warnings.filterwarnings("ignore")  # Suppress warnings (useful in notebooks)
from prophet.plot import plot_plotly, plot_components_plotly  # Plotting Prophet results
from prophet.diagnostics import cross_validation, performance_metrics  # Prophet diagnostics tools

# %%
from typing import List, Tuple  # Type hinting for lists and tuples

from Algorithms.CDREC import CDRec  # Collaborative Denoising for matrix completion
from Algorithms.TKCM import TKCM  # Top-k Case Matching (basic version)
from Algorithms.TKCM_Weighted import TKCM_Weighted  # TKCM with similarity-based weighting
from Algorithms.DynaMMO import DynaMMo  # Dynamic Matrix Modeling for time series imputation
from Algorithms.SoftImpute import SoftImpute  # Low-rank matrix completion using soft-thresholding
from Algorithms.SVDImpute import IterativeSVD  # Iterative SVD-based matrix imputation
from Algorithms.trmf import TRMFImputer  # Temporal Regularized Matrix Factorization
from Algorithms.ST_MVL import ST_MVL  # Space-Time Matrix-Vector Learning
from Algorithms.TKCM_PLUS import TKCM_PLUS  # TKCM variant with alpha–beta blending, also using Target series known values to fill the missing values
from Algorithms.TKCM_PRO import TKCM_PRO  # Pro version of TKCM with anchor filtering, here averaging the refrence to fill the missing values

# %% [markdown]
# ### Loading the Dataset

# %%
gauging_df = pd.read_csv("D:\\Thesis\\Project\\Data\\gauging_data.csv")

# Counting the different types of missingness in the dataset
stats = {
    "Total Rows": len(gauging_df),
    "Total Columns": len(gauging_df.columns),
    "Zero Values": (gauging_df == 0).sum().sum(),
    "NaN Values": gauging_df.isna().sum().sum(),
    "Blank Strings": (gauging_df == "").sum().sum(),
    "Unknown Strings": (gauging_df.applymap(lambda x: isinstance(x, str) and x.strip().lower() == "unknown")).sum().sum()
}

# Return as DataFrame
stats_df = pd.DataFrame(list(stats.items()), columns=["Metric", "Value"])
stats_df
# Out:
#             Metric    Value
# 0       Total Rows  1779379
# 1    Total Columns        6
# 2      Zero Values     3776
# 3       NaN Values        0
# 4    Blank Strings        0
# 5  Unknown Strings        0

# %% [markdown]
# #### Displaying the first 5 rows of the data

# %%
gauging_df.head()
# Out:
#   station_code sensor_code description_it  unit            timestamp   value
# 0      89940PG           Q        Portata  m³/s  2025-01-01 00:00:00  72.904
# 1      89940PG           Q        Portata  m³/s  2024-12-31 23:30:00  70.077
# 2      89940PG           Q        Portata  m³/s  2024-12-31 23:00:00  71.957
# 3      89940PG           Q        Portata  m³/s  2024-12-31 22:30:00  75.775
# 4      89940PG           Q        Portata  m³/s  2024-12-31 22:00:00  79.671

# %% [markdown]
# ### Displaying column-wise metadata

# %%
gauging_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1779379 entries, 0 to 1779378
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   station_code    object
#  1   sensor_code     object
#  2   description_it  object
#  3   unit            object
#  4   timestamp       object
#  5   value           float64
# dtypes: float64(1), object(5)
# memory usage: 81.5+ MB

# %% [markdown]
# ### describe() provide us with statistical summary of numeric columns

# %%
gauging_df.describe()
# Out:
#               value
# count  1.779379e+06
# mean   4.807447e+01
# std    1.236863e+03
# min   -9.750000e+05
# 25%    3.600000e+00
# 50%    9.990000e+00
# 75%    3.400000e+01
# max    5.043200e+04

# %%
# Preview data
print("🔍 Shape:", gauging_df.shape)
# Out:
# 🔍 Shape: (1779379, 6)

# %%
# Check which columns are non-numeric
print("🧠 Columns in the file:\n", gauging_df.dtypes)
# Out:
# 🧠 Columns in the file:
#  station_code       object
# sensor_code        object
# description_it     object
# unit               object
# timestamp          object
# value             float64
# dtype: object

# %% [markdown]
# ### Checking all the unique sensor codes i have in this dataset

# %%
unique_values = gauging_df['sensor_code'].unique()
unique_values
# Out:
# array(['Q', 'W', 'WT', 'SSTF', 'W.ABST'], dtype=object)

# %% [markdown]
# ### checking unique similar station_codes

# %%
unique_values1 = gauging_df['station_code'].unique()
unique_values1
# Out:
# array(['89940PG', '08155PG', '19850PG', '29850PG', '59450PG', '64550PG',
#        '67350PG', '69790PG', '85550PG', '05950PG', '37230PG', '61050PG',
#        '82910PG', '73950PG', '22950PG', '03750PG', '42850PG', '51450PG',
#        '20750PG', '26950PG', '57150PG', '79770GW', '83070GW', '27020GW',
#        '27001GW', '27010GW', '84415GW', '23250GW', '23350GW', '19350GW',
#        '08105GW', '89935GW', '28620GW', '89940GW', '89357PG', '10750PG',
#        '83450PG', '32470PG', '07770PG', '27890GW', '83360GW', '89740GW',
#        '27025GW', '79865GW', '79875GW', '83310GW', '83380GW', '36770PG',
#        '83320GW', '86310GW', '27930GW', '83250GW', '14750PG', '32615GW',
#        '84435GW', '87940GW', '86315GW', '15570PG', '27935GW', '59500GW',
#        '69420GW', '79870GW', '83025GW', '91950PG'], dtype=object)

# %% [markdown]
# ### Looking at the descriptions of the sensor what is meaning of those sensor codes

# %%
unique_values2 = gauging_df['description_it'].unique()
unique_values2
# Out:
# array(['Portata', 'Livello idrometrico', 'Temperatura acqua',
#        'concentrazione solidi sospesi ', 'Altezza freatimetrica '],
#       dtype=object)

# %% [markdown]
# ### checking unit of data values

# %%
unique_values3 = gauging_df['unit'].unique()
unique_values3
# Out:
# array(['m³/s', 'cm', '°C', 'mg/l', 'm'], dtype=object)

# %% [markdown]
# ### looking at unique values

# %%
unique_values4 = gauging_df['value'].unique()
unique_values4
# Out:
# array([72.904, 70.077, 71.957, ..., 33.28 , 33.29 ,  0.688],
#       shape=(16611,))

# %% [markdown]
# ### Checking the columns i have and how they pronounced

# %%
column_names = list(gauging_df.columns)
column_names
# Out:
# ['station_code', 'sensor_code', 'description_it', 'unit', 'timestamp', 'value']

# %% [markdown]
# ### counting the zeroes and sum them

# %%
zero_counts = (gauging_df == 0).sum()
print(zero_counts)
# Out:
# station_code         0
# sensor_code          0
# description_it       0
# unit                 0
# timestamp            0
# value             3776
# dtype: int64

# %% [markdown]
# ### displaying the values with zeroes

# %%
gauging_df[gauging_df["value"] == 0].head()
# Out:
#        station_code sensor_code     description_it unit            timestamp  \
# 238998      59450PG          WT  Temperatura acqua   °C  2024-01-22 12:00:00
# 239008      59450PG          WT  Temperatura acqua   °C  2024-01-22 07:00:00
# 239009      59450PG          WT  Temperatura acqua   °C  2024-01-22 06:30:00
# 239010      59450PG          WT  Temperatura acqua   °C  2024-01-22 06:00:00
# 239023      59450PG          WT  Temperatura acqua   °C  2024-01-21 23:30:00
#
#         value
# 238998    0.0
# 239008    0.0
# 239009    0.0
# 239010    0.0
# 239023    0.0

# %% [markdown]
# #### checking if values are numeric, if yes then add percentage to the zeroes and sort them by percentage of zero they contain.

# %%
# Make sure 'value' is numeric
gauging_df['value'] = pd.to_numeric(gauging_df['value'], errors='coerce')

# Group by sensor_code
zero_stats = (
    gauging_df.groupby('sensor_code')
    .agg(
        total_entries=('value', 'count'),
        zero_count=('value', lambda x: (x == 0).sum())
    )
)

# Add percentage of zeros
zero_stats['zero_percentage'] = (zero_stats['zero_count'] / zero_stats['total_entries']) * 100

# Sort by percentage of zero values
zero_stats = zero_stats.sort_values(by='zero_percentage', ascending=False)

print(zero_stats.reset_index())
# Out:
#   sensor_code  total_entries  zero_count  zero_percentage
# 0        SSTF         107562        1034         0.961306
# 1          WT         599537        2737         0.456519
# 2      W.ABST         239013           5         0.002092
# 3           Q         401156           0         0.000000
# 4           W         432111           0         0.000000

# %%
gauging_df.isnull().sum()
# Out:
# station_code      0
# sensor_code       0
# description_it    0
# unit              0
# timestamp         0
# value             0
# dtype: int64

# %%
# Group by 'sensor_code' and calculate missing value statistics
missing_stats = (
    gauging_df
    .groupby('sensor_code')
    .agg(
        total_entries=('value', 'count'),
        missing_count=('value', lambda x: x.isna().sum())
    )
    .reset_index()
)

# Calculate missing percentage
missing_stats['missing_percentage'] = (missing_stats['missing_count'] / (missing_stats['total_entries'] + missing_stats['missing_count'])) * 100

# Sort by missing percentage (optional)
missing_stats = missing_stats.sort_values(by='missing_percentage', ascending=False)

# Display
print(missing_stats)
# Out:
#   sensor_code  total_entries  missing_count  missing_percentage
# 0           Q         401156              0                 0.0
# 1        SSTF         107562              0                 0.0
# 2           W         432111              0                 0.0
# 3      W.ABST         239013              0                 0.0
# 4          WT         599537              0                 0.0

# %%
# Ensure 'sensor_code' and 'value' columns exist
if 'sensor_code' in gauging_df.columns and 'value' in gauging_df.columns:
    
    # Group by sensor_code and include NaN rows using dropna=False
    stats = (
        gauging_df
        .groupby('sensor_code', dropna=False)
        .agg(
            total_entries=('value', 'size'),  # includes NaNs
            missing_count=('value', lambda x: x.isna().sum()),
            zero_count=('value', lambda x: (x == 0).sum())
        )
        .reset_index()
    )

    # Calculate percentages
    stats['missing_percentage'] = (stats['missing_count'] / stats['total_entries']) * 100
    stats['zero_percentage'] = (stats['zero_count'] / stats['total_entries']) * 100

    # Round percentages to 2 decimals
    stats['missing_percentage'] = stats['missing_percentage'].round(2)
    stats['zero_percentage'] = stats['zero_percentage'].round(2)

    # Sort by highest missing %
    stats = stats.sort_values(by='missing_percentage', ascending=False)

    # Display the DataFrame
    display(stats)

else:
    print("Error: 'sensor_code' and 'value' columns are required in gauging_df")
# Out:
#   sensor_code  total_entries  missing_count  zero_count  missing_percentage  \
# 0           Q         401156              0           0                 0.0
# 1        SSTF         107562              0        1034                 0.0
# 2           W         432111              0           0                 0.0
# 3      W.ABST         239013              0           5                 0.0
# 4          WT         599537              0        2737                 0.0
#
#    zero_percentage
# 0             0.00
# 1             0.96
# 2             0.00
# 3             0.00
# 4             0.46

# %%
# Step 1: Select sensor `LF`
w_abs_df = gauging_df[gauging_df['sensor_code'] == 'W.ABST'].copy()

# %%
# Step 2: Replace `0.0` values with NaN
#w_abs_df.loc[w_abs_df['value'] == 0.0, 'value'] = np.nan

# %%
# Step 3: Pivot to wide format (timestamp × station_code)
w_abs_df['timestamp'] = pd.to_datetime(w_abs_df['timestamp'])
pivot_df = w_abs_df.pivot(index='timestamp', columns='station_code', values='value')

# %%
# Step 4: Drop sparse stations (>10% missing)
threshold = 0.9 * len(pivot_df)
pivot_df = pivot_df.dropna(thresh=threshold, axis=1)

# %%
# Step 5: Drop rows with any missing values
clean_df = pivot_df.dropna(axis=0)

# %% [markdown]
# #### Displaying the clean dataframe to check what i have with me.

# %%
clean_df
# Out:
# station_code         19350GW  23250GW  23350GW  27001GW  27010GW  27020GW  \
# timestamp
# 2023-01-11 09:00:00     7.28    23.45    21.82    35.82     1.83     1.30
# 2023-01-12 11:00:00     7.28    23.46    21.84    35.82     1.82     1.29
# 2023-01-12 12:00:00     7.28    23.46    21.84    35.82     1.82     1.27
# 2023-01-12 13:00:00     7.28    23.46    21.84    35.82     1.82     1.27
# 2023-01-12 14:00:00     7.28    23.46    21.84    35.82     1.81     1.27
# ...                      ...      ...      ...      ...      ...      ...
# 2024-12-22 19:00:00     6.09    19.43    18.14    34.66     1.58     1.27
# 2024-12-22 20:00:00     6.09    19.43    18.14    34.67     1.58     1.27
# 2024-12-22 21:00:00     6.09    19.43    18.14    34.67     1.57     1.25
# 2024-12-22 22:00:00     6.09    19.43    18.14    34.66     1.57     1.24
# 2024-12-22 23:00:00     6.09    19.44    18.14    34.67     1.56     1.24
#
# station_code         27025GW  27890GW  27930GW  27935GW  ...  83310GW  \
# timestamp                                                ...
# 2023-01-11 09:00:00     0.92    28.39     3.52     2.06  ...     5.30
# 2023-01-12 11:00:00     0.92    28.39     3.52     2.06  ...     5.32
# 2023-01-12 12:00:00     0.91    28.39     3.52     2.06  ...     5.32
# 2023-01-12 13:00:00     0.91    28.39     3.52     2.05  ...     5.32
# 2023-01-12 14:00:00     0.91    28.39     3.52     2.06  ...     5.32
# ...                      ...      ...      ...      ...  ...      ...
# 2024-12-22 19:00:00     0.83    28.03     3.03     1.45  ...     4.26
# 2024-12-22 20:00:00     0.82    28.03     3.03     1.45  ...     4.27
# 2024-12-22 21:00:00     0.82    28.03     3.02     1.45  ...     4.26
# 2024-12-22 22:00:00     0.82    28.03     3.02     1.44  ...     4.26
# 2024-12-22 23:00:00     0.82    28.03     3.02     1.45  ...     4.27
#
# station_code         83320GW  83360GW  83380GW  84415GW  84435GW  87940GW  \
# timestamp
# 2023-01-11 09:00:00    13.03     5.52     1.42     7.92     3.05     1.25
# 2023-01-12 11:00:00    13.06     5.54     1.42     7.93     3.06     1.27
# 2023-01-12 12:00:00    13.06     5.54     1.43     7.93     3.06     1.27
# 2023-01-12 13:00:00    13.06     5.54     1.43     7.93     3.06     1.27
# 2023-01-12 14:00:00    13.06     5.54     1.43     7.93     3.06     1.27
# ...                      ...      ...      ...      ...      ...      ...
# 2024-12-22 19:00:00    11.67     4.62     1.13     7.32     2.91     1.30
# 2024-12-22 20:00:00    11.67     4.62     1.13     7.32     2.91     1.30
# 2024-12-22 21:00:00    11.67     4.62     1.13     7.32     2.91     1.30
# 2024-12-22 22:00:00    11.67     4.62     1.13     7.32     2.91     1.31
# 2024-12-22 23:00:00    11.67     4.62     1.13     7.32     2.91     1.31
#
# station_code         89740GW  89935GW  89940GW
# timestamp
# 2023-01-11 09:00:00     2.37     3.55     6.76
# 2023-01-12 11:00:00     2.39     3.56     6.76
# 2023-01-12 12:00:00     2.39     3.57     6.76
# 2023-01-12 13:00:00     2.39     3.57     6.75
# 2023-01-12 14:00:00     2.39     3.58     6.74
# ...                      ...      ...      ...
# 2024-12-22 19:00:00     2.44     3.46     6.60
# 2024-12-22 20:00:00     2.44     3.47     6.60
# 2024-12-22 21:00:00     2.44     3.47     6.60
# 2024-12-22 22:00:00     2.44     3.47     6.60
# 2024-12-22 23:00:00     2.44     3.47     6.60
#
# [4737 rows x 31 columns]

# %%
# Step 6: Pick a target station
target_station = clean_df.columns[2]

# %% [markdown]
# #### displaying target station

# %%
target_station
# Out:
# '23350GW'

# %%
# Step 7: Compute Pearson correlations 
correlations = clean_df.corr()[target_station].drop(index=target_station).sort_values(ascending=False)

# %% [markdown]
# ### displaying correlations

# %%
correlations
# Out:
# station_code
# 23250GW    0.999518
# 19350GW    0.971022
# 27001GW    0.954899
# 69420GW    0.887714
# 27010GW    0.832578
# 32615GW    0.810489
# 83250GW    0.794504
# 83310GW    0.784010
# 83025GW    0.779483
# 83360GW    0.779446
# 83320GW    0.776531
# 83380GW    0.773552
# 79870GW    0.768576
# 79865GW    0.749737
# 28620GW    0.735184
# 79875GW    0.733451
# 84415GW    0.719192
# 27930GW    0.719091
# 27935GW    0.703984
# 27890GW    0.661312
# 84435GW    0.641699
# 27025GW    0.617348
# 89935GW    0.613681
# 27020GW    0.597596
# 89940GW    0.579422
# 87940GW    0.527920
# 89740GW    0.508133
# 83070GW    0.496631
# 59500GW    0.487290
# 79770GW   -0.434689
# Name: 23350GW, dtype: float64

# %% [markdown]
# ### Plotting the correlation of target series with refrence series

# %%
plt.figure(figsize=(10, 14))
correlations.sort_values().plot(kind='barh', color='skyblue', edgecolor='black')

plt.axvline(x=0, color='gray', linestyle='--', linewidth=1)
plt.title("📈 Pearson Correlation with Target Station '02500MS'")
plt.xlabel("Correlation Coefficient")
plt.ylabel("Station Code")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Step 8: Select top 2 correlated reference stations
top_refs = correlations.head(2).index.tolist()
final_df = clean_df[[target_station] + top_refs].copy()

# %%
top_refs
# Out:
# ['23250GW', '19350GW']

# %% [markdown]
# #### Checking the final dataframe

# %%
final_df
# Out:
# station_code         23350GW  23250GW  19350GW
# timestamp
# 2023-01-11 09:00:00    21.82    23.45     7.28
# 2023-01-12 11:00:00    21.84    23.46     7.28
# 2023-01-12 12:00:00    21.84    23.46     7.28
# 2023-01-12 13:00:00    21.84    23.46     7.28
# 2023-01-12 14:00:00    21.84    23.46     7.28
# ...                      ...      ...      ...
# 2024-12-22 19:00:00    18.14    19.43     6.09
# 2024-12-22 20:00:00    18.14    19.43     6.09
# 2024-12-22 21:00:00    18.14    19.43     6.09
# 2024-12-22 22:00:00    18.14    19.43     6.09
# 2024-12-22 23:00:00    18.14    19.44     6.09
#
# [4737 rows x 3 columns]

# %%
# Step 8: Build new DataFrame with target and top 3 references
top_3_refs = correlations.dropna().sort_values(ascending=False).head(3).index.tolist()
selected_stations = [target_station] + top_3_refs
pattern_df = pivot_df[selected_stations].copy()

# %%
pattern_df
# Out:
# station_code         23350GW  23250GW  19350GW  27001GW
# timestamp
# 2023-01-01 00:00:00    21.73    23.34     7.27    35.79
# 2023-01-01 01:00:00    21.73    23.34     7.27    35.80
# 2023-01-01 02:00:00    21.73    23.34     7.26    35.80
# 2023-01-01 03:00:00    21.73    23.34     7.26    35.80
# 2023-01-01 04:00:00    21.73    23.34     7.26    35.79
# ...                      ...      ...      ...      ...
# 2024-12-31 20:00:00    18.31    19.65     6.18    34.88
# 2024-12-31 21:00:00    18.31    19.65     6.18    34.88
# 2024-12-31 22:00:00    18.32    19.65     6.18    34.88
# 2024-12-31 23:00:00    18.32    19.65     6.18    34.88
# 2025-01-01 00:00:00    18.32    19.65     6.18    34.88
#
# [7297 rows x 4 columns]

# %%
import difflib

# 1) Standardize column names once
pattern_df.columns = pattern_df.columns.map(lambda c: str(c).strip())

# 2) Standardize your inputs too
target = target_station.strip()
references = [r.strip() for r in top_3_refs]

requested = [target] + references

# 3) Check what's missing
missing = [c for c in requested if c not in pattern_df.columns]

# 4) Try to auto-suggest closest matches for any missing codes
if missing:
    suggestions = {
        m: difflib.get_close_matches(m, pattern_df.columns.tolist(), n=1, cutoff=0.8)
        for m in missing
    }
    print("⚠️ Missing columns:", missing)
    print("💡 Closest suggestions:", suggestions)
    # Optional: if there is a single confident suggestion, auto-map it
    auto_map = {m: s[0] for m, s in suggestions.items() if len(s) == 1}
    if auto_map:
        print("✅ Auto-mapping:", auto_map)
        requested = [auto_map.get(c, c) for c in requested]

# 5) Keep only the columns that really exist (fail gracefully if none)
present = [c for c in requested if c in pattern_df.columns]
if not present:
    raise KeyError(f"None of the requested columns are in pattern_df: {requested}")

# 6) Slice and plot as before
start_time = "2023-01-01"
end_time   = "2023-01-04"

plot_df = pattern_df[present].loc[start_time:end_time].copy()

# Split present into target + refs again (in case auto-mapping changed names)
present_target = present[0]
present_refs   = present[1:]

import matplotlib.pyplot as plt
import os
os.makedirs("plots", exist_ok=True)

plt.figure(figsize=(14, 6))
for ref in present_refs:
    plt.plot(plot_df.index, plot_df[ref], linestyle="--", linewidth=1.8, label=f"Ref: {ref}")
plt.plot(plot_df.index, plot_df[present_target], linewidth=2.5, label=f"Target: {present_target}")

plt.xlabel("Time", fontsize=14)
plt.ylabel("Raw Sensor Value", fontsize=14)
plt.title("📍 Target & Top 3 References (No Mask, No Normalization)", fontsize=16, pad=15)
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=13, loc="upper right", frameon=True)
plt.tight_layout()

out_path = "plots/target_vs_references.png"
plt.savefig(out_path, dpi=300, bbox_inches="tight")
plt.show()

print(f"✅ Plot saved at: {out_path}")
# Out:
# ✅ Plot saved at: plots/target_vs_references.png

# %%
import matplotlib.pyplot as plt
import os

os.makedirs("plots", exist_ok=True)

target = "23350GW"
references = ["23250GW", "19350GW", "27001GW"]

start_time = "2023-01-01"
end_time   = "2023-01-04"

plot_df = pattern_df[[target] + references].loc[start_time:end_time].copy()

# Normalize each column (0–1 scaling)
norm_df = (plot_df - plot_df.min()) / (plot_df.max() - plot_df.min())

plt.figure(figsize=(14, 6))

# Plot references
for ref in references:
    plt.plot(norm_df.index, norm_df[ref], linestyle="--", linewidth=1.8, label=f"Ref: {ref}")

# Plot target
plt.plot(norm_df.index, norm_df[target], color="blue", linewidth=2.5, label=f"Target: {target}")

plt.xlabel("Time", fontsize=14)
plt.ylabel("Normalized Sensor Value", fontsize=14)
plt.title("📍 Target & Top 3 References (Normalized, Jan 1–4 2023)", fontsize=16, pad=15)

plt.grid(True, alpha=0.3)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=13, loc="best", frameon=True)
plt.tight_layout()

save_path = "plots/Gauing_target_vs_references_normalized.pdf"
plt.savefig(save_path, dpi=300, bbox_inches="tight")
plt.show()

print(f"✅ Normalized plot saved at: {save_path}")
# Out:
# ✅ Normalized plot saved at: plots/Gauing_target_vs_references_normalized.pdf

# %%
print(plot_df.head(10))       # First 10 rows
print(plot_df.describe())     # Summary statistics
print(plot_df.nunique())      # How many unique values per column
# Out:
# station_code         23350GW  23250GW  19350GW  27001GW
# timestamp
# 2023-01-01 00:00:00    21.73    23.34     7.27    35.79
# 2023-01-01 01:00:00    21.73    23.34     7.27    35.80
# 2023-01-01 02:00:00    21.73    23.34     7.26    35.80
# 2023-01-01 03:00:00    21.73    23.34     7.26    35.80
# 2023-01-01 04:00:00    21.73    23.34     7.26    35.79
# 2023-01-01 05:00:00    21.74    23.34     7.26    35.79
# 2023-01-01 06:00:00    21.74    23.34     7.26    35.80
# 2023-01-01 07:00:00    21.74    23.34     7.26    35.80
# 2023-01-01 08:00:00    21.74    23.34     7.26    35.80
# 2023-01-01 09:00:00    21.74    23.34     7.26    35.80
# station_code    23350GW    23250GW    19350GW    27001GW
# count         96.000000  96.000000  96.000000  96.000000
# mean          21.747604  23.358646   7.243958  35.798854
# std            0.008553   0.011664   0.009000   0.003202
# min           21.730000  23.340000   7.230000  35.790000
# 25%           21.740000  23.350000   7.240000  35.800000
# 50%           21.750000  23.360000   7.240000  35.800000
# 75%           21.750000  23.370000   7.250000  35.800000
# max           21.760000  23.380000   7.270000  35.800000
# station_code
# 23350GW    4
# 23250GW    5
# 19350GW    5
# 27001GW    2
# dtype: int64

# %%
pattern_df.isnull().sum()
# Out:
# station_code
# 23350GW      0
# 23250GW      0
# 19350GW    158
# 27001GW      0
# dtype: int64

# %%
# Check how many missing values are in station 19350GW
missing_count = pattern_df['19350GW'].isna().sum()
print(f"🔍 Missing values in station 19350GW: {missing_count}")

# Display timestamps where the values are missing
missing_timestamps = pattern_df[pattern_df['19350GW'].isna()]
print("\n📅 Timestamps with missing values in 19350GW:")
print(missing_timestamps[['19350GW']])
# Out:
# 🔍 Missing values in station 19350GW: 158
#
# 📅 Timestamps with missing values in 19350GW:
# station_code         19350GW
# timestamp
# 2023-03-24 01:00:00      NaN
# 2023-03-24 13:00:00      NaN
# 2023-03-24 14:00:00      NaN
# 2023-03-24 15:00:00      NaN
# 2023-03-24 16:00:00      NaN
# ...                      ...
# 2024-12-14 08:00:00      NaN
# 2024-12-14 09:00:00      NaN
# 2024-12-14 10:00:00      NaN
# 2024-12-14 11:00:00      NaN
# 2024-12-14 12:00:00      NaN
#
# [158 rows x 1 columns]

# %%
for col in pattern_df.columns:
    if pattern_df[col].isnull().sum() > 0:
        print(f"\n🔍 Missing value in station {col}:")
        print(pattern_df[pattern_df[col].isnull()][col])
# Out:
# 🔍 Missing value in station 19350GW:
# timestamp
# 2023-03-24 01:00:00   NaN
# 2023-03-24 13:00:00   NaN
# 2023-03-24 14:00:00   NaN
# 2023-03-24 15:00:00   NaN
# 2023-03-24 16:00:00   NaN
#                        ..
# 2024-12-14 08:00:00   NaN
# 2024-12-14 09:00:00   NaN
# 2024-12-14 10:00:00   NaN
# 2024-12-14 11:00:00   NaN
# 2024-12-14 12:00:00   NaN
# Name: 19350GW, Length: 158, dtype: float64

# %%
# Plot the time series with gaps
plt.figure(figsize=(15, 4))
pattern_df['19350GW'].plot(marker='o', linestyle='-', label='19350GW', color='steelblue')
plt.title('Water Temperature Time Series for Station 19350GW')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Identify timestamps where 19350GW has missing values
missing_timestamps = pattern_df[pattern_df['19350GW'].isna()].index

# Step 2: Drop those timestamps from all stations
clean_df = pattern_df.drop(index=missing_timestamps)

# Step 3 (optional): Verify
print(f"✅ Removed {len(missing_timestamps)} rows from all stations.")
print(f"Remaining rows: {len(clean_df)}")

# Step 4 (optional): Check if NaNs still exist in 19350GW
print(f"Remaining NaNs in 19350GW: {clean_df['19350GW'].isna().sum()}")
# Out:
# ✅ Removed 158 rows from all stations.
# Remaining rows: 7139
# Remaining NaNs in 19350GW: 0

# %%
pattern_df = clean_df

# %%
pattern_df.isnull().sum()  # Check for missing values in the DataFrame
# Out:
# station_code
# 23350GW    0
# 23250GW    0
# 19350GW    0
# 27001GW    0
# dtype: int64

# %%
# Example: Fill NaNs in 19350GW with values from 23350GW if simple fill
#pattern_df['19350GW_filled'] = pattern_df['19350GW'].fillna(pattern_df['23350GW'])

# %%
# subset = gauging_df[(gauging_df['sensor_code'] == 'WT') & (gauging_df['station_code'] == '51450PG')]
# subset['is_missing'] = subset['value'].isna()
# subset[['timestamp', 'is_missing']].head(20)  # Replace timestamp with your actual time column

# %%
print(pattern_df.columns.tolist())
# Out:
# ['23350GW', '23250GW', '19350GW', '27001GW']

# %% [markdown]
# # -------------------------------------------
# # 🔹 STEP 1: Normalizing the Time Series Data
# # -------------------------------------------

# %%
from sklearn.preprocessing import StandardScaler

#  Initialize the Scaler
scaler = StandardScaler()

#  Fit the scaler on the full pattern_df and transform it
normalized_array = scaler.fit_transform(pattern_df)

#  Reconstruct a DataFrame with the same shape, columns, and index
normalized_df = pd.DataFrame(
    normalized_array,
    columns=pattern_df.columns,
    index=pattern_df.index
)

# 4️⃣ Print shape and preview
print(" Normalized shape:", normalized_df.shape)
display(normalized_df.head())
# Out:
#  Normalized shape: (7139, 4)
# station_code          23350GW   23250GW   19350GW   27001GW
# timestamp
# 2023-01-01 00:00:00  1.151297  1.130615  0.929330  1.109151
# 2023-01-01 01:00:00  1.151297  1.130615  0.929330  1.125000
# 2023-01-01 02:00:00  1.151297  1.130615  0.915029  1.125000
# 2023-01-01 03:00:00  1.151297  1.130615  0.915029  1.125000
# 2023-01-01 04:00:00  1.151297  1.130615  0.915029  1.109151

# %% [markdown]
# # ---------------------------------------------------------
# # 🔹 STEP 2: Defining function to the inject block-missing in the end
# # ---------------------------------------------------------

# %%
def introduce_block_missing_end(series: pd.Series, block_length: int) -> Tuple[pd.Series, int, int]:
    """
    Introduce a block of NaN values at the end of a time series.

    Parameters:
        series (pd.Series): The original time series (normalized)
        block_length (int): The number of consecutive values to mask from the end

    Returns:
        masked_series (pd.Series): The modified series with NaNs
        start_idx (int): Starting index of the missing block
        end_idx (int): Ending index (exclusive) of the missing block
    """
    ts = series.copy()
    end_idx = len(ts)
    start_idx = end_idx - block_length
    ts[start_idx:end_idx] = np.nan
    return ts, start_idx, end_idx

# Inject blocks of 7 days (168 time points).

# %% [markdown]
# # ---------------------------------------------------------
# # 🔹 STEP 2b: Applying block-missing to the normalized target series
# # ---------------------------------------------------------

# %%
# ---------------------------------------------------------
# 🔹 STEP 2b: Apply block-missing to the normalized target series
# ---------------------------------------------------------

# Define target station 
target_station = "23350GW"

# Define block length (e.g. 10 time points ~ 5 hours if half-hourly)
block_length = 721

# Apply the masking function
masked_target, start_idx, end_idx = introduce_block_missing_end(
    normalized_df[target_station],
    block_length
)

# ✅ Optional: Print info about the block
print(f"🧱 Missing block injected from index {start_idx} to {end_idx - 1}")
print("🕓 Timestamps of missing block:\n", normalized_df.index[start_idx:end_idx])
# Out:
# 🧱 Missing block injected from index 6418 to 7138
# 🕓 Timestamps of missing block:
#  DatetimeIndex(['2024-11-27 12:00:00', '2024-11-27 13:00:00',
#                '2024-11-27 14:00:00', '2024-11-27 15:00:00',
#                '2024-11-27 16:00:00', '2024-11-27 17:00:00',
#                '2024-11-27 18:00:00', '2024-11-27 19:00:00',
#                '2024-11-27 20:00:00', '2024-11-27 21:00:00',
#                ...
#                '2024-12-31 15:00:00', '2024-12-31 16:00:00',
#                '2024-12-31 17:00:00', '2024-12-31 18:00:00',
#                '2024-12-31 19:00:00', '2024-12-31 20:00:00',
#                '2024-12-31 21:00:00', '2024-12-31 22:00:00',
#                '2024-12-31 23:00:00', '2025-01-01 00:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=721, freq=None)

# %% [markdown]
# # ---------------------------------------------------------
# # 🔹 STEP 3: Preparing NumPy arrays for imputation and evaluation
# # ---------------------------------------------------------

# %%
# Extract the reference station names (excluding the target)
reference_stations = [col for col in normalized_df.columns if col != target_station]

#  Get reference matrix as shape (num_refs, time) — transposed
ref_matrix = normalized_df[reference_stations].to_numpy().T  # shape: (num_refs, time)

#  Get the masked target series as array (shape: time,)
masked_target_array = masked_target.to_numpy().copy()

#  Get the original (true) unmasked target series
true_target_array = normalized_df[target_station].to_numpy()

#  Save the index positions of the block-masked values
nan_block_indices = np.arange(start_idx, end_idx)

#  Preview shapes and sanity check
print(" Target shape:", masked_target_array.shape)
print(" Ref matrix shape:", ref_matrix.shape)
print(" Block indices:", nan_block_indices)
print(" Target preview (with NaNs):", masked_target_array[start_idx:end_idx])
# Out:
#  Target shape: (7139,)
#  Ref matrix shape: (3, 7139)
#  Block indices: [6418 6419 6420 6421 6422 6423 6424 6425 6426 6427 6428 6429 6430 6431
#  6432 6433 6434 6435 6436 6437 6438 6439 6440 6441 6442 6443 6444 6445
#  6446 6447 6448 6449 6450 6451 6452 6453 6454 6455 6456 6457 6458 6459
#  6460 6461 6462 6463 6464 6465 6466 6467 6468 6469 6470 6471 6472 6473
#  6474 6475 6476 6477 6478 6479 6480 6481 6482 6483 6484 6485 6486 6487
#  6488 6489 6490 6491 6492 6493 6494 6495 6496 6497 6498 6499 6500 6501
#  6502 6503 6504 6505 6506 6507 6508 6509 6510 6511 6512 6513 6514 6515
#  6516 6517 6518 6519 6520 6521 6522 6523 6524 6525 6526 6527 6528 6529
#  6530 6531 6532 6533 6534 6535 6536 6537 6538 6539 6540 6541 6542 6543
#  6544 6545 6546 6547 6548 6549 6550 6551 6552 6553 6554 6555 6556 6557
#  6558 6559 6560 6561 6562 6563 6564 6565 6566 6567 6568 6569 6570 6571
#  6572 6573 6574 6575 6576 6577 6578 6579 6580 6581 6582 6583 6584 6585
#  6586 6587 6588 6589 6590 6591 6592 6593 6594 6595 6596 6597 6598 6599
#  6600 6601 6602 6603 6604 6605 6606 6607 6608 6609 6610 6611 6612 6613
#  6614 6615 6616 6617 6618 6619 6620 6621 6622 6623 6624 6625 6626 6627
#  6628 6629 6630 6631 6632 6633 6634 6635 6636 6637 6638 6639 6640 6641
#  6642 6643 6644 6645 6646 6647 6648 6649 6650 6651 6652 6653 6654 6655
#  6656 6657 6658 6659 6660 6661 6662 6663 6664 6665 6666 6667 6668 6669
#  6670 6671 6672 6673 6674 6675 6676 6677 6678 6679 6680 6681 6682 6683
#  6684 6685 6686 6687 6688 6689 6690 6691 6692 6693 6694 6695 6696 6697
#  6698 6699 6700 6701 6702 6703 6704 6705 6706 6707 6708 6709 6710 6711
#  6712 6713 6714 6715 6716 6717 6718 6719 6720 6721 6722 6723 6724 6725
#  6726 6727 6728 6729 6730 6731 6732 6733 6734 6735 6736 6737 6738 6739
#  6740 6741 6742 6743 6744 6745 6746 6747 6748 6749 6750 6751 6752 6753
#  6754 6755 6756 6757 6758 6759 6760 6761 6762 6763 6764 6765 6766 6767
#  6768 6769 6770 6771 6772 6773 6774 6775 6776 6777 6778 6779 6780 6781
#  6782 6783 6784 6785 6786 6787 6788 6789 6790 6791 6792 6793 6794 6795
#  6796 6797 6798 6799 6800 6801 6802 6803 6804 6805 6806 6807 6808 6809
#  6810 6811 6812 6813 6814 6815 6816 6817 6818 6819 6820 6821 6822 6823
#  6824 6825 6826 6827 6828 6829 6830 6831 6832 6833 6834 6835 6836 6837
#  6838 6839 6840 6841 6842 6843 6844 6845 6846 6847 6848 6849 6850 6851
#  6852 6853 6854 6855 6856 6857 6858 6859 6860 6861 6862 6863 6864 6865
#  6866 6867 6868 6869 6870 6871 6872 6873 6874 6875 6876 6877 6878 6879
#  6880 6881 6882 6883 6884 6885 6886 6887 6888 6889 6890 6891 6892 6893
#  6894 6895 6896 6897 6898 6899 6900 6901 6902 6903 6904 6905 6906 6907
#  6908 6909 6910 6911 6912 6913 6914 6915 6916 6917 6918 6919 6920 6921
#  6922 6923 6924 6925 6926 6927 6928 6929 6930 6931 6932 6933 6934 6935
#  6936 6937 6938 6939 6940 6941 6942 6943 6944 6945 6946 6947 6948 6949
#  6950 6951 6952 6953 6954 6955 6956 6957 6958 6959 6960 6961 6962 6963
#  6964 6965 6966 6967 6968 6969 6970 6971 6972 6973 6974 6975 6976 6977
#  6978 6979 6980 6981 6982 6983 6984 6985 6986 6987 6988 6989 6990 6991
#  6992 6993 6994 6995 6996 6997 6998 6999 7000 7001 7002 7003 7004 7005
#  7006 7007 7008 7009 7010 7011 7012 7013 7014 7015 7016 7017 7018 7019
#  7020 7021 7022 7023 7024 7025 7026 7027 7028 7029 7030 7031 7032 7033
#  7034 7035 7036 7037 7038 7039 7040 7041 7042 7043 7044 7045 7046 7047
#  7048 7049 7050 7051 7052 7053 7054 7055 7056 7057 7058 7059 7060 7061
#  7062 7063 7064 7065 7066 7067 7068 7069 7070 7071 7072 7073 7074 7075
#  7076 7077 7078 7079 7080 7081 7082 7083 7084 7085 7086 7087 7088 7089
#  7090 7091 7092 7093 7094 7095 7096 7097 7098 7099 7100 7101 7102 7103
#  7104 7105 7106 7107 7108 7109 7110 7111 7112 7113 7114 7115 7116 7117
#  7118 7119 7120 7121 7122 7123 7124 7125 7126 7127 7128 7129 7130 7131
#  7132 7133 7134 7135 7136 7137 7138]
#  Target preview (with NaNs): [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan]

# %%
print(type(masked_target_array), masked_target_array.shape)
# Out:
# <class 'numpy.ndarray'> (7139,)

# %% [markdown]
# # -----------------------------------------------
# # 🔹 STEP 4.1: Setting safe parameters for all models
# # -----------------------------------------------

# %%
k = 5  # number of top matching sequences (for TKCMs)
l = 4  # sliding window size
rank = max(1, min(ref_matrix.shape[0] - 1, 2))  # safe low-rank dimension for SVD, TRMF

# %% [markdown]
# ### --- Basic Imputers --

# %%
from sklearn.impute import SimpleImputer

# --- Basic Imputers ---

class ZeroImputer:
    def fit_transform(self, X):
        X = X.copy()
        X[np.isnan(X)] = 0
        return X


class MinImputer:
    def fit_transform(self, X):
        fill_value = np.nanmin(X[~np.isnan(X)])
        imp = SimpleImputer(strategy='constant', fill_value=fill_value)
        return imp.fit_transform(X)

class InterpolationImputer:
    def fit_transform(self, X):
        return pd.DataFrame(X).interpolate(method='linear', axis=0, limit_direction='both').values

# %% [markdown]
# # -----------------------------------------------
# # 🔹 STEP 4.2: Applying each model with correct usage
# # -----------------------------------------------

# %%
# Stack the masked target (first row) + full reference matrix (rest)
X_stacked = np.vstack([masked_target_array, ref_matrix])

# TKCM
tkcm = TKCM(k=k, l=l)
tkcm_imputed = tkcm.impute(masked_target_array.copy(), offset=start_idx, ref_ts=ref_matrix)

#  TKCM_PLUS
tkcm_plus = TKCM_PLUS(k=k, l=l, alpha=0.5, beta=0.5)
tkcm_plus_imputed = tkcm_plus.impute(masked_target_array.copy(), offset=start_idx, ref_ts=ref_matrix)

#  TKCM_Weighted
tkcm_w = TKCM_Weighted(k=k, l=l)
tkcm_weighted_imputed = tkcm_w.impute(masked_target_array.copy(), offset=start_idx, ref_ts=ref_matrix)

#  TKCM_PRO
tkcm_pro = TKCM_PRO(k=k, l=l)
tkcm_pro_imputed = tkcm_pro.impute(masked_target_array.copy(), offset=start_idx, ref_ts=ref_matrix)


# CDRec
cdrec = CDRec(rank=rank)
cdrec_imputed = cdrec.impute(X_stacked.copy())[0]  # Only return target row

#  DynaMMo
dynammo = DynaMMo(latent_dim=rank)
dynammo_imputed = dynammo.fit_transform(X_stacked.copy())[0]

#  SoftImpute
soft = SoftImpute(max_rank=rank)
soft_imputed = soft.fit_transform(X_stacked.copy())[0]

#  IterativeSVD
svd = IterativeSVD(rank=rank)
svd_imputed = svd.fit_transform(X_stacked.copy())[0]

#  ST_MVL
st_mvl = ST_MVL()
st_mvl_imputed = st_mvl.impute(X_stacked.copy())[0]

#  TRMF
trmf = TRMFImputer(rank=rank)
trmf_imputed = trmf.fit_transform(X_stacked.copy())[0]

#  Zero Imputer
zero_imputer = ZeroImputer()
zero_imputed = zero_imputer.fit_transform(X_stacked.copy())[0]

#  Min Imputer
min_imputer = MinImputer()
min_imputed = min_imputer.fit_transform(X_stacked.copy())[0]

#  Interpolation Imputer
interp_imputer = InterpolationImputer()
interp_imputed = interp_imputer.fit_transform(X_stacked.copy())[0]

# %%
# In TKCM imputation loop
missing_indices = np.where(np.isnan(masked_target_array))[0]

for offset in missing_indices:
    imputed_series = tkcm.impute(masked_target_array.copy(), offset=offset, ref_ts=ref_matrix)
    print(f"Offset {offset} → Imputed value = {imputed_series[offset]}")
# Out:
# Offset 6418 → Imputed value = -0.8814312212068189
# Offset 6419 → Imputed value = -0.8801372216299864
# Offset 6420 → Imputed value = -0.5863268145610467
# Offset 6421 → Imputed value = -0.8801372216299864
# Offset 6422 → Imputed value = -0.5876208141378794
# Offset 6423 → Imputed value = -0.8814312212068189
# Offset 6424 → Imputed value = -0.29251640749210706
# Offset 6425 → Imputed value = -0.2938104070689397
# Offset 6426 → Imputed value = -0.29251640749210706
# Offset 6427 → Imputed value = -0.29251640749210706
# Offset 6428 → Imputed value = -0.29251640749210706
# Offset 6429 → Imputed value = -0.29251640749210706
# Offset 6430 → Imputed value = 0.0
# Offset 6431 → Imputed value = 0.0
# Offset 6432 → Imputed value = 0.0
# Offset 6433 → Imputed value = 0.0
# Offset 6434 → Imputed value = 0.0
# Offset 6435 → Imputed value = 0.0
# Offset 6436 → Imputed value = 0.0
# Offset 6437 → Imputed value = 0.0
# Offset 6438 → Imputed value = 0.0
# Offset 6439 → Imputed value = 0.0
# Offset 6440 → Imputed value = 0.0
# Offset 6441 → Imputed value = 0.0
# Offset 6442 → Imputed value = 0.0
# Offset 6443 → Imputed value = 0.0
# Offset 6444 → Imputed value = 0.0
# Offset 6445 → Imputed value = 0.0
# Offset 6446 → Imputed value = 0.0
# Offset 6447 → Imputed value = 0.0
# Offset 6448 → Imputed value = 0.0
# Offset 6449 → Imputed value = 0.0
# Offset 6450 → Imputed value = 0.0
# Offset 6451 → Imputed value = 0.0
# Offset 6452 → Imputed value = 0.0
# Offset 6453 → Imputed value = 0.0
# Offset 6454 → Imputed value = 0.0
# Offset 6455 → Imputed value = 0.0
# Offset 6456 → Imputed value = 0.0
# Offset 6457 → Imputed value = 0.0
# Offset 6458 → Imputed value = 0.0
# Offset 6459 → Imputed value = 0.0
# Offset 6460 → Imputed value = 0.0
# Offset 6461 → Imputed value = 0.0
# Offset 6462 → Imputed value = 0.0
# Offset 6463 → Imputed value = 0.0
# Offset 6464 → Imputed value = 0.0
# Offset 6465 → Imputed value = 0.0
# Offset 6466 → Imputed value = 0.0
# Offset 6467 → Imputed value = 0.0
# Offset 6468 → Imputed value = 0.0
# Offset 6469 → Imputed value = 0.0
# Offset 6470 → Imputed value = 0.0
# Offset 6471 → Imputed value = 0.0
# Offset 6472 → Imputed value = 0.0
# Offset 6473 → Imputed value = 0.0
# Offset 6474 → Imputed value = 0.0
# Offset 6475 → Imputed value = 0.0
# Offset 6476 → Imputed value = 0.0
# Offset 6477 → Imputed value = 0.0
# Offset 6478 → Imputed value = 0.0
# Offset 6479 → Imputed value = 0.0
# Offset 6480 → Imputed value = 0.0
# Offset 6481 → Imputed value = 0.0
# Offset 6482 → Imputed value = 0.0
# Offset 6483 → Imputed value = 0.0
# Offset 6484 → Imputed value = 0.0
# Offset 6485 → Imputed value = 0.0
# Offset 6486 → Imputed value = 0.0
# Offset 6487 → Imputed value = 0.0
# Offset 6488 → Imputed value = 0.0
# Offset 6489 → Imputed value = 0.0
# Offset 6490 → Imputed value = 0.0
# Offset 6491 → Imputed value = 0.0
# Offset 6492 → Imputed value = 0.0
# Offset 6493 → Imputed value = 0.0
# Offset 6494 → Imputed value = 0.0
# Offset 6495 → Imputed value = 0.0
# Offset 6496 → Imputed value = 0.0
# Offset 6497 → Imputed value = 0.0
# Offset 6498 → Imputed value = 0.0
# Offset 6499 → Imputed value = 0.0
# Offset 6500 → Imputed value = 0.0
# Offset 6501 → Imputed value = 0.0
# Offset 6502 → Imputed value = 0.0
# Offset 6503 → Imputed value = 0.0
# Offset 6504 → Imputed value = 0.0
# Offset 6505 → Imputed value = 0.0
# Offset 6506 → Imputed value = 0.0
# Offset 6507 → Imputed value = 0.0
# Offset 6508 → Imputed value = 0.0
# Offset 6509 → Imputed value = 0.0
# Offset 6510 → Imputed value = 0.0
# Offset 6511 → Imputed value = 0.0
# Offset 6512 → Imputed value = 0.0
# Offset 6513 → Imputed value = 0.0
# Offset 6514 → Imputed value = 0.0
# Offset 6515 → Imputed value = 0.0
# Offset 6516 → Imputed value = 0.0
# Offset 6517 → Imputed value = 0.0
# Offset 6518 → Imputed value = 0.0
# Offset 6519 → Imputed value = 0.0
# Offset 6520 → Imputed value = 0.0
# Offset 6521 → Imputed value = 0.0
# Offset 6522 → Imputed value = 0.0
# Offset 6523 → Imputed value = 0.0
# Offset 6524 → Imputed value = 0.0
# Offset 6525 → Imputed value = 0.0
# Offset 6526 → Imputed value = 0.0
# Offset 6527 → Imputed value = 0.0
# Offset 6528 → Imputed value = 0.0
# Offset 6529 → Imputed value = 0.0
# Offset 6530 → Imputed value = 0.0
# Offset 6531 → Imputed value = 0.0
# Offset 6532 → Imputed value = 0.0
# Offset 6533 → Imputed value = 0.0
# Offset 6534 → Imputed value = 0.0
# Offset 6535 → Imputed value = 0.0
# Offset 6536 → Imputed value = 0.0
# Offset 6537 → Imputed value = 0.0
# Offset 6538 → Imputed value = 0.0
# Offset 6539 → Imputed value = 0.0
# Offset 6540 → Imputed value = 0.0
# Offset 6541 → Imputed value = 0.0
# Offset 6542 → Imputed value = 0.0
# Offset 6543 → Imputed value = 0.0
# Offset 6544 → Imputed value = 0.0
# Offset 6545 → Imputed value = 0.0
# Offset 6546 → Imputed value = 0.0
# Offset 6547 → Imputed value = 0.0
# Offset 6548 → Imputed value = 0.0
# Offset 6549 → Imputed value = 0.0
# Offset 6550 → Imputed value = 0.0
# Offset 6551 → Imputed value = 0.0
# Offset 6552 → Imputed value = 0.0
# Offset 6553 → Imputed value = 0.0
# Offset 6554 → Imputed value = 0.0
# Offset 6555 → Imputed value = 0.0
# Offset 6556 → Imputed value = 0.0
# Offset 6557 → Imputed value = 0.0
# Offset 6558 → Imputed value = 0.0
# Offset 6559 → Imputed value = 0.0
# Offset 6560 → Imputed value = 0.0
# Offset 6561 → Imputed value = 0.0
# Offset 6562 → Imputed value = 0.0
# Offset 6563 → Imputed value = 0.0
# Offset 6564 → Imputed value = 0.0
# Offset 6565 → Imputed value = 0.0
# Offset 6566 → Imputed value = 0.0
# Offset 6567 → Imputed value = 0.0
# Offset 6568 → Imputed value = 0.0
# Offset 6569 → Imputed value = 0.0
# Offset 6570 → Imputed value = 0.0
# Offset 6571 → Imputed value = 0.0
# Offset 6572 → Imputed value = 0.0
# Offset 6573 → Imputed value = 0.0
# Offset 6574 → Imputed value = 0.0
# Offset 6575 → Imputed value = 0.0
# Offset 6576 → Imputed value = 0.0
# Offset 6577 → Imputed value = 0.0
# Offset 6578 → Imputed value = 0.0
# Offset 6579 → Imputed value = 0.0
# Offset 6580 → Imputed value = 0.0
# Offset 6581 → Imputed value = 0.0
# Offset 6582 → Imputed value = 0.0
# Offset 6583 → Imputed value = 0.0
# Offset 6584 → Imputed value = 0.0
# Offset 6585 → Imputed value = 0.0
# Offset 6586 → Imputed value = 0.0
# Offset 6587 → Imputed value = 0.0
# Offset 6588 → Imputed value = 0.0
# Offset 6589 → Imputed value = 0.0
# Offset 6590 → Imputed value = 0.0
# Offset 6591 → Imputed value = 0.0
# Offset 6592 → Imputed value = 0.0
# Offset 6593 → Imputed value = 0.0
# Offset 6594 → Imputed value = 0.0
# Offset 6595 → Imputed value = 0.0
# Offset 6596 → Imputed value = 0.0
# Offset 6597 → Imputed value = 0.0
# Offset 6598 → Imputed value = 0.0
# Offset 6599 → Imputed value = 0.0
# Offset 6600 → Imputed value = 0.0
# Offset 6601 → Imputed value = 0.0
# Offset 6602 → Imputed value = 0.0
# Offset 6603 → Imputed value = 0.0
# Offset 6604 → Imputed value = 0.0
# Offset 6605 → Imputed value = 0.0
# Offset 6606 → Imputed value = 0.0
# Offset 6607 → Imputed value = 0.0
# Offset 6608 → Imputed value = 0.0
# Offset 6609 → Imputed value = 0.0
# Offset 6610 → Imputed value = 0.0
# Offset 6611 → Imputed value = 0.0
# Offset 6612 → Imputed value = 0.0
# Offset 6613 → Imputed value = 0.0
# Offset 6614 → Imputed value = 0.0
# Offset 6615 → Imputed value = 0.0
# Offset 6616 → Imputed value = 0.0
# Offset 6617 → Imputed value = 0.0
# Offset 6618 → Imputed value = 0.0
# Offset 6619 → Imputed value = 0.0
# Offset 6620 → Imputed value = 0.0
# Offset 6621 → Imputed value = 0.0
# Offset 6622 → Imputed value = 0.0
# Offset 6623 → Imputed value = 0.0
# Offset 6624 → Imputed value = 0.0
# Offset 6625 → Imputed value = 0.0
# Offset 6626 → Imputed value = 0.0
# Offset 6627 → Imputed value = 0.0
# Offset 6628 → Imputed value = 0.0
# Offset 6629 → Imputed value = 0.0
# Offset 6630 → Imputed value = 0.0
# Offset 6631 → Imputed value = 0.0
# Offset 6632 → Imputed value = 0.0
# Offset 6633 → Imputed value = 0.0
# Offset 6634 → Imputed value = 0.0
# Offset 6635 → Imputed value = 0.0
# Offset 6636 → Imputed value = 0.0
# Offset 6637 → Imputed value = 0.0
# Offset 6638 → Imputed value = 0.0
# Offset 6639 → Imputed value = 0.0
# Offset 6640 → Imputed value = 0.0
# Offset 6641 → Imputed value = 0.0
# Offset 6642 → Imputed value = 0.0
# Offset 6643 → Imputed value = 0.0
# Offset 6644 → Imputed value = 0.0
# Offset 6645 → Imputed value = 0.0
# Offset 6646 → Imputed value = 0.0
# Offset 6647 → Imputed value = 0.0
# Offset 6648 → Imputed value = 0.0
# Offset 6649 → Imputed value = 0.0
# Offset 6650 → Imputed value = 0.0
# Offset 6651 → Imputed value = 0.0
# Offset 6652 → Imputed value = 0.0
# Offset 6653 → Imputed value = 0.0
# Offset 6654 → Imputed value = 0.0
# Offset 6655 → Imputed value = 0.0
# Offset 6656 → Imputed value = 0.0
# Offset 6657 → Imputed value = 0.0
# Offset 6658 → Imputed value = 0.0
# Offset 6659 → Imputed value = 0.0
# Offset 6660 → Imputed value = 0.0
# Offset 6661 → Imputed value = 0.0
# Offset 6662 → Imputed value = 0.0
# Offset 6663 → Imputed value = 0.0
# Offset 6664 → Imputed value = 0.0
# Offset 6665 → Imputed value = 0.0
# Offset 6666 → Imputed value = 0.0
# Offset 6667 → Imputed value = 0.0
# Offset 6668 → Imputed value = 0.0
# Offset 6669 → Imputed value = 0.0
# Offset 6670 → Imputed value = 0.0
# Offset 6671 → Imputed value = 0.0
# Offset 6672 → Imputed value = 0.0
# Offset 6673 → Imputed value = 0.0
# Offset 6674 → Imputed value = 0.0
# Offset 6675 → Imputed value = 0.0
# Offset 6676 → Imputed value = 0.0
# Offset 6677 → Imputed value = 0.0
# Offset 6678 → Imputed value = 0.0
# Offset 6679 → Imputed value = 0.0
# Offset 6680 → Imputed value = 0.0
# Offset 6681 → Imputed value = 0.0
# Offset 6682 → Imputed value = 0.0
# Offset 6683 → Imputed value = 0.0
# Offset 6684 → Imputed value = 0.0
# Offset 6685 → Imputed value = 0.0
# Offset 6686 → Imputed value = 0.0
# Offset 6687 → Imputed value = 0.0
# Offset 6688 → Imputed value = 0.0
# Offset 6689 → Imputed value = 0.0
# Offset 6690 → Imputed value = 0.0
# Offset 6691 → Imputed value = 0.0
# Offset 6692 → Imputed value = 0.0
# Offset 6693 → Imputed value = 0.0
# Offset 6694 → Imputed value = 0.0
# Offset 6695 → Imputed value = 0.0
# Offset 6696 → Imputed value = 0.0
# Offset 6697 → Imputed value = 0.0
# Offset 6698 → Imputed value = 0.0
# Offset 6699 → Imputed value = 0.0
# Offset 6700 → Imputed value = 0.0
# Offset 6701 → Imputed value = 0.0
# Offset 6702 → Imputed value = 0.0
# Offset 6703 → Imputed value = 0.0
# Offset 6704 → Imputed value = 0.0
# Offset 6705 → Imputed value = 0.0
# Offset 6706 → Imputed value = 0.0
# Offset 6707 → Imputed value = 0.0
# Offset 6708 → Imputed value = 0.0
# Offset 6709 → Imputed value = 0.0
# Offset 6710 → Imputed value = 0.0
# Offset 6711 → Imputed value = 0.0
# Offset 6712 → Imputed value = 0.0
# Offset 6713 → Imputed value = 0.0
# Offset 6714 → Imputed value = 0.0
# Offset 6715 → Imputed value = 0.0
# Offset 6716 → Imputed value = 0.0
# Offset 6717 → Imputed value = 0.0
# Offset 6718 → Imputed value = 0.0
# Offset 6719 → Imputed value = 0.0
# Offset 6720 → Imputed value = 0.0
# Offset 6721 → Imputed value = 0.0
# Offset 6722 → Imputed value = 0.0
# Offset 6723 → Imputed value = 0.0
# Offset 6724 → Imputed value = 0.0
# Offset 6725 → Imputed value = 0.0
# Offset 6726 → Imputed value = 0.0
# Offset 6727 → Imputed value = 0.0
# Offset 6728 → Imputed value = 0.0
# Offset 6729 → Imputed value = 0.0
# Offset 6730 → Imputed value = 0.0
# Offset 6731 → Imputed value = 0.0
# Offset 6732 → Imputed value = 0.0
# Offset 6733 → Imputed value = 0.0
# Offset 6734 → Imputed value = 0.0
# Offset 6735 → Imputed value = 0.0
# Offset 6736 → Imputed value = 0.0
# Offset 6737 → Imputed value = 0.0
# Offset 6738 → Imputed value = 0.0
# Offset 6739 → Imputed value = 0.0
# Offset 6740 → Imputed value = 0.0
# Offset 6741 → Imputed value = 0.0
# Offset 6742 → Imputed value = 0.0
# Offset 6743 → Imputed value = 0.0
# Offset 6744 → Imputed value = 0.0
# Offset 6745 → Imputed value = 0.0
# Offset 6746 → Imputed value = 0.0
# Offset 6747 → Imputed value = 0.0
# Offset 6748 → Imputed value = 0.0
# Offset 6749 → Imputed value = 0.0
# Offset 6750 → Imputed value = 0.0
# Offset 6751 → Imputed value = 0.0
# Offset 6752 → Imputed value = 0.0
# Offset 6753 → Imputed value = 0.0
# Offset 6754 → Imputed value = 0.0
# Offset 6755 → Imputed value = 0.0
# Offset 6756 → Imputed value = 0.0
# Offset 6757 → Imputed value = 0.0
# Offset 6758 → Imputed value = 0.0
# Offset 6759 → Imputed value = 0.0
# Offset 6760 → Imputed value = 0.0
# Offset 6761 → Imputed value = 0.0
# Offset 6762 → Imputed value = 0.0
# Offset 6763 → Imputed value = 0.0
# Offset 6764 → Imputed value = 0.0
# Offset 6765 → Imputed value = 0.0
# Offset 6766 → Imputed value = 0.0
# Offset 6767 → Imputed value = 0.0
# Offset 6768 → Imputed value = 0.0
# Offset 6769 → Imputed value = 0.0
# Offset 6770 → Imputed value = 0.0
# Offset 6771 → Imputed value = 0.0
# Offset 6772 → Imputed value = 0.0
# Offset 6773 → Imputed value = 0.0
# Offset 6774 → Imputed value = 0.0
# Offset 6775 → Imputed value = 0.0
# Offset 6776 → Imputed value = 0.0
# Offset 6777 → Imputed value = 0.0
# Offset 6778 → Imputed value = 0.0
# Offset 6779 → Imputed value = 0.0
# Offset 6780 → Imputed value = 0.0
# Offset 6781 → Imputed value = 0.0
# Offset 6782 → Imputed value = 0.0
# Offset 6783 → Imputed value = 0.0
# Offset 6784 → Imputed value = 0.0
# Offset 6785 → Imputed value = 0.0
# Offset 6786 → Imputed value = 0.0
# Offset 6787 → Imputed value = 0.0
# Offset 6788 → Imputed value = 0.0
# Offset 6789 → Imputed value = 0.0
# Offset 6790 → Imputed value = 0.0
# Offset 6791 → Imputed value = 0.0
# Offset 6792 → Imputed value = 0.0
# Offset 6793 → Imputed value = 0.0
# Offset 6794 → Imputed value = 0.0
# Offset 6795 → Imputed value = 0.0
# Offset 6796 → Imputed value = 0.0
# Offset 6797 → Imputed value = 0.0
# Offset 6798 → Imputed value = 0.0
# Offset 6799 → Imputed value = 0.0
# Offset 6800 → Imputed value = 0.0
# Offset 6801 → Imputed value = 0.0
# Offset 6802 → Imputed value = 0.0
# Offset 6803 → Imputed value = 0.0
# Offset 6804 → Imputed value = 0.0
# Offset 6805 → Imputed value = 0.0
# Offset 6806 → Imputed value = 0.0
# Offset 6807 → Imputed value = 0.0
# Offset 6808 → Imputed value = 0.0
# Offset 6809 → Imputed value = 0.0
# Offset 6810 → Imputed value = 0.0
# Offset 6811 → Imputed value = 0.0
# Offset 6812 → Imputed value = 0.0
# Offset 6813 → Imputed value = 0.0
# Offset 6814 → Imputed value = 0.0
# Offset 6815 → Imputed value = 0.0
# Offset 6816 → Imputed value = 0.0
# Offset 6817 → Imputed value = 0.0
# Offset 6818 → Imputed value = 0.0
# Offset 6819 → Imputed value = 0.0
# Offset 6820 → Imputed value = 0.0
# Offset 6821 → Imputed value = 0.0
# Offset 6822 → Imputed value = 0.0
# Offset 6823 → Imputed value = 0.0
# Offset 6824 → Imputed value = 0.0
# Offset 6825 → Imputed value = 0.0
# Offset 6826 → Imputed value = 0.0
# Offset 6827 → Imputed value = 0.0
# Offset 6828 → Imputed value = 0.0
# Offset 6829 → Imputed value = 0.0
# Offset 6830 → Imputed value = 0.0
# Offset 6831 → Imputed value = 0.0
# Offset 6832 → Imputed value = 0.0
# Offset 6833 → Imputed value = 0.0
# Offset 6834 → Imputed value = 0.0
# Offset 6835 → Imputed value = 0.0
# Offset 6836 → Imputed value = 0.0
# Offset 6837 → Imputed value = 0.0
# Offset 6838 → Imputed value = 0.0
# Offset 6839 → Imputed value = 0.0
# Offset 6840 → Imputed value = 0.0
# Offset 6841 → Imputed value = 0.0
# Offset 6842 → Imputed value = 0.0
# Offset 6843 → Imputed value = 0.0
# Offset 6844 → Imputed value = 0.0
# Offset 6845 → Imputed value = 0.0
# Offset 6846 → Imputed value = 0.0
# Offset 6847 → Imputed value = 0.0
# Offset 6848 → Imputed value = 0.0
# Offset 6849 → Imputed value = 0.0
# Offset 6850 → Imputed value = 0.0
# Offset 6851 → Imputed value = 0.0
# Offset 6852 → Imputed value = 0.0
# Offset 6853 → Imputed value = 0.0
# Offset 6854 → Imputed value = 0.0
# Offset 6855 → Imputed value = 0.0
# Offset 6856 → Imputed value = 0.0
# Offset 6857 → Imputed value = 0.0
# Offset 6858 → Imputed value = 0.0
# Offset 6859 → Imputed value = 0.0
# Offset 6860 → Imputed value = 0.0
# Offset 6861 → Imputed value = 0.0
# Offset 6862 → Imputed value = 0.0
# Offset 6863 → Imputed value = 0.0
# Offset 6864 → Imputed value = 0.0
# Offset 6865 → Imputed value = 0.0
# Offset 6866 → Imputed value = 0.0
# Offset 6867 → Imputed value = 0.0
# Offset 6868 → Imputed value = 0.0
# Offset 6869 → Imputed value = 0.0
# Offset 6870 → Imputed value = 0.0
# Offset 6871 → Imputed value = 0.0
# Offset 6872 → Imputed value = 0.0
# Offset 6873 → Imputed value = 0.0
# Offset 6874 → Imputed value = 0.0
# Offset 6875 → Imputed value = 0.0
# Offset 6876 → Imputed value = 0.0
# Offset 6877 → Imputed value = 0.0
# Offset 6878 → Imputed value = 0.0
# Offset 6879 → Imputed value = 0.0
# Offset 6880 → Imputed value = 0.0
# Offset 6881 → Imputed value = 0.0
# Offset 6882 → Imputed value = 0.0
# Offset 6883 → Imputed value = 0.0
# Offset 6884 → Imputed value = 0.0
# Offset 6885 → Imputed value = 0.0
# Offset 6886 → Imputed value = 0.0
# Offset 6887 → Imputed value = 0.0
# Offset 6888 → Imputed value = 0.0
# Offset 6889 → Imputed value = 0.0
# Offset 6890 → Imputed value = 0.0
# Offset 6891 → Imputed value = 0.0
# Offset 6892 → Imputed value = 0.0
# Offset 6893 → Imputed value = 0.0
# Offset 6894 → Imputed value = 0.0
# Offset 6895 → Imputed value = 0.0
# Offset 6896 → Imputed value = 0.0
# Offset 6897 → Imputed value = 0.0
# Offset 6898 → Imputed value = 0.0
# Offset 6899 → Imputed value = 0.0
# Offset 6900 → Imputed value = 0.0
# Offset 6901 → Imputed value = 0.0
# Offset 6902 → Imputed value = 0.0
# Offset 6903 → Imputed value = 0.0
# Offset 6904 → Imputed value = 0.0
# Offset 6905 → Imputed value = 0.0
# Offset 6906 → Imputed value = 0.0
# Offset 6907 → Imputed value = 0.0
# Offset 6908 → Imputed value = 0.0
# Offset 6909 → Imputed value = 0.0
# Offset 6910 → Imputed value = 0.0
# Offset 6911 → Imputed value = 0.0
# Offset 6912 → Imputed value = 0.0
# Offset 6913 → Imputed value = 0.0
# Offset 6914 → Imputed value = 0.0
# Offset 6915 → Imputed value = 0.0
# Offset 6916 → Imputed value = 0.0
# Offset 6917 → Imputed value = 0.0
# Offset 6918 → Imputed value = 0.0
# Offset 6919 → Imputed value = 0.0
# Offset 6920 → Imputed value = 0.0
# Offset 6921 → Imputed value = 0.0
# Offset 6922 → Imputed value = 0.0
# Offset 6923 → Imputed value = 0.0
# Offset 6924 → Imputed value = 0.0
# Offset 6925 → Imputed value = 0.0
# Offset 6926 → Imputed value = 0.0
# Offset 6927 → Imputed value = 0.0
# Offset 6928 → Imputed value = 0.0
# Offset 6929 → Imputed value = 0.0
# Offset 6930 → Imputed value = 0.0
# Offset 6931 → Imputed value = 0.0
# Offset 6932 → Imputed value = 0.0
# Offset 6933 → Imputed value = 0.0
# Offset 6934 → Imputed value = 0.0
# Offset 6935 → Imputed value = 0.0
# Offset 6936 → Imputed value = 0.0
# Offset 6937 → Imputed value = 0.0
# Offset 6938 → Imputed value = 0.0
# Offset 6939 → Imputed value = 0.0
# Offset 6940 → Imputed value = 0.0
# Offset 6941 → Imputed value = 0.0
# Offset 6942 → Imputed value = 0.0
# Offset 6943 → Imputed value = 0.0
# Offset 6944 → Imputed value = 0.0
# Offset 6945 → Imputed value = 0.0
# Offset 6946 → Imputed value = 0.0
# Offset 6947 → Imputed value = 0.0
# Offset 6948 → Imputed value = 0.0
# Offset 6949 → Imputed value = 0.0
# Offset 6950 → Imputed value = 0.0
# Offset 6951 → Imputed value = 0.0
# Offset 6952 → Imputed value = 0.0
# Offset 6953 → Imputed value = 0.0
# Offset 6954 → Imputed value = 0.0
# Offset 6955 → Imputed value = 0.0
# Offset 6956 → Imputed value = 0.0
# Offset 6957 → Imputed value = 0.0
# Offset 6958 → Imputed value = 0.0
# Offset 6959 → Imputed value = 0.0
# Offset 6960 → Imputed value = 0.0
# Offset 6961 → Imputed value = 0.0
# Offset 6962 → Imputed value = 0.0
# Offset 6963 → Imputed value = 0.0
# Offset 6964 → Imputed value = 0.0
# Offset 6965 → Imputed value = 0.0
# Offset 6966 → Imputed value = 0.0
# Offset 6967 → Imputed value = 0.0
# Offset 6968 → Imputed value = 0.0
# Offset 6969 → Imputed value = 0.0
# Offset 6970 → Imputed value = 0.0
# Offset 6971 → Imputed value = 0.0
# Offset 6972 → Imputed value = 0.0
# Offset 6973 → Imputed value = 0.0
# Offset 6974 → Imputed value = 0.0
# Offset 6975 → Imputed value = 0.0
# Offset 6976 → Imputed value = 0.0
# Offset 6977 → Imputed value = 0.0
# Offset 6978 → Imputed value = 0.0
# Offset 6979 → Imputed value = 0.0
# Offset 6980 → Imputed value = 0.0
# Offset 6981 → Imputed value = 0.0
# Offset 6982 → Imputed value = 0.0
# Offset 6983 → Imputed value = 0.0
# Offset 6984 → Imputed value = 0.0
# Offset 6985 → Imputed value = 0.0
# Offset 6986 → Imputed value = 0.0
# Offset 6987 → Imputed value = 0.0
# Offset 6988 → Imputed value = 0.0
# Offset 6989 → Imputed value = 0.0
# Offset 6990 → Imputed value = 0.0
# Offset 6991 → Imputed value = 0.0
# Offset 6992 → Imputed value = 0.0
# Offset 6993 → Imputed value = 0.0
# Offset 6994 → Imputed value = 0.0
# Offset 6995 → Imputed value = 0.0
# Offset 6996 → Imputed value = 0.0
# Offset 6997 → Imputed value = 0.0
# Offset 6998 → Imputed value = 0.0
# Offset 6999 → Imputed value = 0.0
# Offset 7000 → Imputed value = 0.0
# Offset 7001 → Imputed value = 0.0
# Offset 7002 → Imputed value = 0.0
# Offset 7003 → Imputed value = 0.0
# Offset 7004 → Imputed value = 0.0
# Offset 7005 → Imputed value = 0.0
# Offset 7006 → Imputed value = 0.0
# Offset 7007 → Imputed value = 0.0
# Offset 7008 → Imputed value = 0.0
# Offset 7009 → Imputed value = 0.0
# Offset 7010 → Imputed value = 0.0
# Offset 7011 → Imputed value = 0.0
# Offset 7012 → Imputed value = 0.0
# Offset 7013 → Imputed value = 0.0
# Offset 7014 → Imputed value = 0.0
# Offset 7015 → Imputed value = 0.0
# Offset 7016 → Imputed value = 0.0
# Offset 7017 → Imputed value = 0.0
# Offset 7018 → Imputed value = 0.0
# Offset 7019 → Imputed value = 0.0
# Offset 7020 → Imputed value = 0.0
# Offset 7021 → Imputed value = 0.0
# Offset 7022 → Imputed value = 0.0
# Offset 7023 → Imputed value = 0.0
# Offset 7024 → Imputed value = 0.0
# Offset 7025 → Imputed value = 0.0
# Offset 7026 → Imputed value = 0.0
# Offset 7027 → Imputed value = 0.0
# Offset 7028 → Imputed value = 0.0
# Offset 7029 → Imputed value = 0.0
# Offset 7030 → Imputed value = 0.0
# Offset 7031 → Imputed value = 0.0
# Offset 7032 → Imputed value = 0.0
# Offset 7033 → Imputed value = 0.0
# Offset 7034 → Imputed value = 0.0
# Offset 7035 → Imputed value = 0.0
# Offset 7036 → Imputed value = 0.0
# Offset 7037 → Imputed value = 0.0
# Offset 7038 → Imputed value = 0.0
# Offset 7039 → Imputed value = 0.0
# Offset 7040 → Imputed value = 0.0
# Offset 7041 → Imputed value = 0.0
# Offset 7042 → Imputed value = 0.0
# Offset 7043 → Imputed value = 0.0
# Offset 7044 → Imputed value = 0.0
# Offset 7045 → Imputed value = 0.0
# Offset 7046 → Imputed value = 0.0
# Offset 7047 → Imputed value = 0.0
# Offset 7048 → Imputed value = 0.0
# Offset 7049 → Imputed value = 0.0
# Offset 7050 → Imputed value = 0.0
# Offset 7051 → Imputed value = 0.0
# Offset 7052 → Imputed value = 0.0
# Offset 7053 → Imputed value = 0.0
# Offset 7054 → Imputed value = 0.0
# Offset 7055 → Imputed value = 0.0
# Offset 7056 → Imputed value = 0.0
# Offset 7057 → Imputed value = 0.0
# Offset 7058 → Imputed value = 0.0
# Offset 7059 → Imputed value = 0.0
# Offset 7060 → Imputed value = 0.0
# Offset 7061 → Imputed value = 0.0
# Offset 7062 → Imputed value = 0.0
# Offset 7063 → Imputed value = 0.0
# Offset 7064 → Imputed value = 0.0
# Offset 7065 → Imputed value = 0.0
# Offset 7066 → Imputed value = 0.0
# Offset 7067 → Imputed value = 0.0
# Offset 7068 → Imputed value = 0.0
# Offset 7069 → Imputed value = 0.0
# Offset 7070 → Imputed value = 0.0
# Offset 7071 → Imputed value = 0.0
# Offset 7072 → Imputed value = 0.0
# Offset 7073 → Imputed value = 0.0
# Offset 7074 → Imputed value = 0.0
# Offset 7075 → Imputed value = 0.0
# Offset 7076 → Imputed value = 0.0
# Offset 7077 → Imputed value = 0.0
# Offset 7078 → Imputed value = 0.0
# Offset 7079 → Imputed value = 0.0
# Offset 7080 → Imputed value = 0.0
# Offset 7081 → Imputed value = 0.0
# Offset 7082 → Imputed value = 0.0
# Offset 7083 → Imputed value = 0.0
# Offset 7084 → Imputed value = 0.0
# Offset 7085 → Imputed value = 0.0
# Offset 7086 → Imputed value = 0.0
# Offset 7087 → Imputed value = 0.0
# Offset 7088 → Imputed value = 0.0
# Offset 7089 → Imputed value = 0.0
# Offset 7090 → Imputed value = 0.0
# Offset 7091 → Imputed value = 0.0
# Offset 7092 → Imputed value = 0.0
# Offset 7093 → Imputed value = 0.0
# Offset 7094 → Imputed value = 0.0
# Offset 7095 → Imputed value = 0.0
# Offset 7096 → Imputed value = 0.0
# Offset 7097 → Imputed value = 0.0
# Offset 7098 → Imputed value = 0.0
# Offset 7099 → Imputed value = 0.0
# Offset 7100 → Imputed value = 0.0
# Offset 7101 → Imputed value = 0.0
# Offset 7102 → Imputed value = 0.0
# Offset 7103 → Imputed value = 0.0
# Offset 7104 → Imputed value = 0.0
# Offset 7105 → Imputed value = 0.0
# Offset 7106 → Imputed value = 0.0
# Offset 7107 → Imputed value = 0.0
# Offset 7108 → Imputed value = 0.0
# Offset 7109 → Imputed value = 0.0
# Offset 7110 → Imputed value = 0.0
# Offset 7111 → Imputed value = 0.0
# Offset 7112 → Imputed value = 0.0
# Offset 7113 → Imputed value = 0.0
# Offset 7114 → Imputed value = 0.0
# Offset 7115 → Imputed value = 0.0
# Offset 7116 → Imputed value = 0.0
# Offset 7117 → Imputed value = 0.0
# Offset 7118 → Imputed value = 0.0
# Offset 7119 → Imputed value = 0.0
# Offset 7120 → Imputed value = 0.0
# Offset 7121 → Imputed value = 0.0
# Offset 7122 → Imputed value = 0.0
# Offset 7123 → Imputed value = 0.0
# Offset 7124 → Imputed value = 0.0
# Offset 7125 → Imputed value = 0.0
# Offset 7126 → Imputed value = 0.0
# Offset 7127 → Imputed value = 0.0
# Offset 7128 → Imputed value = 0.0
# Offset 7129 → Imputed value = 0.0
# Offset 7130 → Imputed value = 0.0
# Offset 7131 → Imputed value = 0.0
# Offset 7132 → Imputed value = 0.0
# Offset 7133 → Imputed value = 0.0
# Offset 7134 → Imputed value = 0.0
# Offset 7135 → Imputed value = 0.0
# Offset 7136 → Imputed value = 0.0
# Offset 7137 → Imputed value = 0.0
# Offset 7138 → Imputed value = 0.0

# %% [markdown]
# # ---------------------------------------------------------
# # 🔹 STEP 5: Evaluating all imputation methods (END Block)
# # ---------------------------------------------------------

# %%
results_block = []

# 🎯 True values for the missing block
true_vals = true_target_array[start_idx:end_idx]
missing_indices = np.arange(start_idx, end_idx)

# ✅ Helper to evaluate predictions against true values

def evaluate_direct(name, imputed_array):
    try:
        predicted = imputed_array[start_idx:end_idx]
        
        # Core Errors
        mae = np.mean(np.abs(predicted - true_vals))
        rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))
        me = np.mean(predicted - true_vals)  # Mean Error (signed)

        # Bias-Variance
        bias = np.mean(predicted) - np.mean(true_vals)
        bias_sq = bias ** 2
        variance = np.mean((predicted - np.mean(predicted)) ** 2)

        results_block.append({
            "Method": name,
            "MAE": round(mae, 4),
            "RMSE": round(rmse, 4),
            "ME": round(me, 4),
            "Bias^2": round(bias_sq, 4),
            "Variance": round(variance, 4),
            "First Imputed": round(predicted[0], 4),
            "Last Imputed": round(predicted[-1], 4),
            "First True": round(true_vals[0], 4),
            "Last True": round(true_vals[-1], 4),
            "Missing Block": "END"
        })
    except Exception as e:
        results_block.append({
            "Method": name,
            "MAE": "NaN",
            "RMSE": "NaN",
            "ME": "NaN",
            "Bias^2": "NaN",
            "Variance": "NaN",
            "First Imputed": "NaN",
            "Last Imputed": "NaN",
            "First True": round(true_vals[0], 4),
            "Last True": round(true_vals[-1], 4),
            "Missing Block": "END"
        })

# ✅ TKCM (loop over all missing indices)
try:
    tkcm_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_imputed = TKCM(k=k, l=l).impute(tkcm_imputed, offset=offset, ref_ts=ref_matrix)
    evaluate_direct("TKCM", tkcm_imputed)
except Exception as e:
    print(" TKCM failed:", e)
    evaluate_direct("TKCM", np.full_like(true_vals, np.nan))
    
# ✅ TKCM_PLUS (loop over all missing indices)
try:
    tkcm_plus_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_plus_imputed = TKCM_PLUS(k=k, l=l, alpha=0.5, beta=0.5).impute(
            tkcm_plus_imputed, offset=offset, ref_ts=ref_matrix
        )
    evaluate_direct("TKCM_PLUS", tkcm_plus_imputed)
except Exception as e:
    print(" TKCM_PLUS failed:", e)
    evaluate_direct("TKCM_PLUS", np.full_like(true_vals, np.nan))


# ✅ TKCM_Weighted (loop over all missing indices)
try:
    tkcm_weighted_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_weighted_imputed = TKCM_Weighted(k=k, l=l).impute(tkcm_weighted_imputed, offset=offset, ref_ts=ref_matrix)
    evaluate_direct("TKCM_Weighted", tkcm_weighted_imputed)
except Exception as e:
    print(" TKCM_Weighted failed:", e)
    evaluate_direct("TKCM_Weighted", np.full_like(true_vals, np.nan))
    
# ✅ TKCM_PRO (loop over all missing indices)
try:
    tkcm_pro_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_pro_imputed = TKCM_PRO(k=k, l=l).impute(
            tkcm_pro_imputed, offset=offset, ref_ts=ref_matrix
        )
    evaluate_direct("TKCM_PRO", tkcm_pro_imputed)
except Exception as e:
    print(" TKCM_PRO failed:", e)
    evaluate_direct("TKCM_PRO", np.full_like(true_vals, np.nan))
    



# ✅ Other models (no change needed)
evaluate_direct("CDRec", cdrec_imputed)
evaluate_direct("DynaMMo", dynammo_imputed)
evaluate_direct("SoftImpute", soft_imputed)
evaluate_direct("SVDImpute", svd_imputed)

# ✅ ST_MVL — remove NaNs from references
try:
    X_stmv = X_stacked.copy()
    X_stmv[1:, :] = np.nan_to_num(X_stmv[1:, :])
    st_mvl_model = ST_MVL()
    st_mvl_imputed = st_mvl_model.impute(X_stmv)[0]
    evaluate_direct("ST_MVL", st_mvl_imputed)
except Exception as e:
    print(" ST_MVL failed:", e)
    evaluate_direct("ST_MVL", np.full_like(true_vals, np.nan))

# ✅ TRMF — fixed implementation
try:
    X_trmf_input = X_stacked.T.copy()
    observed_mask = ~np.isnan(X_stacked.T)
    X_trmf_input = np.nan_to_num(X_trmf_input, nan=0.0).astype(np.float64)
    trmf_model = TRMFImputer(rank=rank, lag_idx=[1, 2, 3])
    trmf_model.fit(X_trmf_input, observed_mask)
    X_trmf_output = trmf_model.transform()
    trmf_imputed = X_trmf_output[:, 0]
    evaluate_direct("TRMF", trmf_imputed)
except Exception as e:
    print(" TRMF failed:", e)
    evaluate_direct("TRMF", np.full_like(true_vals, np.nan))
    
evaluate_direct("Zero", zero_imputed)
evaluate_direct("Min", min_imputed)
evaluate_direct("Interpolation", interp_imputed)


# ✅ Final Results Display
results_df = pd.DataFrame(results_block)
display(results_df.style.background_gradient(cmap="YlGnBu", subset=["MAE", "RMSE", "ME", "Bias^2", "Variance"]))
# Out:
# <style type="text/css">
# #T_4d6e5_row0_col1, #T_4d6e5_row2_col1 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_4d6e5_row0_col2, #T_4d6e5_row2_col2 {
#   background-color: #1f7eb7;
#   color: #f1f1f1;
# }
# #T_4d6e5_row0_col3, #T_4d6e5_row2_col3 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_4d6e5_row0_col4, #T_4d6e5_row2_col4 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_4d6e5_row0_col5, #T_4d6e5_row6_col4 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_4d6e5_row1_col1 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_4d6e5_row1_col2 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_4d6e5_row1_col3 {
#   background-color: #3db2c4;
#   color: #f1f1f1;
# }
# #T_4d6e5_row1_col4 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_4d6e5_row1_col5, #T_4d6e5_row3_col3, #T_4d6e5_row9_col5, #T_4d6e5_row10_col5, #T_4d6e5_row11_col5, #T_4d6e5_row12_col1, #T_4d6e5_row12_col2, #T_4d6e5_row12_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_4d6e5_row2_col5 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_4d6e5_row3_col1, #T_4d6e5_row3_col2, #T_4d6e5_row3_col4, #T_4d6e5_row3_col5, #T_4d6e5_row10_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_4d6e5_row4_col1, #T_4d6e5_row4_col2, #T_4d6e5_row5_col1, #T_4d6e5_row5_col2, #T_4d6e5_row7_col1, #T_4d6e5_row7_col2 {
#   background-color: #eef8b3;
#   color: #000000;
# }
# #T_4d6e5_row4_col3 {
#   background-color: #1f82b9;
#   color: #f1f1f1;
# }
# #T_4d6e5_row4_col4, #T_4d6e5_row5_col4, #T_4d6e5_row7_col4 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_4d6e5_row4_col5, #T_4d6e5_row7_col5 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_4d6e5_row5_col3, #T_4d6e5_row7_col3 {
#   background-color: #1e83ba;
#   color: #f1f1f1;
# }
# #T_4d6e5_row5_col5, #T_4d6e5_row6_col5 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_4d6e5_row6_col1, #T_4d6e5_row6_col2 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_4d6e5_row6_col3 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_4d6e5_row8_col1 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_4d6e5_row8_col2 {
#   background-color: #cfecb3;
#   color: #000000;
# }
# #T_4d6e5_row8_col3 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_4d6e5_row8_col4 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_4d6e5_row8_col5 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_4d6e5_row9_col1 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_4d6e5_row9_col2 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_4d6e5_row9_col3 {
#   background-color: #172976;
#   color: #f1f1f1;
# }
# #T_4d6e5_row9_col4 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_4d6e5_row10_col1 {
#   background-color: #2070b0;
#   color: #f1f1f1;
# }
# #T_4d6e5_row10_col2 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
# }
# #T_4d6e5_row10_col4 {
#   background-color: #42b6c4;
#   color: #f1f1f1;
# }
# #T_4d6e5_row11_col1 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_4d6e5_row11_col2 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_4d6e5_row11_col3 {
#   background-color: #9ed9b8;
#   color: #000000;
# }
# #T_4d6e5_row11_col4 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_4d6e5_row12_col3 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_4d6e5_row12_col5 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# </style>
# <table id="T_4d6e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d6e5_level0_col0" class="col_heading level0 col0" >Method</th>
#       <th id="T_4d6e5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4d6e5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4d6e5_level0_col3" class="col_heading level0 col3" >ME</th>
#       <th id="T_4d6e5_level0_col4" class="col_heading level0 col4" >Bias^2</th>
#       <th id="T_4d6e5_level0_col5" class="col_heading level0 col5" >Variance</th>
#       <th id="T_4d6e5_level0_col6" class="col_heading level0 col6" >First Imputed</th>
#       <th id="T_4d6e5_level0_col7" class="col_heading level0 col7" >Last Imputed</th>
#       <th id="T_4d6e5_level0_col8" class="col_heading level0 col8" >First True</th>
#       <th id="T_4d6e5_level0_col9" class="col_heading level0 col9" >Last True</th>
#       <th id="T_4d6e5_level0_col10" class="col_heading level0 col10" >Missing Block</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d6e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d6e5_row0_col0" class="data row0 col0" >TKCM</td>
#       <td id="T_4d6e5_row0_col1" class="data row0 col1" >1.233200</td>
#       <td id="T_4d6e5_row0_col2" class="data row0 col2" >1.239900</td>
#       <td id="T_4d6e5_row0_col3" class="data row0 col3" >1.233200</td>
#       <td id="T_4d6e5_row0_col4" class="data row0 col4" >1.520800</td>
#       <td id="T_4d6e5_row0_col5" class="data row0 col5" >0.008800</td>
#       <td id="T_4d6e5_row0_col6" class="data row0 col6" >-0.881400</td>
#       <td id="T_4d6e5_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_4d6e5_row0_col8" class="data row0 col8" >-1.462600</td>
#       <td id="T_4d6e5_row0_col9" class="data row0 col9" >-1.055000</td>
#       <td id="T_4d6e5_row0_col10" class="data row0 col10" >END</td>
#     </tr>
#     <tr>
#       <th id="T_4d6e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4d6e5_row1_col0" class="data row1 col0" >TKCM_PLUS</td>
#       <td id="T_4d6e5_row1_col1" class="data row1 col1" >0.215500</td>
#       <td id="T_4d6e5_row1_col2" class="data row1 col2" >0.248100</td>
#       <td id="T_4d6e5_row1_col3" class="data row1 col3" >-0.215500</td>
#       <td id="T_4d6e5_row1_col4" class="data row1 col4" >0.046400</td>
#       <td id="T_4d6e5_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_4d6e5_row1_col6" class="data row1 col6" >-1.470300</td>
#       <td id="T_4d6e5_row1_col7" class="data row1 col7" >-1.466700</td>
#       <td id="T_4d6e5_row1_col8" class="data row1 col8" >-1.462600</td>
#       <td id="T_4d6e5_row1_col9" class="data row1 col9" >-1.055000</td>
#       <td id="T_4d6e5_row1_col10" class="data row1 col10" >END</td>
#     </tr>
#     <tr>
#       <th id="T_4d6e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4d6e5_row2_col0" class="data row2 col0" >TKCM_Weighted</td>
#       <td id="T_4d6e5_row2_col1" class="data row2 col1" >1.232100</td>
#       <td id="T_4d6e5_row2_col2" class="data row2 col2" >1.239800</td>
#       <td id="T_4d6e5_row2_col3" class="data row2 col3" >1.232100</td>
#       <td id="T_4d6e5_row2_col4" class="data row2 col4" >1.518000</td>
#       <td id="T_4d6e5_row2_col5" class="data row2 col5" >0.011800</td>
#       <td id="T_4d6e5_row2_col6" class="data row2 col6" >-0.856000</td>
#       <td id="T_4d6e5_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_4d6e5_row2_col8" class="data row2 col8" >-1.462600</td>
#       <td id="T_4d6e5_row2_col9" class="data row2 col9" >-1.055000</td>
#       <td id="T_4d6e5_row2_col10" class="data row2 col10" >END</td>
#     </tr>
#     <tr>
#       <th id="T_4d6e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4d6e5_row3_col0" class="data row3 col0" >TKCM_PRO</td>
#       <td id="T_4d6e5_row3_col1" class="data row3 col1" >1.773300</td>
#       <td id="T_4d6e5_row3_col2" class="data row3 col2" >1.844200</td>
#       <td id="T_4d6e5_row3_col3" class="data row3 col3" >-1.773300</td>
#       <td id="T_4d6e5_row3_col4" class="data row3 col4" >3.144600</td>
#       <td id="T_4d6e5_row3_col5" class="data row3 col5" >0.396200</td>
#       <td id="T_4d6e5_row3_col6" class="data row3 col6" >-4.074600</td>
#       <td id="T_4d6e5_row3_col7" class="data row3 col7" >-2.047700</td>
#       <td id="T_4d6e5_row3_col8" class="data row3 col8" >-1.462600</td>
#       <td id="T_4d6e5_row3_col9" class="data row3 col9" >-1.055000</td>
#       <td id="T_4d6e5_row3_col10" class="data row3 col10" >END</td>
#     </tr>
#     <tr>
#       <th id="T_4d6e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4d6e5_row4_col0" class="data row4 col0" >CDRec</td>
#       <td id="T_4d6e5_row4_col1" class="data row4 col1" >0.223700</td>

# %% [markdown]
# - MAE (Mean Absolute Error): Average of absolute differences between predicted and true values — lower is better for consistent imputation.
# - RMSE (Root Mean Squared Error): Penalizes larger errors more heavily than MAE — lower means fewer extreme errors.
# - ME (Mean Error): Shows systematic over- or under-estimation — close to 0 means no consistent bias.
# - Bias²: Squared mean error (systematic error); contributes to RMSE — should be low for accurate central tendency.
# - Variance: Error variability across samples — lower variance means more stable predictions.

# %% [markdown]
# ### Simulating a dataset similar to the context of my imputation results

# %%
# Define time axis using the full length of the time series
time = np.arange(len(true_target_array))

# ✅ Imputation results dictionary (same order as benchmark)
imputed_data_real = {
    "True": true_target_array,
    "Masked": masked_target_array,
    "TKCM": tkcm_imputed,
    "TKCM_Weighted": tkcm_weighted_imputed,
    "TKCM_PLUS": tkcm_plus_imputed,
    "TKCM_PRO": tkcm_pro_imputed,
    "CDRec": cdrec_imputed,
    "DynaMMo": dynammo_imputed,
    "SoftImpute": soft_imputed,
    "SVDImpute": svd_imputed,
    "ST_MVL": st_mvl_imputed,
    "TRMF": trmf_imputed,
}

# ✅ Plotting
plt.figure(figsize=(16, 8))

for method, series in imputed_data_real.items():
    # Highlight 'True' as bold solid, others as dashed
    linestyle = "-" if method == "True" else "--"
    linewidth = 2.5 if method == "True" else 1.5
    alpha = 1.0 if method in {"True", "Masked"} else 0.9
    
    plt.plot(time, series, label=method, linestyle=linestyle, linewidth=linewidth, alpha=alpha)

# ✅ Highlight missing block visually
plt.axvspan(start_idx, end_idx, color="gray", alpha=0.2, label="Missing Block")

# ✅ Labels and visual styling
plt.title("🧠 Imputation Comparison on Real Sensor Data", fontsize=16)
plt.xlabel("Time Index", fontsize=13)
plt.ylabel("Normalized Sensor Value", fontsize=13)
plt.legend(loc="upper right", fontsize=10)
plt.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()

# %%
# Time axis based on the full target array
time = np.arange(len(true_target_array))

# Full dictionary of imputed results including basic imputers
imputed_data_real = {
    "True": true_target_array,
    "Masked": masked_target_array,
    "TKCM": tkcm_imputed,
    "TKCM_Weighted": tkcm_weighted_imputed,
    "TKCM_PLUS": tkcm_plus_imputed,
    "TKCM_PRO": tkcm_pro_imputed,
    "CDRec": cdrec_imputed,
    "DynaMMo": dynammo_imputed,
    "SoftImpute": soft_imputed,
    "SVDImpute": svd_imputed,
    "ST_MVL": st_mvl_imputed,
    "TRMF": trmf_imputed,
    "Zero": zero_imputed,
    "Min": min_imputed,
    "Interpolation": interp_imputed,
}

# ✅ Plotting
plt.figure(figsize=(18, 9))

for method, series in imputed_data_real.items():
    # Visual distinction
    if method == "True":
        linestyle = "-"
        linewidth = 2.5
        alpha = 1.0
    elif method == "Masked":
        linestyle = ":"
        linewidth = 2
        alpha = 0.9
    else:
        linestyle = "--"
        linewidth = 1.3
        alpha = 0.8

    plt.plot(time, series, label=method, linestyle=linestyle, linewidth=linewidth, alpha=alpha)

# ✅ Highlight the missing block
plt.axvspan(start_idx, end_idx, color="gray", alpha=0.2, label="Missing Block")

# ✅ Labels and layout
plt.title("🧠 Imputation Comparison Across All Algorithms", fontsize=16)
plt.xlabel("Time Index", fontsize=13)
plt.ylabel("Normalized Sensor Value", fontsize=13)
plt.legend(loc="upper right", fontsize=9, ncol=2)
plt.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()

# %%
# ✅ Define zoom window around the missing block
zoom_start = max(0, start_idx - 20)
zoom_end = min(len(true_target_array), end_idx + 20)
time_zoom = np.arange(zoom_start, zoom_end)

# ✅ Prepare zoomed slices for all methods including basic imputers
imputed_data_zoom = {
    "True": true_target_array[zoom_start:zoom_end],
    "Masked": masked_target_array[zoom_start:zoom_end],
    "TKCM": tkcm_imputed[zoom_start:zoom_end],
    "TKCM_Weighted": tkcm_weighted_imputed[zoom_start:zoom_end],
    "TKCM_PLUS": tkcm_plus_imputed[zoom_start:zoom_end],
    "TKCM_PRO": tkcm_pro_imputed[zoom_start:zoom_end],
    "CDRec": cdrec_imputed[zoom_start:zoom_end],
    "DynaMMo": dynammo_imputed[zoom_start:zoom_end],
    "SoftImpute": soft_imputed[zoom_start:zoom_end],
    "SVDImpute": svd_imputed[zoom_start:zoom_end],
    "ST_MVL": st_mvl_imputed[zoom_start:zoom_end],
    "TRMF": trmf_imputed[zoom_start:zoom_end],
    "Zero": zero_imputed[zoom_start:zoom_end],
    "Min": min_imputed[zoom_start:zoom_end],
    "Interpolation": interp_imputed[zoom_start:zoom_end],
}

# ✅ Plotting
plt.figure(figsize=(18, 9))

for method, series in imputed_data_zoom.items():
    # Styling logic
    if method == "True":
        linestyle = "-"
        linewidth = 2.5
        alpha = 1.0
    elif method == "Masked":
        linestyle = ":"
        linewidth = 2.0
        alpha = 0.9
    else:
        linestyle = "--"
        linewidth = 1.3
        alpha = 0.8

    plt.plot(time_zoom, series, label=method, linestyle=linestyle, linewidth=linewidth, alpha=alpha)

# ✅ Highlight the missing block area
plt.axvspan(start_idx, end_idx, color="gray", alpha=0.25, label="Missing Block")

# ✅ Labels and layout
plt.title("🔍 Zoomed-In Imputation Comparison Around Missing Block", fontsize=16)
plt.xlabel("Time Index", fontsize=13)
plt.ylabel("Normalized Sensor Value", fontsize=13)
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1), fontsize=9)
plt.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()

# %%
# ✅ Mapping method names to imputed arrays
imputed_series_map = {
    "TKCM": tkcm_imputed,
    "TKCM_Weighted": tkcm_weighted_imputed,
    "TKCM_PLUS": tkcm_plus_imputed,
    "TKCM_PRO": tkcm_pro_imputed,
    "CDRec": cdrec_imputed,
    "DynaMMo": dynammo_imputed,
    "SoftImpute": soft_imputed,
    "SVDImpute": svd_imputed,
    "ST_MVL": st_mvl_imputed,
    "TRMF": trmf_imputed,
    "Zero": zero_imputed,
    "Min": min_imputed,
    "Interpolation": interp_imputed,
}

# ✅ Get top 4 methods by RMSE (excluding "True" and "Masked")
top_methods = results_df.sort_values(by="RMSE")["Method"].tolist()
top_methods = [m for m in top_methods if m not in ["True", "Masked"]][:4]

# ✅ Define zoom window
zoom_start = max(0, start_idx - 20)
zoom_end = min(len(true_target_array), end_idx + 20)
time_zoom = np.arange(zoom_start, zoom_end)

# ✅ 2x2 subplot layout
fig, axs = plt.subplots(2, 2, figsize=(16, 10))
axs = axs.flatten()

for i, method in enumerate(top_methods):
    ax = axs[i]

    # Plot True
    ax.plot(time_zoom, true_target_array[zoom_start:zoom_end], 
            label="True", color="black", linewidth=2.5)

    # Plot Masked
    ax.plot(time_zoom, masked_target_array[zoom_start:zoom_end], 
            label="Masked", color="gray", linestyle=":", linewidth=2)

    # Plot imputed method
    if method in imputed_series_map:
        ax.plot(time_zoom, imputed_series_map[method][zoom_start:zoom_end], 
                label=method, linestyle="--", linewidth=1.8)

    # Highlight missing block
    ax.axvspan(start_idx, end_idx, color="lightgray", alpha=0.4)

    # Formatting
    ax.set_title(f"{method} vs True", fontsize=12)
    ax.set_xlabel("Time Index", fontsize=10)
    ax.set_ylabel("Normalized Value", fontsize=10)
    ax.legend(fontsize=9)
    ax.grid(True, linestyle="--", alpha=0.4)

# ✅ Global title and layout
plt.suptitle("🔍 Top 4 Imputation Methods – Zoomed Block View", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# 1️⃣ Define the real missing block range
block_start = start_idx
block_end = end_idx
block_length = block_end - block_start
time_block = np.arange(block_length)

# 2️⃣ Build a mapping with only the imputed block per method
imputed_data_block = {
    "True": true_target_array[block_start:block_end],
    "Masked": masked_target_array[block_start:block_end],
    "TKCM": tkcm_imputed[block_start:block_end],
    "TKCM_Weighted": tkcm_weighted_imputed[block_start:block_end],
    "TKCM_PLUS": tkcm_plus_imputed[block_start:block_end],
    "TKCM_PRO": tkcm_pro_imputed[block_start:block_end],
    "CDRec": cdrec_imputed[block_start:block_end],
    "DynaMMo": dynammo_imputed[block_start:block_end],
    "SoftImpute": soft_imputed[block_start:block_end],
    "SVDImpute": svd_imputed[block_start:block_end],
    "ST_MVL": st_mvl_imputed[block_start:block_end],
    "TRMF": trmf_imputed[block_start:block_end],
    "Zero": zero_imputed[block_start:block_end],
    "Min": min_imputed[block_start:block_end],
    "Interpolation": interp_imputed[block_start:block_end],
}

# 3️⃣ Plot settings
num_plots = len(imputed_data_block)
cols = 3
rows = (num_plots + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(22, 4 * rows), sharex=True, sharey=True)
axes = axes.flatten()

# 4️⃣ Optional color and linestyle configs
linestyles = {
    "True": "-",
    "Masked": ":"
}

colors = {
    "True": "black",
    "Masked": "gray",
    "TKCM": "red",
    "TKCM_Weighted": "orange",
    "TKCM_PLUS": "purple",
    "TKCM_PRO": "green",
    "CDRec": "royalblue",
    "DynaMMo": "saddlebrown",
    "SoftImpute": "hotpink",
    "SVDImpute": "teal",
    "ST_MVL": "turquoise",
    "TRMF": "darkorange",
    "Zero": "darkred",
    "Min": "darkgreen",
    "Interpolation": "slateblue"
}

# 5️⃣ Plot each method’s block
for i, (method, series) in enumerate(imputed_data_block.items()):
    ax = axes[i]
    ax.plot(
        time_block, series,
        label=method,
        linestyle=linestyles.get(method, "--"),
        linewidth=2 if method in ["True", "Masked"] else 1.5,
        color=colors.get(method, "gray")
    )
    ax.axvspan(0, block_length, color="gray", alpha=0.1)
    ax.set_title(f"{method} Imputation", fontsize=13)
    ax.set_xlabel("Time Index", fontsize=10)
    ax.set_ylabel("Sensor Value", fontsize=10)
    ax.grid(True, linestyle='--', alpha=0.4)
    ax.legend(loc="upper right", fontsize=9)

# 6️⃣ Hide unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# 7️⃣ Final layout
fig.suptitle("📊 Imputation Method Performance – Missing Block Only", fontsize=18)
plt.tight_layout(rect=[0, 0.02, 1, 0.95])
plt.show()

# %%
# 1️⃣ Time axis for full-length series
time = np.arange(len(true_target_array))

# 2️⃣ Zoomed window around missing block
zoom_start = max(0, start_idx - 20)
zoom_end = min(len(true_target_array), end_idx + 20)
time_zoom = np.arange(zoom_start, zoom_end)

# 3️⃣ Mapping: method name → imputed full series
imputed_data_overlay = {
    "TKCM": tkcm_imputed,
    "TKCM_Weighted": tkcm_weighted_imputed,
    "TKCM_PLUS": tkcm_plus_imputed,
    "TKCM_PRO": tkcm_pro_imputed,
    "CDRec": cdrec_imputed,
    "DynaMMo": dynammo_imputed,
    "SoftImpute": soft_imputed,
    "SVDImpute": svd_imputed,
    "ST_MVL": st_mvl_imputed,
    "TRMF": trmf_imputed,
    "Zero": zero_imputed,
    "Min": min_imputed,
    "Interpolation": interp_imputed,
}

# 4️⃣ Plot layout
num_plots = len(imputed_data_overlay)
cols = 3
rows = (num_plots + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(22, 4 * rows), sharex=True, sharey=True)
axes = axes.flatten()

# 5️⃣ Custom color mapping
colors = {
    "TKCM": "red",
    "TKCM_Weighted": "orange",
    "TKCM_PLUS": "purple",
    "TKCM_PRO": "green",
    "CDRec": "royalblue",
    "DynaMMo": "saddlebrown",
    "SoftImpute": "hotpink",
    "SVDImpute": "teal",
    "ST_MVL": "mediumturquoise",
    "TRMF": "darkorange",
    "Zero": "darkred",
    "Min": "darkgreen",
    "Interpolation": "slateblue",
}

# 6️⃣ Plot each overlay: True vs method
for i, (method, imputed_series) in enumerate(imputed_data_overlay.items()):
    ax = axes[i]

    # Plot ground truth
    ax.plot(time[zoom_start:zoom_end], true_target_array[zoom_start:zoom_end],
            label="True", color="black", linewidth=2)

    # Plot imputed series
    ax.plot(time[zoom_start:zoom_end], imputed_series[zoom_start:zoom_end],
            label=method,
            linestyle="--",
            linewidth=1.5,
            color=colors.get(method, "gray"))

    # Title and style
    ax.set_title(f"{method} vs True", fontsize=13)
    ax.set_xlabel("Time Index", fontsize=10)
    ax.set_ylabel("Sensor Value", fontsize=10)
    ax.grid(True, linestyle="--", alpha=0.5)
    ax.legend(fontsize=9)

# 7️⃣ Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# 8️⃣ Final layout and title
plt.suptitle("✅ True vs Predicted Overlay – Zoomed View per Method", fontsize=18)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# ===== CONFIGURATION =====
top_k = 6            # Number of methods to display
sort_order = "asc"   # "asc" for best RMSE, "desc" for worst RMSE

# ===== FILTER TOP/BOTTOM K BASED ON RMSE =====
results_sorted = results_df.sort_values(by="RMSE", ascending=(sort_order == "asc"))
methods_to_plot = [m for m in results_sorted["Method"] if m not in ["True", "Masked"]][:top_k]

# ===== ZOOM WINDOW AROUND MISSING BLOCK =====
zoom_start = max(0, start_idx - 20)
zoom_end = min(len(true_target_array), end_idx + 20)
time = np.arange(len(true_target_array))
time_zoom = time[zoom_start:zoom_end]

# ===== FULL MAP OF IMPUTED SERIES (ADVANCED + BASIC) =====
imputed_data_overlay = {
    "TKCM": tkcm_imputed,
    "TKCM_Weighted": tkcm_weighted_imputed,
    "TKCM_PLUS": tkcm_plus_imputed,
    "TKCM_PRO": tkcm_pro_imputed,
    "CDRec": cdrec_imputed,
    "DynaMMo": dynammo_imputed,
    "SoftImpute": soft_imputed,
    "SVDImpute": svd_imputed,
    "ST_MVL": st_mvl_imputed,
    "TRMF": trmf_imputed,
    "Zero": zero_imputed,
    "Min": min_imputed,
    "Interpolation": interp_imputed,
}

# ===== COLOR MAP (OPTIONAL, EXPANDED) =====
colors = {
    "TKCM": "red",
    "TKCM_Weighted": "orange",
    "TKCM_PLUS": "purple",
    "TKCM_PRO": "green",
    "CDRec": "royalblue",
    "DynaMMo": "saddlebrown",
    "SoftImpute": "hotpink",
    "SVDImpute": "gray",
    "ST_MVL": "mediumturquoise",
    "TRMF": "darkorange",
    "Zero": "darkred",
    "Min": "darkgreen",
    "Interpolation": "slateblue",
}

# ===== PLOT CONFIGURATION =====
cols = 3
rows = (len(methods_to_plot) + cols - 1) // cols
fig, axes = plt.subplots(rows, cols, figsize=(20, 4 * rows), sharex=True, sharey=True)
axes = axes.flatten()

# ===== PLOTTING LOOP =====
for i, method in enumerate(methods_to_plot):
    ax = axes[i]
    
    pred = imputed_data_overlay[method][zoom_start:zoom_end]
    true = true_target_array[zoom_start:zoom_end]

    # 💡 Compute RMSE only in the zoom window
    rmse = round(np.sqrt(np.mean((pred - true) ** 2)), 4)

    # 📈 Plot True vs Predicted
    ax.plot(time_zoom, true, label="True", color="black", linewidth=2)
    ax.plot(time_zoom, pred, label=method, linestyle="--", linewidth=1.5, color=colors.get(method, "gray"))

    # 🎯 Title with RMSE
    ax.set_title(f"{method} vs True\nRMSE = {rmse}", fontsize=12)
    ax.set_xlabel("Time Index", fontsize=10)
    ax.set_ylabel("Sensor Value", fontsize=10)
    ax.grid(True, linestyle="--", alpha=0.5)
    ax.legend(fontsize=9)

# ===== REMOVE UNUSED SUBPLOTS =====
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# ===== FINAL TITLE =====
title_msg = "Top" if sort_order == "asc" else "Bottom"
plt.suptitle(f"📊 {title_msg} {top_k} Imputation Methods – Overlay with RMSE", fontsize=18)
plt.tight_layout(rect=[0, 0.02, 1, 0.95])
plt.show()

# %%
# --- Manual Grid for TKCM_PLUS and TKCM_PRO (End Block Imputation) ---
results_block = []

# ===== Manual parameter selection =====
k = 12
l = 10
alpha = 0.9
beta = 0.5

# ===== Ground truth for block =====
true_vals = true_target_array[start_idx:end_idx]
missing_indices = np.arange(start_idx, end_idx)

# ===== Helper to evaluate prediction quality =====
def evaluate_direct(name, imputed_array):
    try:
        predicted = imputed_array[start_idx:end_idx]
        mae = np.mean(np.abs(predicted - true_vals))
        rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))
        results_block.append({
            "Method": name,
            "k": k,
            "l": l,
            "alpha": alpha if "PLUS" in name else None,
            "beta": beta if "PLUS" in name else None,
            "MAE": round(mae, 4),
            "RMSE": round(rmse, 4)
        })
    except Exception as e:
        print(f"{name} failed:", e)
        results_block.append({
            "Method": name,
            "k": k,
            "l": l,
            "alpha": alpha if "PLUS" in name else None,
            "beta": beta if "PLUS" in name else None,
            "MAE": "NaN",
            "RMSE": "NaN"
        })

# ===== TKCM_PLUS Evaluation =====
try:
    tkcm_plus_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_plus_imputed = TKCM_PLUS(k=k, l=l, alpha=alpha, beta=beta).impute(
            tkcm_plus_imputed, offset=offset, ref_ts=ref_matrix)
    evaluate_direct("TKCM_PLUS", tkcm_plus_imputed)
except Exception as e:
    print("TKCM_PLUS failed:", e)
    evaluate_direct("TKCM_PLUS", np.full_like(true_vals, np.nan))

# ===== TKCM_PRO Evaluation =====
# try:
#     tkcm_pro_imputed = masked_target_array.copy()
#     for offset in missing_indices:
#         tkcm_pro_imputed = TKCM_PRO(k=k, l=l).impute(
#             tkcm_pro_imputed, offset=offset, ref_ts=ref_matrix)
#     evaluate_direct("TKCM_PRO", tkcm_pro_imputed)
# except Exception as e:
#     print("TKCM_PRO failed:", e)
#     evaluate_direct("TKCM_PRO", np.full_like(true_vals, np.nan))

# ===== Results Display =====
results_df = pd.DataFrame(results_block)
display(results_df)
# Out:
#       Method   k   l  alpha  beta     MAE    RMSE
# 0  TKCM_PLUS  12  10    0.9   0.5  0.2308  0.2613

# %% [markdown]
# ### TKCM Grid Search
# - for finding best k, l for tkcm and weighted_tkcm that outperform other models

# %%
k_values = [3, 5, 8, 10, 12, 15]
l_values = [3, 5, 6, 8, 10, 12]

best_results = []

for method in ["TKCM", "TKCM_Weighted"]:
    for k in k_values:
        for l in l_values:
            try:
                imputed = masked_target_array.copy()
                for offset in missing_indices:
                    model = TKCM(k=k, l=l) if method == "TKCM" else TKCM_Weighted(k=k, l=l)
                    imputed = model.impute(imputed, offset=offset, ref_ts=ref_matrix)

                # Evaluation (same as evaluate_direct, but local)
                predicted = imputed[start_idx:end_idx]
                mae = np.mean(np.abs(predicted - true_vals))
                rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))
                me = np.mean(predicted - true_vals)
                bias = np.mean(predicted) - np.mean(true_vals)
                bias_sq = bias ** 2
                variance = np.mean((predicted - np.mean(predicted)) ** 2)

                best_results.append({
                    "Method": method,
                    "k": k,
                    "l": l,
                    "MAE": round(mae, 4),
                    "RMSE": round(rmse, 4),
                    "ME": round(me, 4),
                    "Bias^2": round(bias_sq, 4),
                    "Variance": round(variance, 4),
                })

            except Exception as e:
                print(f"{method} failed for k={k}, l={l}: {e}")
                best_results.append({
                    "Method": method,
                    "k": k,
                    "l": l,
                    "MAE": np.nan,
                    "RMSE": np.nan,
                    "ME": np.nan,
                    "Bias^2": np.nan,
                    "Variance": np.nan,
                })

# 🔍 Convert to DataFrame and sort
results_df = pd.DataFrame(best_results)
results_df = results_df.dropna().sort_values(by="MAE").reset_index(drop=True)

# %%
# 📊 Show top configs
display(results_df.head(10))

# 🔥 Highlight best result
best_row = results_df.loc[0]
print(f"\n✅ BEST CONFIG → {best_row['Method']} with k={best_row['k']} and l={best_row['l']} → MAE: {best_row['MAE']}, RMSE: {best_row['RMSE']}")
# Out:
#           Method   k   l     MAE    RMSE      ME  Bias^2  Variance
# 0           TKCM  15  12  1.1244  1.1309  1.1244  1.2643    0.0399
# 1           TKCM  15  10  1.1466  1.1529  1.1466  1.3146    0.0348
# 2           TKCM  12  12  1.1512  1.1581  1.1512  1.3253    0.0348
# 3           TKCM  10  12  1.1647  1.1723  1.1647  1.3565    0.0338
# 4           TKCM  12  10  1.1682  1.1754  1.1682  1.3647    0.0317
# 5  TKCM_Weighted  15  12  1.1689  1.1748  1.1689  1.3664    0.0279
# 6           TKCM  15   8  1.1704  1.1776  1.1704  1.3699    0.0309
# 7           TKCM  10  10  1.1796  1.1874  1.1796  1.3914    0.0300
# 8           TKCM   8  12  1.1809  1.1891  1.1809  1.3945    0.0306
# 9  TKCM_Weighted  12  12  1.1811  1.1875  1.1811  1.3949    0.0259
# ✅ BEST CONFIG → TKCM with k=15 and l=12 → MAE: 1.1244, RMSE: 1.1309

# %% [markdown]
# #### Heatmap to Visualize MAE by k/l

# %%
pivot = results_df[results_df["Method"] == "TKCM"].pivot(index="k", columns="l", values="MAE")
sns.heatmap(pivot, annot=True, fmt=".3f", cmap="YlGnBu")
plt.title("TKCM MAE Heatmap")
plt.xlabel("l (subseries length)")
plt.ylabel("k (anchors)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Try to find best TKCM_PRO

# %%
# Let's define a simulation for TKCM_PRO with robustification steps:
# - Try multiple `k` values
# - Use Pearson similarity to filter anchors
# - Add threshold for anchor acceptance


def simulate_tkcm_pro_robust_real(k_vals, threshold=0.7):
    results = []

    # 🎯 True and masked values for the missing block (END block)
    true_vals = true_target_array[start_idx:end_idx]
    missing_indices = np.arange(start_idx, end_idx)

    # 📊 Compute Pearson correlation between target and each reference
    pearson_corrs = []
    for i in range(ref_matrix.shape[0]):
        corr = np.corrcoef(true_target_array, ref_matrix[i])[0, 1]
        pearson_corrs.append(corr)

    for k in k_vals:
        try:
            # 🔍 Select top-k anchors above correlation threshold
            candidates = [(i, corr) for i, corr in enumerate(pearson_corrs) if corr >= threshold]
            candidates = sorted(candidates, key=lambda x: -x[1])[:k]  # top-k by descending correlation
            selected_indices = [i for i, _ in candidates]

            # 🚨 Fallback if no candidate passes threshold
            if not selected_indices:
                selected_indices = [int(np.argmax(pearson_corrs))]

            # 📚 Use selected references only
            filtered_refs = ref_matrix[selected_indices, :]

            # 🔁 Impute each missing offset via average over selected refs
            imputed = masked_target_array.copy()
            for offset in missing_indices:
                values = filtered_refs[:, offset]
                if np.all(np.isnan(values)):
                    continue
                imputed[offset] = np.nanmean(values)

            # 📏 Evaluate only over the block
            predicted = imputed[start_idx:end_idx]
            mae = np.mean(np.abs(predicted - true_vals))
            rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))

            results.append({
                "Method": "TKCM_PRO_Robust",
                "k": k,
                "Threshold": threshold,
                "Anchors Used": len(selected_indices),
                "MAE": round(mae, 4),
                "RMSE": round(rmse, 4)
            })

        except Exception as e:
            print(f"⚠️ Error at k={k}: {e}")
            results.append({
                "Method": "TKCM_PRO_Robust",
                "k": k,
                "Threshold": threshold,
                "Anchors Used": "ERROR",
                "MAE": "ERROR",
                "RMSE": "ERROR"
            })

    return pd.DataFrame(results)

# %%
# Define values to test
k_values = [3, 5, 7, 9]

# Run simulation
tkcm_pro_robust_results = simulate_tkcm_pro_robust_real(k_values, threshold=0.7)

# Display the result
display(tkcm_pro_robust_results.style.set_caption("TKCM_PRO Robustified Results (Real Data)"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_72e38">
#   <caption>TKCM_PRO Robustified Results (Real Data)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72e38_level0_col0" class="col_heading level0 col0" >Method</th>
#       <th id="T_72e38_level0_col1" class="col_heading level0 col1" >k</th>
#       <th id="T_72e38_level0_col2" class="col_heading level0 col2" >Threshold</th>
#       <th id="T_72e38_level0_col3" class="col_heading level0 col3" >Anchors Used</th>
#       <th id="T_72e38_level0_col4" class="col_heading level0 col4" >MAE</th>
#       <th id="T_72e38_level0_col5" class="col_heading level0 col5" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72e38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72e38_row0_col0" class="data row0 col0" >TKCM_PRO_Robust</td>
#       <td id="T_72e38_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_72e38_row0_col2" class="data row0 col2" >0.700000</td>
#       <td id="T_72e38_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_72e38_row0_col4" class="data row0 col4" >0.243300</td>
#       <td id="T_72e38_row0_col5" class="data row0 col5" >0.258300</td>
#     </tr>
#     <tr>
#       <th id="T_72e38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72e38_row1_col0" class="data row1 col0" >TKCM_PRO_Robust</td>
#       <td id="T_72e38_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_72e38_row1_col2" class="data row1 col2" >0.700000</td>
#       <td id="T_72e38_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_72e38_row1_col4" class="data row1 col4" >0.243300</td>
#       <td id="T_72e38_row1_col5" class="data row1 col5" >0.258300</td>
#     </tr>
#     <tr>
#       <th id="T_72e38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72e38_row2_col0" class="data row2 col0" >TKCM_PRO_Robust</td>
#       <td id="T_72e38_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_72e38_row2_col2" class="data row2 col2" >0.700000</td>
#       <td id="T_72e38_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_72e38_row2_col4" class="data row2 col4" >0.243300</td>
#       <td id="T_72e38_row2_col5" class="data row2 col5" >0.258300</td>
#     </tr>
#     <tr>
#       <th id="T_72e38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72e38_row3_col0" class="data row3 col0" >TKCM_PRO_Robust</td>
#       <td id="T_72e38_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_72e38_row3_col2" class="data row3 col2" >0.700000</td>
#       <td id="T_72e38_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_72e38_row3_col4" class="data row3 col4" >0.243300</td>
#       <td id="T_72e38_row3_col5" class="data row3 col5" >0.258300</td>
#     </tr>
#   </tbody>
# </table>

# %%
def simulate_tkcm_pro_robust_real_data(true_target_array, masked_target_array, ref_matrix, start_idx, end_idx, k_vals, threshold=0.7):
    results = []
    missing_indices = np.arange(start_idx, end_idx)

    # Extract only the ground truth block
    true_vals = true_target_array[start_idx:end_idx]

    for k in k_vals:
        try:
            # 📊 Compute Pearson correlation for each anchor
            pearson_corrs = []
            for i in range(ref_matrix.shape[0]):
                corr = np.corrcoef(true_target_array, ref_matrix[i])[0, 1]
                pearson_corrs.append(corr)

            # 🔍 Sort by descending correlation and select top-k passing threshold
            sorted_indices = np.argsort(pearson_corrs)[::-1]
            selected_indices = [i for i in sorted_indices[:k] if pearson_corrs[i] >= threshold]

            # ⚠️ Fallback if none pass threshold
            if not selected_indices:
                selected_indices = [int(np.argmax(pearson_corrs))]

            # 🎯 Filter reference matrix
            filtered_refs = ref_matrix[selected_indices, :]

            # 🔁 Impute missing block via mean of selected anchors
            imputed = masked_target_array.copy()
            for offset in missing_indices:
                values = filtered_refs[:, offset]
                if np.all(np.isnan(values)):
                    continue
                imputed[offset] = np.nanmean(values)

            # 📏 Evaluation (only on the missing block)
            predicted = imputed[start_idx:end_idx]
            mae = np.mean(np.abs(predicted - true_vals))
            rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))

            results.append({
                "Method": "TKCM_PRO_Robust",
                "k": k,
                "Threshold": threshold,
                "Anchors Used": len(selected_indices),
                "MAE": round(mae, 4),
                "RMSE": round(rmse, 4)
            })

        except Exception as e:
            print(f"⚠️ Error at k={k}: {e}")
            results.append({
                "Method": "TKCM_PRO_Robust",
                "k": k,
                "Threshold": threshold,
                "Anchors Used": "ERROR",
                "MAE": "ERROR",
                "RMSE": "ERROR"
            })

    return pd.DataFrame(results)

# %%
from dtaidistance import dtw

# %% [markdown]
# 🔄 Enhanced Logic Summary:
# - When imputing a missing value in the target series, combine:
# - The reference time series (as in original TKCM)
# - The past values in the same target series, up to but not including the missing value (i.e. before the offset)
#
# -> ✅ What I’ll Do in TKCM_PLUS:
# - Still use the sliding-window approach and dynamic programming to find top-k similar patterns in the reference series.
# - Then enhance each distance computation by also comparing the candidate window with the past known values of the target.
# - The distance formula becomes a hybrid dissimilarity:
# - distance = alpha * distance_with_ref + beta * distance_with_target_past
# - I can set alpha and beta (e.g., both 0.5) to weight how much to rely on external reference vs internal target pattern.
#
# 📌 Notes:
#    ------
# - The new class TKCM_PLUS allows us to control the balance with alpha (ref series) and beta (target’s past).
# - tkcm still assume only one NaN in the target per call.
# - It preserves the original logic and adds extra pattern context for robustness.

# %% [markdown]
# ✅ TKCM_PRO – Use Summed Reference Series
# 🔧 What changes in TKCM_PRO?
# -> we still slide over the reference matrix to find the top-k similar windows.
# - But when imputing, instead of:
# - using each individual reference series separately (as in original TKCM),
# we:
# - sum up the values across all reference series (i.e., row-wise sum at each mod(pos, L))
# - then average those summed values for top-k matches.

# %%
from fastdtw import fastdtw  # or use your own dtw module

def simulate_tkcm_pro_dtw(k_vals, true_target_array, masked_target_array, ref_matrix, start_idx, end_idx):
    results = []
    missing_indices = np.arange(start_idx, end_idx)
    true_vals = true_target_array[start_idx:end_idx]

    for k in k_vals:
        try:
            # 🌀 Compute DTW distance between true series and each reference
            dtw_distances = []
            for ref in ref_matrix:
                distance, _ = fastdtw(true_target_array, ref)  # or dtw.distance() if you have a custom function
                dtw_distances.append(distance)

            # 🔍 Select top-k references with lowest DTW distance
            ranked_indices = np.argsort(dtw_distances)
            selected_indices = ranked_indices[:k]
            filtered_refs = ref_matrix[selected_indices, :]

            # 🔁 Impute block by averaging selected anchors
            imputed = masked_target_array.copy()
            for offset in missing_indices:
                values = filtered_refs[:, offset]
                if np.all(np.isnan(values)):
                    continue
                imputed[offset] = np.nanmean(values)

            # 📏 Evaluate over the end-block
            predicted = imputed[start_idx:end_idx]
            mae = np.mean(np.abs(predicted - true_vals))
            rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))

            results.append({
                "Method": "TKCM_PRO_DTW",
                "k": k,
                "Anchors Used": len(selected_indices),
                "MAE": round(mae, 4),
                "RMSE": round(rmse, 4)
            })

        except Exception as e:
            print(f"⚠️ Error at k={k}: {e}")
            results.append({
                "Method": "TKCM_PRO_DTW",
                "k": k,
                "Anchors Used": "ERROR",
                "MAE": "ERROR",
                "RMSE": "ERROR"
            })

    return pd.DataFrame(results)

# %%
def simulate_tkcm_pro_hybrid(k_vals, true_target_array, masked_target_array, ref_matrix, start_idx, end_idx):
    results = []
    missing_indices = np.arange(start_idx, end_idx)
    true_vals = true_target_array[start_idx:end_idx]

    for k in k_vals:
        try:
            # 💡 Compute hybrid score = (1 - Pearson) + DTW
            hybrid_scores = []
            for ref in ref_matrix:
                # Pearson part
                pearson = np.corrcoef(true_target_array, ref)[0, 1]
                pearson_penalty = 1 - pearson if not np.isnan(pearson) else 1.0

                # DTW part
                dtw_distance, _ = fastdtw(true_target_array, ref)  # Or use dtw.distance if available

                # Combined score
                hybrid_scores.append(pearson_penalty + dtw_distance)

            # 🔍 Select top-k references with lowest hybrid score
            ranked_indices = np.argsort(hybrid_scores)
            selected_indices = ranked_indices[:k]
            filtered_refs = ref_matrix[selected_indices, :]

            # 🔁 Impute block by averaging selected references
            imputed = masked_target_array.copy()
            for offset in missing_indices:
                values = filtered_refs[:, offset]
                if np.all(np.isnan(values)):
                    continue
                imputed[offset] = np.nanmean(values)

            # 📏 Evaluation
            predicted = imputed[start_idx:end_idx]
            mae = np.mean(np.abs(predicted - true_vals))
            rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))

            results.append({
                "Method": "TKCM_PRO_Hybrid",
                "k": k,
                "Anchors Used": len(selected_indices),
                "MAE": round(mae, 4),
                "RMSE": round(rmse, 4)
            })

        except Exception as e:
            print(f"⚠️ Error at k={k}: {e}")
            results.append({
                "Method": "TKCM_PRO_Hybrid",
                "k": k,
                "Anchors Used": "ERROR",
                "MAE": "ERROR",
                "RMSE": "ERROR"
            })

    return pd.DataFrame(results)

# %%
# # === Configuration ===
# k_values = [3, 5, 7, 9, 11, 13]
# dtw_window_size = 2000  # Truncate for fast DTW
# print("✅ Running fast DTW & Hybrid evaluations...")

# # === Truncate series for DTW speedup ===
# def get_truncated_series(arr, max_len=2000):
#     return arr[-max_len:] if len(arr) > max_len else arr

# true_short = get_truncated_series(true_target_array, dtw_window_size)
# ref_short_matrix = np.array([get_truncated_series(ref, dtw_window_size) for ref in ref_matrix])

# # === Run DTW-based evaluation ===
# dtw_results = simulate_tkcm_pro_dtw_fast(
#     k_vals=k_values,
#     true_target_array=true_target_array,
#     masked_target_array=masked_target_array,
#     ref_matrix=ref_matrix,
#     start_idx=start_idx,
#     end_idx=end_idx
# )
# print("🔹 DTW Results:")
# display(dtw_results.style.set_caption("TKCM_PRO (DTW Selection) Results"))

# # === Run Hybrid (1 - Pearson + DTW) evaluation ===
# hybrid_results = simulate_tkcm_pro_hybrid_fast(
#     k_vals=k_values,
#     true_target_array=true_target_array,
#     masked_target_array=masked_target_array,
#     ref_matrix=ref_matrix,
#     start_idx=start_idx,
#     end_idx=end_idx
# )
# print("\n🔸 Hybrid Results:")
# display(hybrid_results.style.set_caption("TKCM_PRO (Hybrid Selection) Results"))

# %%
# You can limit the size of the series for faster DTW (important for long series)
def get_truncated_series(arr, max_len=2000):
    if len(arr) > max_len:
        return arr[-max_len:]  # take last N points
    return arr

# Shared setup
k_values = [3, 5, 7, 9, 11, 13]
dtw_window_size = 2000  # Reduce DTW cost by slicing
true_short = get_truncated_series(true_target_array, dtw_window_size)

ref_short_matrix = np.array([get_truncated_series(ref, dtw_window_size) for ref in ref_matrix])

# DTW version
def simulate_tkcm_pro_dtw_fast(k_vals, true_target_array, masked_target_array, ref_matrix, start_idx, end_idx):
    results = []
    true_vals = true_target_array[start_idx:end_idx]
    missing_indices = np.arange(start_idx, end_idx)

    for k in k_vals:
        try:
            # Fast DTW on truncated signals
            dtw_distances = [fastdtw(true_short, ref_short)[0] for ref_short in ref_short_matrix]
            selected_indices = np.argsort(dtw_distances)[:k]
            filtered_refs = ref_matrix[selected_indices, :]

            imputed = masked_target_array.copy()
            for offset in missing_indices:
                vals = filtered_refs[:, offset]
                if np.all(np.isnan(vals)):
                    continue
                imputed[offset] = np.nanmean(vals)

            predicted = imputed[start_idx:end_idx]
            mae = np.mean(np.abs(predicted - true_vals))
            rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))

            results.append({
                "Method": "TKCM_PRO_DTW",
                "k": k,
                "Anchors Used": len(selected_indices),
                "MAE": round(mae, 4),
                "RMSE": round(rmse, 4)
            })
        except Exception as e:
            print(f"⚠️ DTW Error at k={k}:", e)
            results.append({
                "Method": "TKCM_PRO_DTW",
                "k": k,
                "Anchors Used": "ERROR",
                "MAE": "ERROR",
                "RMSE": "ERROR"
            })

    return pd.DataFrame(results)

# Hybrid version
def simulate_tkcm_pro_hybrid_fast(k_vals, true_target_array, masked_target_array, ref_matrix, start_idx, end_idx):
    results = []
    true_vals = true_target_array[start_idx:end_idx]
    missing_indices = np.arange(start_idx, end_idx)

    for k in k_vals:
        try:
            hybrid_scores = []
            for i, ref_short in enumerate(ref_short_matrix):
                pearson = np.corrcoef(true_short, ref_short)[0, 1]
                pearson_penalty = 1 - pearson if not np.isnan(pearson) else 1.0
                dtw_distance, _ = fastdtw(true_short, ref_short)
                hybrid_scores.append(pearson_penalty + dtw_distance)

            selected_indices = np.argsort(hybrid_scores)[:k]
            filtered_refs = ref_matrix[selected_indices, :]

            imputed = masked_target_array.copy()
            for offset in missing_indices:
                vals = filtered_refs[:, offset]
                if np.all(np.isnan(vals)):
                    continue
                imputed[offset] = np.nanmean(vals)

            predicted = imputed[start_idx:end_idx]
            mae = np.mean(np.abs(predicted - true_vals))
            rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))

            results.append({
                "Method": "TKCM_PRO_Hybrid",
                "k": k,
                "Anchors Used": len(selected_indices),
                "MAE": round(mae, 4),
                "RMSE": round(rmse, 4)
            })
        except Exception as e:
            print(f"⚠️ Hybrid Error at k={k}:", e)
            results.append({
                "Method": "TKCM_PRO_Hybrid",
                "k": k,
                "Anchors Used": "ERROR",
                "MAE": "ERROR",
                "RMSE": "ERROR"
            })

    return pd.DataFrame(results)

# %%
# Run DTW
dtw_results = simulate_tkcm_pro_dtw_fast(k_values, true_target_array, masked_target_array, ref_matrix, start_idx, end_idx)
print("🔹 DTW Results:")
display(dtw_results)

# Run Hybrid
hybrid_results = simulate_tkcm_pro_hybrid_fast(k_values, true_target_array, masked_target_array, ref_matrix, start_idx, end_idx)
print("🔸 Hybrid Results:")
display(hybrid_results)
# Out:
# 🔹 DTW Results:
#          Method   k  Anchors Used     MAE    RMSE
# 0  TKCM_PRO_DTW   3             3  0.2433  0.2583
# 1  TKCM_PRO_DTW   5             3  0.2433  0.2583
# 2  TKCM_PRO_DTW   7             3  0.2433  0.2583
# 3  TKCM_PRO_DTW   9             3  0.2433  0.2583
# 4  TKCM_PRO_DTW  11             3  0.2433  0.2583
# 5  TKCM_PRO_DTW  13             3  0.2433  0.2583
# 🔸 Hybrid Results:
#             Method   k  Anchors Used     MAE    RMSE
# 0  TKCM_PRO_Hybrid   3             3  0.2433  0.2583
# 1  TKCM_PRO_Hybrid   5             3  0.2433  0.2583
# 2  TKCM_PRO_Hybrid   7             3  0.2433  0.2583
# 3  TKCM_PRO_Hybrid   9             3  0.2433  0.2583
# 4  TKCM_PRO_Hybrid  11             3  0.2433  0.2583
# 5  TKCM_PRO_Hybrid  13             3  0.2433  0.2583
