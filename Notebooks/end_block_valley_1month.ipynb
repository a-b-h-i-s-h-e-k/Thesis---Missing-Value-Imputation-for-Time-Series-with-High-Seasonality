# %% [markdown]
# ### Enable importing modules from the parent project directory

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))  # Adds project root

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd  # Data manipulation and DataFrame support
import numpy as np  # Numerical computing with arrays
import math  # Basic mathematical functions
import matplotlib.pyplot as plt  # Plotting and visualization
from sklearn.metrics import mean_squared_error, mean_absolute_error  # Evaluation metrics
from statistics import mode  # Compute statistical mode
import folium  # Interactive maps (leaflet.js-based)
from folium.plugins import MarkerCluster  # Cluster markers on maps
from scipy.stats import pearsonr  # Pearson correlation calculation
from sklearn.preprocessing import StandardScaler  # Z-score normalization
from sklearn.preprocessing import MinMaxScaler  # Scale features to 0–1 range
from tqdm import tqdm  # Progress bars for loops
from prophet import Prophet  # Facebook Prophet time series forecasting
import random  # Random number generation
from sklearn.impute import SimpleImputer  # Basic missing value imputation
from typing import Dict  # Type hinting for dictionaries
import seaborn as sns  # Statistical data visualization
from sklearn.impute import SimpleImputer  # (Duplicate) Basic imputation again
from IPython.display import display, HTML  # Pretty HTML display in notebooks
from sklearn.decomposition import PCA  # Principal Component Analysis (dimensionality reduction)
from sklearn.preprocessing import StandardScaler  # (Duplicate) Z-score scaling
from statsmodels.tsa.holtwinters import ExponentialSmoothing  # Time series smoothing & forecasting
from sklearn.ensemble import RandomForestRegressor  # Random Forest for regression tasks
from sklearn.inspection import permutation_importance  # Feature importance via permutation
import warnings  # Control warning messages
warnings.filterwarnings("ignore")  # Suppress warnings (useful in notebooks)
from prophet.plot import plot_plotly, plot_components_plotly  # Plotting Prophet results
from prophet.diagnostics import cross_validation, performance_metrics  # Prophet diagnostics tools

# %%
from typing import List, Tuple  # Type hinting for lists and tuples

from Algorithms.CDREC import CDRec  # Collaborative Denoising for matrix completion
from Algorithms.TKCM import TKCM  # Top-k Case Matching (basic version)
from Algorithms.TKCM_Weighted import TKCM_Weighted  # TKCM with similarity-based weighting
from Algorithms.DynaMMO import DynaMMo  # Dynamic Matrix Modeling for time series imputation
from Algorithms.SoftImpute import SoftImpute  # Low-rank matrix completion using soft-thresholding
from Algorithms.SVDImpute import IterativeSVD  # Iterative SVD-based matrix imputation
from Algorithms.trmf import TRMFImputer  # Temporal Regularized Matrix Factorization
from Algorithms.ST_MVL import ST_MVL  # Space-Time Matrix-Vector Learning
from Algorithms.TKCM_PLUS import TKCM_PLUS  # TKCM variant with alpha–beta blending, also using Target series known values to fill the missing values
from Algorithms.TKCM_PRO import TKCM_PRO  # Pro version of TKCM with anchor filtering, here averaging the refrence to fill the missing values

# %% [markdown]
# ### Loading the Dataset

# %%
valley_df = pd.read_csv("D:\\Thesis\\Project\\Data\\valley_data.csv")

# Counting the different types of missingness in the dataset
stats = {
    "Total Rows": len(valley_df),
    "Total Columns": len(valley_df.columns),
    "Zero Values": (valley_df == 0).sum().sum(),
    "NaN Values": valley_df.isna().sum().sum(),
    "Blank Strings": (valley_df == "").sum().sum(),
    "Unknown Strings": (valley_df.applymap(lambda x: isinstance(x, str) and x.strip().lower() == "unknown")).sum().sum()
}

# Return as DataFrame
stats_df = pd.DataFrame(list(stats.items()), columns=["Metric", "Value"])
stats_df
# Out:
#             Metric    Value
# 0       Total Rows  7079427
# 1    Total Columns        6
# 2      Zero Values  1667902
# 3       NaN Values        0
# 4    Blank Strings        0
# 5  Unknown Strings        0

# %% [markdown]
# #### Displaying the first 5 rows of the data

# %%
valley_df.head()
# Out:
#   station_code sensor_code         description_it unit            timestamp  \
# 0      37100MS          LT  Temperatura dell´aria   °C  2025-01-01 00:00:00
# 1      37100MS          LT  Temperatura dell´aria   °C  2024-12-31 23:30:00
# 2      37100MS          LT  Temperatura dell´aria   °C  2024-12-31 23:00:00
# 3      37100MS          LT  Temperatura dell´aria   °C  2024-12-31 22:30:00
# 4      37100MS          LT  Temperatura dell´aria   °C  2024-12-31 22:00:00
#
#    value
# 0  -10.4
# 1   -8.9
# 2   -9.5
# 3   -8.1
# 4   -8.8

# %% [markdown]
# ### Displaying column-wise metadata

# %%
valley_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7079427 entries, 0 to 7079426
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   station_code    object
#  1   sensor_code     object
#  2   description_it  object
#  3   unit            object
#  4   timestamp       object
#  5   value           float64
# dtypes: float64(1), object(5)
# memory usage: 324.1+ MB

# %% [markdown]
# ### describe() provide us with statistical summary of numeric columns

# %%
valley_df.describe()
# Out:
#               value
# count  7.079427e+06
# mean   1.722966e+02
# std    3.336668e+02
# min   -9.760000e+01
# 25%    0.000000e+00
# 50%    3.600000e+00
# 75%    1.000000e+02
# max    1.474800e+03

# %%
# Preview data
print("🔍 Shape:", valley_df.shape)
# Out:
# 🔍 Shape: (7079427, 6)

# %%
# Check which columns are non-numeric
print("🧠 Columns in the file:\n", valley_df.dtypes)
# Out:
# 🧠 Columns in the file:
#  station_code       object
# sensor_code        object
# description_it     object
# unit               object
# timestamp          object
# value             float64
# dtype: object

# %% [markdown]
# ### Checking all the unique sensor codes i have in this dataset

# %%
unique_values = valley_df['sensor_code'].unique()
unique_values
# Out:
# array(['LT', 'N', 'WR', 'WG', 'WG.BOE', 'LF', 'LD.RED', 'GS', 'SD', 'HS',
#        'W', 'WT'], dtype=object)

# %% [markdown]
# ### checking unique similar station_codes

# %%
unique_values1 = valley_df['station_code'].unique()
unique_values1
# Out:
# array(['37100MS', '20500MS', '19300MS', '80300MS', '50500MS', '34500MS',
#        '56900MS', '54500MS', '69900MS', '09700MS', '82200MS', '88820MS',
#        '59700MS', '85120MS', '83200MS', '86900MS', '39100MS', '08200MS',
#        '23200MS', '47400MS', '86600MS', '37700MS', '74900MS', '89190MS',
#        '22210MS', '25900MS', '73500MS', '68600MS', '02200MS', '03100MS',
#        '41000MS', '75600MS', '62600MS', '74200MS', '11400MS', '02500MS',
#        '33500MS', '44500MS', '06400MS', '65600MS', '24400MS', '43200MS',
#        '78305MS', '56500MS', '42700MS', '15800MS', '65350MS', '89950SE',
#        '02250SE', '78150SE', '82910MS', '47150SE', '27100MS', '89155SE',
#        '89355SE', '85700MS', '89055SE', '42150SE', '39050SE', '79450SE',
#        '87300MS', '66500MS', '20910MS', '31410MS', '78110MS', '61300MS',
#        '01110MS', '71510MS', '79300MS', '75510SE', '90150SE', '91510MS'],
#       dtype=object)

# %% [markdown]
# ### Looking at the descriptions of the sensor what is meaning of those sensor codes

# %%
unique_values2 = valley_df['description_it'].unique()
unique_values2
# Out:
# array(['Temperatura dell´aria', 'Precipitazioni', 'Direzione del vento',
#        'Velocità del vento', 'Velocitá raffica', 'Umidità relativa',
#        'Pressione atmosferica', 'Radiazione globale ',
#        'Durata soleggiamento', 'Altezza neve al suolo',
#        'Livello idrometrico', 'Temperatura acqua'], dtype=object)

# %% [markdown]
# ### checking unit of data values

# %%
unique_values3 = valley_df['unit'].unique()
unique_values3
# Out:
# array(['°C', 'mm', '° ', 'm/s', '%', 'hPa', 'W/m²', 's', 'cm'],
#       dtype=object)

# %% [markdown]
# ### looking at unique values

# %%
unique_values4 = valley_df['value'].unique()
unique_values4
# Out:
# array([-10.4,  -8.9,  -9.5, ..., 981.9, 855.3, 802.7], shape=(11245,))

# %% [markdown]
# ### Checking the columns i have and how they pronounced

# %%
column_names = list(valley_df.columns)
column_names
# Out:
# ['station_code', 'sensor_code', 'description_it', 'unit', 'timestamp', 'value']

# %% [markdown]
# ### counting the zeroes and sum them

# %%
zero_counts = (valley_df == 0).sum()
print(zero_counts)
# Out:
# station_code            0
# sensor_code             0
# description_it          0
# unit                    0
# timestamp               0
# value             1667902
# dtype: int64

# %% [markdown]
# ### displaying the values with zeroes

# %%
valley_df[valley_df["value"] == 0].head()
# Out:
#     station_code sensor_code         description_it unit            timestamp  \
# 116      37100MS          LT  Temperatura dell´aria   °C  2024-12-29 14:00:00
# 338      37100MS          LT  Temperatura dell´aria   °C  2024-12-24 23:00:00
# 426      37100MS          LT  Temperatura dell´aria   °C  2024-12-23 03:00:00
# 598      37100MS          LT  Temperatura dell´aria   °C  2024-12-19 13:00:00
# 637      37100MS          LT  Temperatura dell´aria   °C  2024-12-18 17:30:00
#
#      value
# 116    0.0
# 338    0.0
# 426    0.0
# 598    0.0
# 637    0.0

# %% [markdown]
# #### checking if values are numeric, if yes then add percentage to the zeroes and sort them by percentage of zero they contain.

# %%
# Make sure 'value' is numeric
valley_df['value'] = pd.to_numeric(valley_df['value'], errors='coerce')

# Group by sensor_code
zero_stats = (
    valley_df.groupby('sensor_code')
    .agg(
        total_entries=('value', 'count'),
        zero_count=('value', lambda x: (x == 0).sum())
    )
)

# Add percentage of zeros
zero_stats['zero_percentage'] = (zero_stats['zero_count'] / zero_stats['total_entries']) * 100

# Sort by percentage of zero values
zero_stats = zero_stats.sort_values(by='zero_percentage', ascending=False)

print(zero_stats.reset_index())
# Out:
#    sensor_code  total_entries  zero_count  zero_percentage
# 0            N         585918      565938        96.589967
# 1           SD         773271      643102        83.166445
# 2           GS         758400      438331        57.796809
# 3            W          83263        5222         6.271693
# 4           LT         889920        7619         0.856144
# 5           WG         713371        4772         0.668937
# 6           HS          29182         170         0.582551
# 7       WG.BOE         713371        2423         0.339655
# 8           WT          83262          60         0.072062
# 9           WR         713371         265         0.037148
# 10          LF         875328           0         0.000000
# 11      LD.RED         860770           0         0.000000

# %%
# Step 1: Select sensor `LF`
lf_df = valley_df[valley_df['sensor_code'] == 'LF'].copy()

# %%
# Step 2: Replace `0.0` values with NaN
lf_df.loc[lf_df['value'] == 0.0, 'value'] = np.nan

# %%
# Step 3: Pivot to wide format (timestamp × station_code)
lf_df['timestamp'] = pd.to_datetime(lf_df['timestamp'])
pivot_df = lf_df.pivot(index='timestamp', columns='station_code', values='value')

# %%
# Step 4: Drop sparse stations (>10% missing)
threshold = 0.9 * len(pivot_df)
pivot_df = pivot_df.dropna(thresh=threshold, axis=1)

# %%
# Step 5: Drop rows with any missing values
clean_df = pivot_df.dropna(axis=0)

# %% [markdown]
# #### Displaying the clean dataframe to check what i have with me.

# %%
clean_df
# Out:
# station_code         01110MS  02200MS  02500MS  03100MS  06400MS  08200MS  \
# timestamp
# 2023-01-01 00:00:00     99.1     90.4     82.5     86.2     94.8     99.8
# 2023-01-01 00:30:00     98.1     90.8     80.8     84.9     97.1     99.8
# 2023-01-01 01:00:00     98.0     91.5     81.9     83.5     96.7     99.8
# 2023-01-01 01:30:00     99.7     92.6     81.1     85.3     97.7     99.8
# 2023-01-01 02:00:00     99.8     94.2     81.9     84.5     95.4     99.8
# ...                      ...      ...      ...      ...      ...      ...
# 2024-12-31 22:00:00     54.5     74.4     38.3     53.7     48.4     91.3
# 2024-12-31 22:30:00     54.7     75.9     41.8     56.0     46.0     91.3
# 2024-12-31 23:00:00     54.7     77.3     39.0     55.8     46.4     92.2
# 2024-12-31 23:30:00     53.8     78.7     40.1     56.7     50.2     91.5
# 2025-01-01 00:00:00     56.7     79.3     43.5     56.6     46.2     92.7
#
# station_code         09700MS  11400MS  15800MS  19300MS  ...  82910MS  \
# timestamp                                                ...
# 2023-01-01 00:00:00     92.7     91.6     91.9     90.6  ...     93.8
# 2023-01-01 00:30:00     91.1     92.1     92.7     91.7  ...     91.8
# 2023-01-01 01:00:00     90.0     89.1     92.4     90.1  ...     92.1
# 2023-01-01 01:30:00     89.4     88.5     93.3     89.2  ...     95.1
# 2023-01-01 02:00:00     88.2     86.2     94.2     89.1  ...     98.6
# ...                      ...      ...      ...      ...  ...      ...
# 2024-12-31 22:00:00     64.9     51.1     49.7     89.4  ...     84.0
# 2024-12-31 22:30:00     67.3     51.9     50.2     90.5  ...     84.5
# 2024-12-31 23:00:00     64.2     51.1     51.0     90.4  ...     85.7
# 2024-12-31 23:30:00     69.7     51.6     51.0     92.0  ...     86.8
# 2025-01-01 00:00:00     70.1     51.6     47.8     91.4  ...     86.4
#
# station_code         83200MS  85120MS  85700MS  86600MS  86900MS  87300MS  \
# timestamp
# 2023-01-01 00:00:00     87.7     99.9     96.8     95.8     98.1     97.6
# 2023-01-01 00:30:00     87.0     99.9     97.7     94.5     97.0     97.5
# 2023-01-01 01:00:00     85.3     99.9     97.1     93.5     98.5     99.7
# 2023-01-01 01:30:00     84.2     99.9     98.8     92.5     99.2     96.4
# 2023-01-01 02:00:00     88.4     99.9     99.6     94.5     99.0     99.9
# ...                      ...      ...      ...      ...      ...      ...
# 2024-12-31 22:00:00     90.2     47.1    100.2     99.6     98.7     53.8
# 2024-12-31 22:30:00     88.9     48.7    100.2     99.1    100.0     54.0
# 2024-12-31 23:00:00     89.0     48.4     99.7     99.7    100.0     57.7
# 2024-12-31 23:30:00     88.1     48.3    100.2    100.0    100.0     53.5
# 2025-01-01 00:00:00     91.1     49.5     99.7     99.7    100.0     54.1
#
# station_code         88820MS  89190MS  91510MS
# timestamp
# 2023-01-01 00:00:00     83.5     84.3     99.9
# 2023-01-01 00:30:00     82.7     84.3     99.9
# 2023-01-01 01:00:00     89.8     81.3     99.9
# 2023-01-01 01:30:00     90.6     83.9     99.9
# 2023-01-01 02:00:00     90.0     80.9     99.9
# ...                      ...      ...      ...
# 2024-12-31 22:00:00     95.8     64.1     96.9
# 2024-12-31 22:30:00     99.0     61.4     96.0
# 2024-12-31 23:00:00     96.6     63.5     96.1
# 2024-12-31 23:30:00     93.9     62.9     97.0
# 2025-01-01 00:00:00     99.9     57.5     98.0
#
# [14457 rows x 60 columns]

# %%
# Step 6: Pick a target station
target_station = clean_df.columns[2]

# %% [markdown]
# #### displaying target station

# %%
target_station
# Out:
# '02500MS'

# %%
# Step 7: Compute Pearson correlations 
correlations = clean_df.corr()[target_station].drop(index=target_station).sort_values(ascending=False)

# %% [markdown]
# ### displaying correlations

# %%
correlations
# Out:
# station_code
# 15800MS    0.860133
# 03100MS    0.856343
# 06400MS    0.820458
# 20910MS    0.815276
# 24400MS    0.812125
# 71510MS    0.806599
# 68600MS    0.800845
# 01110MS    0.791615
# 20500MS    0.790726
# 11400MS    0.787193
# 65600MS    0.757288
# 02200MS    0.756943
# 87300MS    0.755742
# 85120MS    0.755661
# 78110MS    0.751061
# 79300MS    0.736962
# 34500MS    0.730753
# 75600MS    0.725095
# 74200MS    0.723658
# 73500MS    0.720382
# 66500MS    0.720341
# 25900MS    0.701794
# 89190MS    0.688170
# 82200MS    0.681692
# 44500MS    0.661228
# 47400MS    0.660803
# 78305MS    0.656539
# 82910MS    0.645984
# 69900MS    0.640392
# 50500MS    0.635309
# 09700MS    0.633138
# 54500MS    0.627258
# 61300MS    0.615036
# 80300MS    0.614604
# 37700MS    0.610875
# 08200MS    0.609098
# 22210MS    0.560592
# 31410MS    0.544317
# 42700MS    0.535828
# 37100MS    0.530221
# 83200MS    0.519141
# 62600MS    0.510519
# 74900MS    0.487708
# 19300MS    0.482003
# 23200MS    0.477953
# 39100MS    0.473874
# 88820MS    0.465987
# 86900MS    0.454714
# 41000MS    0.453751
# 56500MS    0.453069
# 33500MS    0.448209
# 85700MS    0.428693
# 27100MS    0.418963
# 86600MS    0.416998
# 91510MS    0.414266
# 43200MS    0.382961
# 56900MS    0.377842
# 59700MS    0.372126
# 65350MS    0.287156
# Name: 02500MS, dtype: float64

# %% [markdown]
# ### Plotting the correlation of target series with refrence series

# %%
plt.figure(figsize=(10, 14))
correlations.sort_values().plot(kind='barh', color='skyblue', edgecolor='black')

plt.axvline(x=0, color='gray', linestyle='--', linewidth=1)
plt.title("📈 Pearson Correlation with Target Station '02500MS'")
plt.xlabel("Correlation Coefficient")
plt.ylabel("Station Code")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Step 8: Select top 2 correlated reference stations
top_refs = correlations.head(2).index.tolist()
final_df = clean_df[[target_station] + top_refs].copy()

# %%
top_refs
# Out:
# ['15800MS', '03100MS']

# %% [markdown]
# #### Checking the final dataframe

# %%
final_df
# Out:
# station_code         02500MS  15800MS  03100MS
# timestamp
# 2023-01-01 00:00:00     82.5     91.9     86.2
# 2023-01-01 00:30:00     80.8     92.7     84.9
# 2023-01-01 01:00:00     81.9     92.4     83.5
# 2023-01-01 01:30:00     81.1     93.3     85.3
# 2023-01-01 02:00:00     81.9     94.2     84.5
# ...                      ...      ...      ...
# 2024-12-31 22:00:00     38.3     49.7     53.7
# 2024-12-31 22:30:00     41.8     50.2     56.0
# 2024-12-31 23:00:00     39.0     51.0     55.8
# 2024-12-31 23:30:00     40.1     51.0     56.7
# 2025-01-01 00:00:00     43.5     47.8     56.6
#
# [14457 rows x 3 columns]

# %%
# Step 8: Build new DataFrame with target and top 3 references
top_3_refs = correlations.dropna().sort_values(ascending=False).head(3).index.tolist()
selected_stations = [target_station] + top_3_refs
pattern_df = pivot_df[selected_stations].copy()

# %%
pattern_df
# Out:
# station_code         02500MS  15800MS  03100MS  06400MS
# timestamp
# 2023-01-01 00:00:00     82.5     91.9     86.2     94.8
# 2023-01-01 00:30:00     80.8     92.7     84.9     97.1
# 2023-01-01 01:00:00     81.9     92.4     83.5     96.7
# 2023-01-01 01:30:00     81.1     93.3     85.3     97.7
# 2023-01-01 02:00:00     81.9     94.2     84.5     95.4
# ...                      ...      ...      ...      ...
# 2024-12-31 22:00:00     38.3     49.7     53.7     48.4
# 2024-12-31 22:30:00     41.8     50.2     56.0     46.0
# 2024-12-31 23:00:00     39.0     51.0     55.8     46.4
# 2024-12-31 23:30:00     40.1     51.0     56.7     50.2
# 2025-01-01 00:00:00     43.5     47.8     56.6     46.2
#
# [14593 rows x 4 columns]

# %% [markdown]
# #### Plotting target station with reference stations

# %%
# Define the stations 
target = "02500MS"
references = ["15800MS","03100MS","06400MS"]

# Define time range for plot (e.g., Jan 1 to Jan 4, 2023)
start_time = "2023-01-01"
end_time = "2023-01-04"

# Slicing the DataFrame
plot_df = pattern_df[[target] + references].loc[start_time:end_time].copy()

# Plotting
plt.figure(figsize=(14, 6))

# Plot reference series
for ref in references:
    plt.plot(plot_df.index, plot_df[ref], linestyle='--', label=f"Ref: {ref}")

# Plot target series
plt.plot(plot_df.index, plot_df[target], color='blue', linewidth=2, label=f"Target: {target}")

plt.xlabel("Time")
plt.ylabel("Raw Sensor Value")
plt.title("📍 Target & Top 3 References (No Mask, No Normalization)")
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # -------------------------------------------
# # 🔹 STEP 1: Normalizing the Time Series Data
# # -------------------------------------------

# %%
from sklearn.preprocessing import StandardScaler

#  Initialize the Scaler
scaler = StandardScaler()

#  Fit the scaler on the full pattern_df and transform it
normalized_array = scaler.fit_transform(pattern_df)

#  Reconstruct a DataFrame with the same shape, columns, and index
normalized_df = pd.DataFrame(
    normalized_array,
    columns=pattern_df.columns,
    index=pattern_df.index
)

# 4️⃣ Print shape and preview
print(" Normalized shape:", normalized_df.shape)
display(normalized_df.head())
# Out:
#  Normalized shape: (14593, 4)
# station_code          02500MS   15800MS   03100MS   06400MS
# timestamp
# 2023-01-01 00:00:00  1.119923  1.189939  0.666856  1.250501
# 2023-01-01 00:30:00  1.038581  1.225965  0.609234  1.356561
# 2023-01-01 01:00:00  1.091214  1.212455  0.547179  1.338115
# 2023-01-01 01:30:00  1.052935  1.252984  0.626964  1.384229
# 2023-01-01 02:00:00  1.091214  1.293513  0.591504  1.278168

# %% [markdown]
# # ---------------------------------------------------------
# # 🔹 STEP 2: Defining function to the inject block-missing in the end
# # ---------------------------------------------------------

# %%
def introduce_block_missing_end(series: pd.Series, block_length: int) -> Tuple[pd.Series, int, int]:
    """
    Introduce a block of NaN values at the end of a time series.

    Parameters:
        series (pd.Series): The original time series (normalized)
        block_length (int): The number of consecutive values to mask from the end

    Returns:
        masked_series (pd.Series): The modified series with NaNs
        start_idx (int): Starting index of the missing block
        end_idx (int): Ending index (exclusive) of the missing block
    """
    ts = series.copy()
    end_idx = len(ts)
    start_idx = end_idx - block_length
    ts[start_idx:end_idx] = np.nan
    return ts, start_idx, end_idx

# Inject blocks of 7 days (168 time points).

# %% [markdown]
# # ---------------------------------------------------------
# # 🔹 STEP 2b: Applying block-missing to the normalized target series
# # ---------------------------------------------------------

# %%
# ---------------------------------------------------------
# 🔹 STEP 2b: Apply block-missing to the normalized target series
# ---------------------------------------------------------

# Define target station (from your pattern_df)
target_station = "02500MS"

# Define block length (e.g. 10 time points ~ 5 hours if half-hourly)
block_length = 3131 

# Apply the masking function
masked_target, start_idx, end_idx = introduce_block_missing_end(
    normalized_df[target_station],
    block_length
)

# ✅ Optional: Print info about the block
print(f"🧱 Missing block injected from index {start_idx} to {end_idx - 1}")
print("🕓 Timestamps of missing block:\n", normalized_df.index[start_idx:end_idx])
# Out:
# 🧱 Missing block injected from index 11462 to 14592
# 🕓 Timestamps of missing block:
#  DatetimeIndex(['2024-10-27 19:00:00', '2024-10-27 19:30:00',
#                '2024-10-27 20:00:00', '2024-10-27 20:30:00',
#                '2024-10-27 21:00:00', '2024-10-27 21:30:00',
#                '2024-10-27 22:00:00', '2024-10-27 22:30:00',
#                '2024-10-27 23:00:00', '2024-10-27 23:30:00',
#                ...
#                '2024-12-31 19:30:00', '2024-12-31 20:00:00',
#                '2024-12-31 20:30:00', '2024-12-31 21:00:00',
#                '2024-12-31 21:30:00', '2024-12-31 22:00:00',
#                '2024-12-31 22:30:00', '2024-12-31 23:00:00',
#                '2024-12-31 23:30:00', '2025-01-01 00:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=3131, freq=None)

# %% [markdown]
# # ---------------------------------------------------------
# # 🔹 STEP 3: Preparing NumPy arrays for imputation and evaluation
# # ---------------------------------------------------------

# %%
# Extract the reference station names (excluding the target)
reference_stations = [col for col in normalized_df.columns if col != target_station]

#  Get reference matrix as shape (num_refs, time) — transposed
ref_matrix = normalized_df[reference_stations].to_numpy().T  # shape: (num_refs, time)

#  Get the masked target series as array (shape: time,)
masked_target_array = masked_target.to_numpy().copy()

#  Get the original (true) unmasked target series
true_target_array = normalized_df[target_station].to_numpy()

#  Save the index positions of the block-masked values
nan_block_indices = np.arange(start_idx, end_idx)

#  Preview shapes and sanity check
print(" Target shape:", masked_target_array.shape)
print(" Ref matrix shape:", ref_matrix.shape)
print(" Block indices:", nan_block_indices)
print(" Target preview (with NaNs):", masked_target_array[start_idx:end_idx])
# Out:
#  Target shape: (14593,)
#  Ref matrix shape: (3, 14593)
#  Block indices: [11462 11463 11464 ... 14590 14591 14592]
#  Target preview (with NaNs): [nan nan nan ... nan nan nan]

# %%
print(type(masked_target_array), masked_target_array.shape)
# Out:
# <class 'numpy.ndarray'> (14593,)

# %% [markdown]
# # -----------------------------------------------
# # 🔹 STEP 4.1: Setting safe parameters for all models
# # -----------------------------------------------

# %%
k = 5  # number of top matching sequences (for TKCMs)
l = 4  # sliding window size
rank = max(1, min(ref_matrix.shape[0] - 1, 2))  # safe low-rank dimension for SVD, TRMF

# %% [markdown]
# ### --- Basic Imputers --

# %%
from sklearn.impute import SimpleImputer

# --- Basic Imputers ---

class ZeroImputer:
    def fit_transform(self, X):
        X = X.copy()
        X[np.isnan(X)] = 0
        return X


class MinImputer:
    def fit_transform(self, X):
        fill_value = np.nanmin(X[~np.isnan(X)])
        imp = SimpleImputer(strategy='constant', fill_value=fill_value)
        return imp.fit_transform(X)

class InterpolationImputer:
    def fit_transform(self, X):
        return pd.DataFrame(X).interpolate(method='linear', axis=0, limit_direction='both').values

# %% [markdown]
# # -----------------------------------------------
# # 🔹 STEP 4.2: Applying each model with correct usage
# # -----------------------------------------------

# %%
# Stack the masked target (first row) + full reference matrix (rest)
X_stacked = np.vstack([masked_target_array, ref_matrix])

# TKCM
tkcm = TKCM(k=k, l=l)
tkcm_imputed = tkcm.impute(masked_target_array.copy(), offset=start_idx, ref_ts=ref_matrix)

#  TKCM_PLUS
tkcm_plus = TKCM_PLUS(k=k, l=l, alpha=0.5, beta=0.5)
tkcm_plus_imputed = tkcm_plus.impute(masked_target_array.copy(), offset=start_idx, ref_ts=ref_matrix)

#  TKCM_Weighted
tkcm_w = TKCM_Weighted(k=k, l=l)
tkcm_weighted_imputed = tkcm_w.impute(masked_target_array.copy(), offset=start_idx, ref_ts=ref_matrix)

#  TKCM_PRO
tkcm_pro = TKCM_PRO(k=k, l=l)
tkcm_pro_imputed = tkcm_pro.impute(masked_target_array.copy(), offset=start_idx, ref_ts=ref_matrix)


# CDRec
cdrec = CDRec(rank=rank)
cdrec_imputed = cdrec.impute(X_stacked.copy())[0]  # Only return target row

#  DynaMMo
dynammo = DynaMMo(latent_dim=rank)
dynammo_imputed = dynammo.fit_transform(X_stacked.copy())[0]

#  SoftImpute
soft = SoftImpute(max_rank=rank)
soft_imputed = soft.fit_transform(X_stacked.copy())[0]

#  IterativeSVD
svd = IterativeSVD(rank=rank)
svd_imputed = svd.fit_transform(X_stacked.copy())[0]

#  ST_MVL
st_mvl = ST_MVL()
st_mvl_imputed = st_mvl.impute(X_stacked.copy())[0]

#  TRMF
trmf = TRMFImputer(rank=rank)
trmf_imputed = trmf.fit_transform(X_stacked.copy())[0]

#  Zero Imputer
zero_imputer = ZeroImputer()
zero_imputed = zero_imputer.fit_transform(X_stacked.copy())[0]

#  Min Imputer
min_imputer = MinImputer()
min_imputed = min_imputer.fit_transform(X_stacked.copy())[0]

#  Interpolation Imputer
interp_imputer = InterpolationImputer()
interp_imputed = interp_imputer.fit_transform(X_stacked.copy())[0]

# %%
# In TKCM imputation loop
missing_indices = np.where(np.isnan(masked_target_array))[0]

for offset in missing_indices:
    imputed_series = tkcm.impute(masked_target_array.copy(), offset=offset, ref_ts=ref_matrix)
    print(f"Offset {offset} → Imputed value = {imputed_series[offset]}")
# Out:
# Offset 2140 → Imputed value = -1.492608975643674
# Offset 2141 → Imputed value = -1.5835212708512756
# Offset 11462 → Imputed value = 1.317963081800368
# Offset 11463 → Imputed value = 1.042301959828461
# Offset 11464 → Imputed value = 0.39049770539203527
# Offset 11465 → Imputed value = 0.7283619767165115
# Offset 11466 → Imputed value = 1.1064190522380328
# Offset 11467 → Imputed value = 1.4184450922929805
# Offset 11468 → Imputed value = 1.5093573875005823
# Offset 11469 → Imputed value = 1.1456548849065769
# Offset 11470 → Imputed value = 0.39049770539203527
# Offset 11471 → Imputed value = 0.39049770539203527
# Offset 11472 → Imputed value = 0.7809954107840705
# Offset 11473 → Imputed value = 0.7809954107840705
# Offset 11474 → Imputed value = 0.7149643753174967
# Offset 11475 → Imputed value = 1.4739494409460425
# Offset 11476 → Imputed value = 1.4796912701170488
# Offset 11477 → Imputed value = 1.479691270117049
# Offset 11478 → Imputed value = 1.4060044624224666
# Offset 11479 → Imputed value = 1.0891935647250137
# Offset 11480 → Imputed value = 1.4155741777074773
# Offset 11481 → Imputed value = 1.4634227541325306
# Offset 11482 → Imputed value = 1.4902179569305607
# Offset 11483 → Imputed value = 1.7400408476329385
# Offset 11484 → Imputed value = 1.567785972502746
# Offset 11485 → Imputed value = 1.5572592856892347
# Offset 11486 → Imputed value = 1.5151525384351874
# Offset 11487 → Imputed value = 0.9188526326518233
# Offset 11488 → Imputed value = 0.4058625716116512
# Offset 11489 → Imputed value = 0.39049770539203527
# Offset 11490 → Imputed value = 0.39049770539203527
# Offset 11491 → Imputed value = 1.179202210167713
# Offset 11492 → Imputed value = 0.8461227964857422
# Offset 11493 → Imputed value = 1.1983949625013333
# Offset 11494 → Imputed value = 0.1819312339424009
# Offset 11495 → Imputed value = -0.013344279635416076
# Offset 11496 → Imputed value = 0.088201345912895
# Offset 11497 → Imputed value = 0.011750267160007145
# Offset 11498 → Imputed value = -0.1327524336436543
# Offset 11499 → Imputed value = -0.0427971099645537
# Offset 11500 → Imputed value = -0.08118261463179424
# Offset 11501 → Imputed value = 0.2777350303197057
# Offset 11502 → Imputed value = 0.19644577216071366
# Offset 11503 → Imputed value = 0.41171104430985545
# Offset 11504 → Imputed value = 0.12079169964553019
# Offset 11505 → Imputed value = 0.5983738141311628
# Offset 11506 → Imputed value = 0.7409092501142233
# Offset 11507 → Imputed value = 0.3589709667150988
# Offset 11508 → Imputed value = 0.6184168944660865
# Offset 11509 → Imputed value = 0.09197591026330046
# Offset 11510 → Imputed value = 0.7399522785857221
# Offset 11511 → Imputed value = 0.5389349358368987
# Offset 11512 → Imputed value = 1.0031194489235162
# Offset 11513 → Imputed value = 0.7571244443351426
# Offset 11514 → Imputed value = 0.7198025547236009
# Offset 11515 → Imputed value = 0.45562509109370686
# Offset 11516 → Imputed value = 0.27566112197190695
# Offset 11517 → Imputed value = 0.58385927591285
# Offset 11518 → Imputed value = 0.5771604752133427
# Offset 11519 → Imputed value = 0.2823599226714143
# Offset 11520 → Imputed value = 0.5436664717158053
# Offset 11521 → Imputed value = 0.9839266965898961
# Offset 11522 → Imputed value = 1.6185054635133032
# Offset 11523 → Imputed value = 1.8835865769080993
# Offset 11524 → Imputed value = 1.3122212526293615
# Offset 11525 → Imputed value = 0.81741365063071
# Offset 11526 → Imputed value = 0.8547355402422518
# Offset 11527 → Imputed value = 1.4634760758961296
# Offset 11528 → Imputed value = 0.9973776197525099
# Offset 11529 → Imputed value = 1.2701678271389139
# Offset 11530 → Imputed value = 1.3390697771909905
# Offset 11531 → Imputed value = 1.2003089055583356
# Offset 11532 → Imputed value = 0.8509609758918462
# Offset 11533 → Imputed value = 0.9648405877834735
# Offset 11534 → Imputed value = 0.5753531756835383
# Offset 11535 → Imputed value = 0.7007164459171784
# Offset 11536 → Imputed value = 0.7572310878623403
# Offset 11537 → Imputed value = 0.6232550738721905
# Offset 11538 → Imputed value = 0.43659230405088323
# Offset 11539 → Imputed value = 0.392571613739834
# Offset 11540 → Imputed value = 0.4413771616933883
# Offset 11541 → Imputed value = 0.41367830913045633
# Offset 11542 → Imputed value = -0.11366632483723178
# Offset 11543 → Imputed value = -0.3462104062629917
# Offset 11544 → Imputed value = -0.4630142545037209
# Offset 11545 → Imputed value = -0.22860955178455783
# Offset 11546 → Imputed value = -0.6074636335437836
# Offset 11547 → Imputed value = -0.7002898718083873
# Offset 11548 → Imputed value = -0.7318166104853239
# Offset 11549 → Imputed value = -0.8801471974029896
# Offset 11550 → Imputed value = -0.3289849187499724
# Offset 11551 → Imputed value = 0.047158213714546746
# Offset 11552 → Imputed value = 0.43377471122897904
# Offset 11553 → Imputed value = 0.4470656691007962
# Offset 11554 → Imputed value = 0.24424102682216825
# Offset 11555 → Imputed value = 0.27295017267720034
# Offset 11556 → Imputed value = 0.42989350335137566
# Offset 11557 → Imputed value = 0.4298401815877767
# Offset 11558 → Imputed value = 0.3867764628052286
# Offset 11559 → Imputed value = 0.34084182943717745
# Offset 11560 → Imputed value = 0.5456870583000051
# Offset 11561 → Imputed value = 0.601191406953067
# Offset 11562 → Imputed value = 0.5983204923675639
# Offset 11563 → Imputed value = 0.8949283444392965
# Offset 11564 → Imputed value = 0.3292515275679668
# Offset 11565 → Imputed value = 0.3292515275679668
# Offset 11566 → Imputed value = 0.3292515275679668
# Offset 11567 → Imputed value = -0.006645478935908629
# Offset 11568 → Imputed value = 0.11207231236182277
# Offset 11569 → Imputed value = 0.2623168423364908
# Offset 11570 → Imputed value = 0.36083158800850207
# Offset 11571 → Imputed value = 0.3092084472330431
# Offset 11572 → Imputed value = 0.3541861090725934
# Offset 11573 → Imputed value = 0.6279332879874981
# Offset 11574 → Imputed value = 0.5982671706039651
# Offset 11575 → Imputed value = 0.016321837748117025
# Offset 11576 → Imputed value = 0.016321837748117025
# Offset 11577 → Imputed value = 0.0
# Offset 11578 → Imputed value = 0.5666337883998308
# Offset 11579 → Imputed value = 0.4403668684012885
# Offset 11580 → Imputed value = 0.4192601730106661
# Offset 11581 → Imputed value = 0.721716497780603
# Offset 11582 → Imputed value = 0.5149573258607731
# Offset 11583 → Imputed value = 0.8395306393134323
# Offset 11584 → Imputed value = 1.0596340908686783
# Offset 11585 → Imputed value = 0.8701537282254664
# Offset 11586 → Imputed value = 0.8577130983549525
# Offset 11587 → Imputed value = 0.40788315819585097
# Offset 11588 → Imputed value = 0.4653547716695142
# Offset 11589 → Imputed value = 0.057631578764459644
# Offset 11590 → Imputed value = 0.20505851591722327
# Offset 11591 → Imputed value = -0.0811826146317943
# Offset 11592 → Imputed value = -0.4572724253327145
# Offset 11593 → Imputed value = -0.4371227014705933
# Offset 11594 → Imputed value = -0.6658388967823489
# Offset 11595 → Imputed value = -0.7557408986978505
# Offset 11596 → Imputed value = -0.8045997684150039
# Offset 11597 → Imputed value = -0.6715274041897565
# Offset 11598 → Imputed value = -0.3768334951750259
# Offset 11599 → Imputed value = -0.2735338918605093
# Offset 11600 → Imputed value = -0.12227906859374134
# Offset 11601 → Imputed value = 0.19155427099101058
# Offset 11602 → Imputed value = 0.15423238137946887
# Offset 11603 → Imputed value = 0.27863868008460774
# Offset 11604 → Imputed value = 0.33036846438726436
# Offset 11605 → Imputed value = 0.4786990513049302
# Offset 11606 → Imputed value = 0.27103622962019813
# Offset 11607 → Imputed value = 0.3332927007363667
# Offset 11608 → Imputed value = 0.3763564195189148
# Offset 11609 → Imputed value = 0.3993237362029402
# Offset 11610 → Imputed value = 0.30745446946683774
# Offset 11611 → Imputed value = 0.339938179672275
# Offset 11612 → Imputed value = 0.46822568625501726
# Offset 11613 → Imputed value = 0.32744422803816237
# Offset 11614 → Imputed value = 0.515967619152873
# Offset 11615 → Imputed value = 0.6605236417201332
# Offset 11616 → Imputed value = 0.6605236417201332
# Offset 11617 → Imputed value = 0.515967619152873
# Offset 11618 → Imputed value = 0.515967619152873
# Offset 11619 → Imputed value = 0.725597705658206
# Offset 11620 → Imputed value = 0.9361847636920402
# Offset 11621 → Imputed value = 0.8452724684844386
# Offset 11622 → Imputed value = 0.4384529253442865
# Offset 11623 → Imputed value = 0.9399593280424456
# Offset 11624 → Imputed value = 0.7121467824955923
# Offset 11625 → Imputed value = 0.31601389145974845
# Offset 11626 → Imputed value = 0.27778835208330444
# Offset 11627 → Imputed value = 0.047158213714546746
# Offset 11628 → Imputed value = 0.3725285334049103
# Offset 11629 → Imputed value = 0.3753461262268146
# Offset 11630 → Imputed value = 0.3188848060452515
# Offset 11631 → Imputed value = 0.5151172911515697
# Offset 11632 → Imputed value = 0.2164355307320382
# Offset 11633 → Imputed value = -0.03051644538483648
# Offset 11634 → Imputed value = 0.37816371904871915
# Offset 11635 → Imputed value = 0.12360929246743453
# Offset 11636 → Imputed value = 0.282519887962211
# Offset 11637 → Imputed value = 0.5227730633795782
# Offset 11638 → Imputed value = -0.24296412471207388
# Offset 11639 → Imputed value = -0.4572724253327145
# Offset 11640 → Imputed value = -0.2677920626895028
# Offset 11641 → Imputed value = -0.3826286461096312
# Offset 11642 → Imputed value = -0.5012931156437638
# Offset 11643 → Imputed value = -0.5797647809808516
# Offset 11644 → Imputed value = -0.5644532365248345
# Offset 11645 → Imputed value = -0.2812429858521167
# Offset 11646 → Imputed value = -0.6543019166767372
# Offset 11647 → Imputed value = -0.4332948153565891
# Offset 11648 → Imputed value = -0.624689121056803
# Offset 11649 → Imputed value = -0.30410365900894465
# Offset 11650 → Imputed value = 0.03944911972293932
# Offset 11651 → Imputed value = -0.1434390857479627
# Offset 11652 → Imputed value = -0.23238411613496335
# Offset 11653 → Imputed value = -0.202771320515029
# Offset 11654 → Imputed value = -0.21606227838684616
# Offset 11655 → Imputed value = -0.2898024078450275
# Offset 11656 → Imputed value = -0.24285748118487613
# Offset 11657 → Imputed value = -0.036204952792244095
# Offset 11658 → Imputed value = 0.030729732439231883
# Offset 11659 → Imputed value = 0.08724437438439393
# Offset 11660 → Imputed value = -0.12520330494284354
# Offset 11661 → Imputed value = 0.008826030810905083
# Offset 11662 → Imputed value = 0.02413757526692221
# Offset 11663 → Imputed value = -0.09644083732421256
# Offset 11664 → Imputed value = 0.04896551324435121
# Offset 11665 → Imputed value = 0.08150254521338762
# Offset 11666 → Imputed value = 0.08628740285589283
# Offset 11667 → Imputed value = 0.0862874028558929
# Offset 11668 → Imputed value = -0.021850379864727976
# Offset 11669 → Imputed value = -0.0065388354087107855
# Offset 11670 → Imputed value = 0.10537351166231541
# Offset 11671 → Imputed value = 0.20590884391852654
# Offset 11672 → Imputed value = 0.16284512513597832
# Offset 11673 → Imputed value = 0.336056971794672
# Offset 11674 → Imputed value = 0.352378809542789
# Offset 11675 → Imputed value = 0.12461958575953451
# Offset 11676 → Imputed value = -0.3587043578971044
# Offset 11677 → Imputed value = -0.29650120854453493
# Offset 11678 → Imputed value = 0.06805162205077372
# Offset 11679 → Imputed value = 0.10643712671801434
# Offset 11680 → Imputed value = 0.015418187983214829
# Offset 11681 → Imputed value = 0.0641704141731705
# Offset 11682 → Imputed value = 0.1838984987630019
# Offset 11683 → Imputed value = 0.2231876531951446
# Offset 11684 → Imputed value = 0.23557496130205968
# Offset 11685 → Imputed value = -0.2869314932595242
# Offset 11686 → Imputed value = 0.0
# Offset 11687 → Imputed value = -0.1894270408796129
# Offset 11688 → Imputed value = -0.37789711023072464
# Offset 11689 → Imputed value = -0.5913017610864632
# Offset 11690 → Imputed value = -1.0897772839083228
# Offset 11691 → Imputed value = -1.0907342554368238
# Offset 11692 → Imputed value = -1.4361476554621109
# Offset 11693 → Imputed value = -1.2811182678449378
# Offset 11694 → Imputed value = -1.1930768872228392
# Offset 11695 → Imputed value = -0.624689121056803
# Offset 11696 → Imputed value = -0.5443035126627129
# Offset 11697 → Imputed value = -0.5452604841912141
# Offset 11698 → Imputed value = -0.30979216641635215
# Offset 11699 → Imputed value = -0.3654031585966119
# Offset 11700 → Imputed value = -0.13865422810545738
# Offset 11701 → Imputed value = -0.2955442370160339
# Offset 11702 → Imputed value = -0.18262159665290773
# Offset 11703 → Imputed value = -0.08309655768879644
# Offset 11704 → Imputed value = -0.2649211481039996
# Offset 11705 → Imputed value = -0.06023588453196853
# Offset 11706 → Imputed value = 0.08527710956379295
# Offset 11707 → Imputed value = -0.19219131193791839
# Offset 11708 → Imputed value = -0.416972977608472
# Offset 11709 → Imputed value = -0.17018096678239383
# Offset 11710 → Imputed value = -0.3270176539293715
# Offset 11711 → Imputed value = -0.46391790426862317
# Offset 11712 → Imputed value = 0.017332131040217004
# Offset 11713 → Imputed value = -0.10712748942852093
# Offset 11714 → Imputed value = -0.2621035552820953
# Offset 11715 → Imputed value = -0.04098981043474931
# Offset 11716 → Imputed value = -0.2907593793735285
# Offset 11717 → Imputed value = -0.405542641030058
# Offset 11718 → Imputed value = -0.33180251157187685
# Offset 11719 → Imputed value = -0.012174021052519588
# Offset 11720 → Imputed value = -0.47827247719613925
# Offset 11721 → Imputed value = -0.023764322921730086
# Offset 11722 → Imputed value = -0.1548694223263767
# Offset 11723 → Imputed value = 0.14365237280235818
# Offset 11724 → Imputed value = 0.18198455570599995
# Offset 11725 → Imputed value = 0.10542683342591422
# Offset 11726 → Imputed value = 0.3773133910474158
# Offset 11727 → Imputed value = 0.040406091251440415
# Offset 11728 → Imputed value = 0.2624234858636884
# Offset 11729 → Imputed value = 0.08724437438439399
# Offset 11730 → Imputed value = 0.13886751515985285
# Offset 11731 → Imputed value = 0.005848472698204132
# Offset 11732 → Imputed value = 0.13020144963974437
# Offset 11733 → Imputed value = 0.07187950816477791
# Offset 11734 → Imputed value = -0.1654494309034873
# Offset 11735 → Imputed value = -0.24009321012657076
# Offset 11736 → Imputed value = -0.40277836997175254
# Offset 11737 → Imputed value = -0.6812570847655637
# Offset 11738 → Imputed value = -0.9443709333397589
# Offset 11739 → Imputed value = -0.8199646346346199
# Offset 11740 → Imputed value = -0.7826427450230782
# Offset 11741 → Imputed value = -0.3912947116297397
# Offset 11742 → Imputed value = -0.4171329428992686
# Offset 11743 → Imputed value = -0.5711520372243418
# Offset 11744 → Imputed value = -0.42468207160007926
# Offset 11745 → Imputed value = -0.309845488179951
# Offset 11746 → Imputed value = -0.33945828379988535
# Offset 11747 → Imputed value = -0.44190755911309865
# Offset 11748 → Imputed value = -0.3834789741109345
# Offset 11749 → Imputed value = -0.40750990585065894
# Offset 11750 → Imputed value = -0.10032204520181565
# Offset 11751 → Imputed value = -0.44196088087669744
# Offset 11752 → Imputed value = -0.23148046637006106
# Offset 11753 → Imputed value = -0.22185742932145153
# Offset 11754 → Imputed value = -0.2151053068583452
# Offset 11755 → Imputed value = -0.30320000924404245
# Offset 11756 → Imputed value = -0.18549251123841087
# Offset 11757 → Imputed value = -0.2045786200448334
# Offset 11758 → Imputed value = -0.20750285639393545
# Offset 11759 → Imputed value = -0.08208626439669645
# Offset 11760 → Imputed value = -0.1558263938548777
# Offset 11761 → Imputed value = -0.1385475845782596
# Offset 11762 → Imputed value = -0.004518248824510995
# Offset 11763 → Imputed value = -0.16821370196179278
# Offset 11764 → Imputed value = 0.006008437989000787
# Offset 11765 → Imputed value = 0.29214292501082056
# Offset 11766 → Imputed value = 0.16486571172017833
# Offset 11767 → Imputed value = 0.10739409824651536
# Offset 11768 → Imputed value = 0.2432840552936671
# Offset 11769 → Imputed value = 0.17055421912758592
# Offset 11770 → Imputed value = 0.22228400343024246
# Offset 11771 → Imputed value = 0.21840279555263936
# Offset 11772 → Imputed value = 0.34376606578627944
# Offset 11773 → Imputed value = 0.22031673860964146
# Offset 11774 → Imputed value = 0.10542683342591422
# Offset 11775 → Imputed value = -0.1271172479998457
# Offset 11776 → Imputed value = -0.10505358108072216
# Offset 11777 → Imputed value = 0.16390874019167717
# Offset 11778 → Imputed value = 0.3131429768742452
# Offset 11779 → Imputed value = 0.2078227869755286
# Offset 11780 → Imputed value = 0.07384677298537894
# Offset 11781 → Imputed value = -0.4122414417295654
# Offset 11782 → Imputed value = -0.6294739786993082
# Offset 11783 → Imputed value = -0.4008111051511515
# Offset 11784 → Imputed value = -0.5443568344263119
# Offset 11785 → Imputed value = -0.7825361014958805
# Offset 11786 → Imputed value = -0.8801471974029894
# Offset 11787 → Imputed value = -0.6017751261363761
# Offset 11788 → Imputed value = -0.846706515669051
# Offset 11789 → Imputed value = -0.9241678877140387
# Offset 11790 → Imputed value = -0.9088563432580216
# Offset 11791 → Imputed value = -0.5270780251496938
# Offset 11792 → Imputed value = -0.13769725657695622
# Offset 11793 → Imputed value = -0.3395649273270831
# Offset 11794 → Imputed value = -0.30506063053744575
# Offset 11795 → Imputed value = -0.20936347768733882
# Offset 11796 → Imputed value = 0.07576071604238113
# Offset 11797 → Imputed value = 0.039289154432142745
# Offset 11798 → Imputed value = -0.20181434898652792
# Offset 11799 → Imputed value = -0.24296412471207388
# Offset 11800 → Imputed value = 0.1474802589163624
# Offset 11801 → Imputed value = 0.06704132875867368
# Offset 11802 → Imputed value = 0.026901846325227685
# Offset 11803 → Imputed value = -0.257265375875991
# Offset 11804 → Imputed value = -0.2400398883629718
# Offset 11805 → Imputed value = -0.07932199333839096
# Offset 11806 → Imputed value = 0.037375211375140584
# Offset 11807 → Imputed value = 0.19724277839841803
# Offset 11808 → Imputed value = 0.19437186381291488
# Offset 11809 → Imputed value = -0.19500890475982263
# Offset 11810 → Imputed value = -0.18352524641780976
# Offset 11811 → Imputed value = -0.4466924167556039
# Offset 11812 → Imputed value = -0.6075169553073824
# Offset 11813 → Imputed value = -0.5663671795818365
# Offset 11814 → Imputed value = -0.14439605727646382
# Offset 11815 → Imputed value = -0.34344613520468614
# Offset 11816 → Imputed value = -0.22387801590565135
# Offset 11817 → Imputed value = 0.0
# Offset 11818 → Imputed value = -0.24774898235457926
# Offset 11819 → Imputed value = 0.0
# Offset 11820 → Imputed value = -0.47072334849532843
# Offset 11821 → Imputed value = 0.0
# Offset 11822 → Imputed value = -0.4993791725867617
# Offset 11823 → Imputed value = -0.3932086546867418
# Offset 11824 → Imputed value = -0.3587576796607033
# Offset 11825 → Imputed value = -0.4304772225346847
# Offset 11826 → Imputed value = -0.5682811226388387
# Offset 11827 → Imputed value = -0.6017751261363761
# Offset 11828 → Imputed value = -0.3587576796607033
# Offset 11829 → Imputed value = -0.2650277916311974
# Offset 11830 → Imputed value = -0.1654494309034873
# Offset 11831 → Imputed value = -0.20372829204353007
# Offset 11832 → Imputed value = -0.5080452381068701
# Offset 11833 → Imputed value = -0.423831743598776
# Offset 11834 → Imputed value = -0.8218785776916221
# Offset 11835 → Imputed value = -1.4036106234930745
# Offset 11836 → Imputed value = -1.3882990790370573
# Offset 11837 → Imputed value = -0.8294810281560319
# Offset 11838 → Imputed value = -0.7089559373284958
# Offset 11839 → Imputed value = -0.7423966190624345
# Offset 11840 → Imputed value = -0.5395719767838066
# Offset 11841 → Imputed value = -0.681203763001965
# Offset 11842 → Imputed value = -0.8390507434410424
# Offset 11843 → Imputed value = -0.3176079039351573
# Offset 11844 → Imputed value = -0.3941123044516441
# Offset 11845 → Imputed value = -0.6170333488287943
# Offset 11846 → Imputed value = -0.5051210017577681
# Offset 11847 → Imputed value = -0.35296252872609796
# Offset 11848 → Imputed value = -0.2515768684685835
# Offset 11849 → Imputed value = -0.4324444873552856
# Offset 11850 → Imputed value = -0.19995372769312464
# Offset 11851 → Imputed value = 0.0
# Offset 11852 → Imputed value = -0.5146907170427787
# Offset 11853 → Imputed value = -0.5691847724037409
# Offset 11854 → Imputed value = -0.5318628827921992
# Offset 11855 → Imputed value = -0.5289919682066959
# Offset 11856 → Imputed value = -0.6342588363418136
# Offset 11857 → Imputed value = -0.4323911655916867
# Offset 11858 → Imputed value = -0.3826286461096312
# Offset 11859 → Imputed value = -0.5672708293467388
# Offset 11860 → Imputed value = -0.5146373952791798
# Offset 11861 → Imputed value = -0.5529162564192227
# Offset 11862 → Imputed value = -0.37018801623911723
# Offset 11863 → Imputed value = -0.5194222529216853
# Offset 11864 → Imputed value = -0.42755298618558263
# Offset 11865 → Imputed value = -0.3289849187499724
# Offset 11866 → Imputed value = -0.48497127789564676
# Offset 11867 → Imputed value = -0.44956333134110726
# Offset 11868 → Imputed value = -0.5309059112636982
# Offset 11869 → Imputed value = -0.3768334951750259
# Offset 11870 → Imputed value = -0.17491250266130023
# Offset 11871 → Imputed value = -0.20457862004483346
# Offset 11872 → Imputed value = -0.49167007859515427
# Offset 11873 → Imputed value = -0.1643858158477885
# Offset 11874 → Imputed value = -0.03524798126374301
# Offset 11875 → Imputed value = -0.42372510007157826
# Offset 11876 → Imputed value = -0.06300015559027394
# Offset 11877 → Imputed value = 0.0641704141731705
# Offset 11878 → Imputed value = 0.08330984474319189
# Offset 11879 → Imputed value = -0.219093158263146
# Offset 11880 → Imputed value = -0.1894270408796129
# Offset 11881 → Imputed value = -0.668763133131451
# Offset 11882 → Imputed value = -1.3653317623530319
# Offset 11883 → Imputed value = -1.0447996220687723
# Offset 11884 → Imputed value = -1.2457103212903982
# Offset 11885 → Imputed value = -0.8562229091904628
# Offset 11886 → Imputed value = -0.6017218043727771
# Offset 11887 → Imputed value = -0.2850175502025222
# Offset 11888 → Imputed value = -0.7930627883093923
# Offset 11889 → Imputed value = -0.18926707558881634
# Offset 11890 → Imputed value = -0.10510690284432107
# Offset 11891 → Imputed value = -0.30117942265984254
# Offset 11892 → Imputed value = 0.028922432909427486
# Offset 11893 → Imputed value = 0.12940444340203985
# Offset 11894 → Imputed value = 0.23371434000865632
# Offset 11895 → Imputed value = -0.32037217499346277
# Offset 11896 → Imputed value = -0.22175078579425372
# Offset 11897 → Imputed value = -0.39310201115954413
# Offset 11898 → Imputed value = -0.17874038877530457
# Offset 11899 → Imputed value = -0.199793762402328
# Offset 11900 → Imputed value = -0.48970281377455327
# Offset 11901 → Imputed value = -0.026635237507233255
# Offset 11902 → Imputed value = -0.05917226947626969
# Offset 11903 → Imputed value = 0.07964192391998437
# Offset 11904 → Imputed value = -0.1232360401222424
# Offset 11905 → Imputed value = -0.2332344441362665
# Offset 11906 → Imputed value = -0.3863498886964377
# Offset 11907 → Imputed value = -0.1204184473003381
# Offset 11908 → Imputed value = -0.15965427996888196
# Offset 11909 → Imputed value = -0.2544477830540867
# Offset 11910 → Imputed value = -0.25061989694008246
# Offset 11911 → Imputed value = -0.12424633341434244
# Offset 11912 → Imputed value = -0.08793473709490066
# Offset 11913 → Imputed value = -0.06879530652487927
# Offset 11914 → Imputed value = -0.0946335377944081
# Offset 11915 → Imputed value = -0.07645107875288779
# Offset 11916 → Imputed value = -0.07645107875288779
# Offset 11917 → Imputed value = -0.04205342549044816
# Offset 11918 → Imputed value = -0.09170930144530604
# Offset 11919 → Imputed value = -0.14912759315537022
# Offset 11920 → Imputed value = -0.04013948243344606
# Offset 11921 → Imputed value = -0.07645107875288779
# Offset 11922 → Imputed value = -0.13477302022785423
# Offset 11923 → Imputed value = -0.10601055260922325
# Offset 11924 → Imputed value = -0.010313399759116238
# Offset 11925 → Imputed value = -0.0772480849905923
# Offset 11926 → Imputed value = -0.5949696819096708
# Offset 11927 → Imputed value = -0.5768405446317494
# Offset 11928 → Imputed value = -0.6648819252538478
# Offset 11929 → Imputed value = -0.8524483448400574
# Offset 11930 → Imputed value = -0.46588516908922417
# Offset 11931 → Imputed value = -0.859093823775966
# Offset 11932 → Imputed value = -0.4563154538042135
# Offset 11933 → Imputed value = -0.27539451315391256
# Offset 11934 → Imputed value = -0.3758765236465248
# Offset 11935 → Imputed value = -0.09649415908781139
# Offset 11936 → Imputed value = -0.1271705697634445
# Offset 11937 → Imputed value = -0.2630072050469975
# Offset 11938 → Imputed value = 0.251790155522979
# Offset 11939 → Imputed value = -0.007495806937211946
# Offset 11940 → Imputed value = -0.02280735139322907
# Offset 11941 → Imputed value = 0.11116866259692067
# Offset 11942 → Imputed value = 0.20117730803962006
# Offset 11943 → Imputed value = 0.19926336498261796
# Offset 11944 → Imputed value = 0.09399649684750033
# Offset 11945 → Imputed value = 0.07772798086298212
# Offset 11946 → Imputed value = 0.1178674632964281
# Offset 11947 → Imputed value = -0.0017539777662055112
# Offset 11948 → Imputed value = 0.0691152371064725
# Offset 11949 → Imputed value = 0.041203097489144844
# Offset 11950 → Imputed value = -0.014301251163917159
# Offset 11951 → Imputed value = -0.06783833499637817
# Offset 11952 → Imputed value = 0.0048381794061042325
# Offset 11953 → Imputed value = 0.0
# Offset 11954 → Imputed value = 0.014407894691114928
# Offset 11955 → Imputed value = 0.031633382204134156
# Offset 11956 → Imputed value = 0.04885886971715344
# Offset 11957 → Imputed value = 0.0
# Offset 11958 → Imputed value = 0.031633382204134156
# Offset 11959 → Imputed value = 0.0
# Offset 11960 → Imputed value = 0.0
# Offset 11961 → Imputed value = 0.06613767899377147
# Offset 11962 → Imputed value = 0.07283647969327907
# Offset 11963 → Imputed value = 0.07570739427878218
# Offset 11964 → Imputed value = 0.021106695390622373
# Offset 11965 → Imputed value = 0.054600698888159806
# Offset 11966 → Imputed value = 0.0795352803927865
# Offset 11967 → Imputed value = 0.08724437438439385
# Offset 11968 → Imputed value = 0.0
# Offset 11969 → Imputed value = 0.07379345122178008
# Offset 11970 → Imputed value = 0.19160759275460937
# Offset 11971 → Imputed value = 0.06613767899377147
# Offset 11972 → Imputed value = 0.027965461380926527
# Offset 11973 → Imputed value = -0.35487647178310017
# Offset 11974 → Imputed value = -0.519475574685284
# Offset 11975 → Imputed value = -0.3109091032356498
# Offset 11976 → Imputed value = -0.2831569289091188
# Offset 11977 → Imputed value = -0.6907734782869756
# Offset 11978 → Imputed value = -0.35774738636860326
# Offset 11979 → Imputed value = -0.5692380941673398
# Offset 11980 → Imputed value = -0.8562762309540617
# Offset 11981 → Imputed value = -0.8840284052805927
# Offset 11982 → Imputed value = -0.6811504412383659
# Offset 11983 → Imputed value = -0.32813459074866913
# Offset 11984 → Imputed value = -0.43239116559168683
# Offset 11985 → Imputed value = -0.5654102080533354
# Offset 11986 → Imputed value = -0.02860250232783438
# Offset 11987 → Imputed value = -0.28017937079641786
# Offset 11988 → Imputed value = -0.1844822179463109
# Offset 11989 → Imputed value = 0.0
# Offset 11990 → Imputed value = -0.14822394339046802
# Offset 11991 → Imputed value = -0.07549410722438678
# Offset 11992 → Imputed value = -0.10037536696541452
# Offset 11993 → Imputed value = -0.05066616924695784
# Offset 11994 → Imputed value = -0.07549410722438678
# Offset 11995 → Imputed value = -0.024827937977428934
# Offset 11996 → Imputed value = 0.046041276895249075
# Offset 11997 → Imputed value = 0.016375159511715913
# Offset 11998 → Imputed value = 0.054600698888159806
# Offset 11999 → Imputed value = 0.041203097489144844
# Offset 12000 → Imputed value = 0.04885886971715344
# Offset 12001 → Imputed value = 0.04604127689524908
# Offset 12002 → Imputed value = 0.013450923162613846
# Offset 12003 → Imputed value = 0.06326676440826831
# Offset 12004 → Imputed value = 0.0431703623097459
# Offset 12005 → Imputed value = -0.004678214115307578
# Offset 12006 → Imputed value = 0.09112558226199707
# Offset 12007 → Imputed value = 0.0767710093344811
# Offset 12008 → Imputed value = 0.07390009474897792
# Offset 12009 → Imputed value = 0.09490014661240252
# Offset 12010 → Imputed value = 0.11691049176792703
# Offset 12011 → Imputed value = 0.1791136411204966
# Offset 12012 → Imputed value = 0.22419794648724461
# Offset 12013 → Imputed value = 0.19160759275460937
# Offset 12014 → Imputed value = 0.1235559707038358
# Offset 12015 → Imputed value = 0.16380209666447948
# Offset 12016 → Imputed value = 0.012600595161310527
# Offset 12017 → Imputed value = -0.11563358965783277
# Offset 12018 → Imputed value = -0.0017006560026066263
# Offset 12019 → Imputed value = -0.013237636108218365
# Offset 12020 → Imputed value = 0.0021272301113977156
# Offset 12021 → Imputed value = -0.12424633341434244
# Offset 12022 → Imputed value = -0.519475574685284
# Offset 12023 → Imputed value = -0.24774898235457918
# Offset 12024 → Imputed value = -0.23243743789856214
# Offset 12025 → Imputed value = -0.44100390934819644
# Offset 12026 → Imputed value = -0.08894503038700062
# Offset 12027 → Imputed value = -0.271673270567106
# Offset 12028 → Imputed value = -0.0659777137029749
# Offset 12029 → Imputed value = -0.26114658375359423
# Offset 12030 → Imputed value = -0.5892278527386644
# Offset 12031 → Imputed value = -0.4897561355381521
# Offset 12032 → Imputed value = -0.35578012154800237
# Offset 12033 → Imputed value = -0.23419141566476767
# Offset 12034 → Imputed value = -0.2256319936718568
# Offset 12035 → Imputed value = 0.08059889544848542
# Offset 12036 → Imputed value = 0.12935112163844095
# Offset 12037 → Imputed value = 0.11882443482492919
# Offset 12038 → Imputed value = 0.09585711814090352
# Offset 12039 → Imputed value = 0.02397760997612562
# Offset 12040 → Imputed value = 0.014407894691114928
# Offset 12041 → Imputed value = 0.17337181194949025
# Offset 12042 → Imputed value = 0.27677805879120465
# Offset 12043 → Imputed value = 0.1313183864590421
# Offset 12044 → Imputed value = 0.23270404671655642
# Offset 12045 → Imputed value = 0.12456626399593569
# Offset 12046 → Imputed value = 0.10920139777631968
# Offset 12047 → Imputed value = 0.09681408966940455
# Offset 12048 → Imputed value = 0.5868901557891497
# Offset 12049 → Imputed value = 0.4365389822872842
# Offset 12050 → Imputed value = 0.1225456774117358
# Offset 12051 → Imputed value = 0.2872514238411174
# Offset 12052 → Imputed value = 0.3398848579086763
# Offset 12053 → Imputed value = 0.5734392326265361
# Offset 12054 → Imputed value = 0.6758885079397495
# Offset 12055 → Imputed value = 0.3629054963563007
# Offset 12056 → Imputed value = 0.1216953494104325
# Offset 12057 → Imputed value = 0.13030809316694206
# Offset 12058 → Imputed value = 0.18288820547090198
# Offset 12059 → Imputed value = 0.1685869543069849
# Offset 12060 → Imputed value = 0.196285806869917
# Offset 12061 → Imputed value = 0.19054397769891063
# Offset 12062 → Imputed value = 0.14652328738786138
# Offset 12063 → Imputed value = 0.196285806869917
# Offset 12064 → Imputed value = 0.19532883534141585
# Offset 12065 → Imputed value = 0.24801559117257366
# Offset 12066 → Imputed value = 0.19155427099101047
# Offset 12067 → Imputed value = 0.24413438329497045
# Offset 12068 → Imputed value = 0.17246816218458808
# Offset 12069 → Imputed value = 0.09500679013960031
# Offset 12070 → Imputed value = -0.3481776710835927
# Offset 12071 → Imputed value = -0.3998541336226504
# Offset 12072 → Imputed value = -0.3969832190371473
# Offset 12073 → Imputed value = -0.1549760658535744
# Offset 12074 → Imputed value = -0.7184723308499077
# Offset 12075 → Imputed value = -0.7548372489329483
# Offset 12076 → Imputed value = -1.0830251614452162
# Offset 12077 → Imputed value = -0.48784219248114996
# Offset 12078 → Imputed value = -0.30516727406464345
# Offset 12079 → Imputed value = -0.2868781714959253
# Offset 12080 → Imputed value = -0.4017147549160537
# Offset 12081 → Imputed value = -0.09351660097511047
# Offset 12082 → Imputed value = -0.13381604869935315
# Offset 12083 → Imputed value = -0.11749421095123605
# Offset 12084 → Imputed value = 0.0011169368192977425
# Offset 12085 → Imputed value = 0.07001888687137471
# Offset 12086 → Imputed value = 0.10829774801141749
# Offset 12087 → Imputed value = -0.05438741183376433
# Offset 12088 → Imputed value = -0.024667972686632417
# Offset 12089 → Imputed value = -0.05242014701316335
# Offset 12090 → Imputed value = -0.08118261463179426
# Offset 12091 → Imputed value = -0.11276267507232958
# Offset 12092 → Imputed value = -0.16348216608288624
# Offset 12093 → Imputed value = -0.22276107908635373
# Offset 12094 → Imputed value = -0.18836342582391405
# Offset 12095 → Imputed value = -0.18070765359590546
# Offset 12096 → Imputed value = -0.08208626439669646
# Offset 12097 → Imputed value = -0.2648145045768019
# Offset 12098 → Imputed value = -0.2514702249413857
# Offset 12099 → Imputed value = -0.20165438369573127
# Offset 12100 → Imputed value = -0.38826383175343987
# Offset 12101 → Imputed value = -0.2954375934888362
# Offset 12102 → Imputed value = -0.320318853229864
# Offset 12103 → Imputed value = -0.2992654796028405
# Offset 12104 → Imputed value = -0.23520170895686765
# Offset 12105 → Imputed value = -0.09936507367331462
# Offset 12106 → Imputed value = -0.4428112088780008
# Offset 12107 → Imputed value = -0.4094238489076611
# Offset 12108 → Imputed value = -0.36636013012511304
# Offset 12109 → Imputed value = -0.24200715318357285
# Offset 12110 → Imputed value = -0.2677920626895028
# Offset 12111 → Imputed value = -0.2084598279224365
# Offset 12112 → Imputed value = -0.19889011263742584
# Offset 12113 → Imputed value = -0.15199850774087345
# Offset 12114 → Imputed value = -0.1109020537789263
# Offset 12115 → Imputed value = -0.08984868015190275
# Offset 12116 → Imputed value = -0.6150660840081933
# Offset 12117 → Imputed value = -0.37975773152412795
# Offset 12118 → Imputed value = -0.6026787759012783
# Offset 12119 → Imputed value = -0.5749266015747472
# Offset 12120 → Imputed value = -0.5711520372243419
# Offset 12121 → Imputed value = -0.7653639357464602
# Offset 12122 → Imputed value = -1.1347016239842742
# Offset 12123 → Imputed value = -0.8400610367331425
# Offset 12124 → Imputed value = -1.1414004246837814
# Offset 12125 → Imputed value = -0.9433606400476592
# Offset 12126 → Imputed value = -0.8754156615240831
# Offset 12127 → Imputed value = -0.5041107084656681
# Offset 12128 → Imputed value = -0.6419146085698222
# Offset 12129 → Imputed value = -0.8629750316535691
# Offset 12130 → Imputed value = -0.6859886206444702
# Offset 12131 → Imputed value = -0.38071470305262906
# Offset 12132 → Imputed value = -0.4840676281307446
# Offset 12133 → Imputed value = -0.46301425450372113
# Offset 12134 → Imputed value = -0.4678524339098252
# Offset 12135 → Imputed value = -0.31378001782115306
# Offset 12136 → Imputed value = -0.3692843664742151
# Offset 12137 → Imputed value = -0.584496316859758
# Offset 12138 → Imputed value = -0.37880075999562696
# Offset 12139 → Imputed value = -0.7040644361587928
# Offset 12140 → Imputed value = -0.622721856236202
# Offset 12141 → Imputed value = -0.5242071105641906
# Offset 12142 → Imputed value = -0.3692310447106163
# Offset 12143 → Imputed value = -0.48980945730175096
# Offset 12144 → Imputed value = -0.4008111051511515
# Offset 12145 → Imputed value = -0.22563199367185688
# Offset 12146 → Imputed value = -0.3624789222475099
# Offset 12147 → Imputed value = -0.056301354890766445
# Offset 12148 → Imputed value = -0.587367231445261
# Offset 12149 → Imputed value = -0.27263024209560716
# Offset 12150 → Imputed value = -0.3788007599956269
# Offset 12151 → Imputed value = -0.5356907689062034
# Offset 12152 → Imputed value = -0.7232038667288142
# Offset 12153 → Imputed value = -0.43807967299909434
# Offset 12154 → Imputed value = -0.4744979128457339
# Offset 12155 → Imputed value = -0.22191075108505037
# Offset 12156 → Imputed value = -0.4362190517056911
# Offset 12157 → Imputed value = -0.5290452899702949
# Offset 12158 → Imputed value = -0.940436403698557
# Offset 12159 → Imputed value = -0.5864102599167602
# Offset 12160 → Imputed value = -0.531916204555798
# Offset 12161 → Imputed value = -0.8036427968865029
# Offset 12162 → Imputed value = -0.6725376974818563
# Offset 12163 → Imputed value = -0.6314412435199094
# Offset 12164 → Imputed value = -0.4343584304122878
# Offset 12165 → Imputed value = -0.5664205013454354
# Offset 12166 → Imputed value = -0.5702483874594396
# Offset 12167 → Imputed value = -0.8716410971736778
# Offset 12168 → Imputed value = -0.7214498889626088
# Offset 12169 → Imputed value = -1.0879166626149193
# Offset 12170 → Imputed value = -1.4735228668372513
# Offset 12171 → Imputed value = -1.535726016189821
# Offset 12172 → Imputed value = -1.5558224182883436
# Offset 12173 → Imputed value = -1.483092582122262
# Offset 12174 → Imputed value = -1.2983970771215558
# Offset 12175 → Imputed value = -1.2658600451525195
# Offset 12176 → Imputed value = -0.6267097076410028
# Offset 12177 → Imputed value = -0.2985217951287348
# Offset 12178 → Imputed value = -0.2946939090147305
# Offset 12179 → Imputed value = -0.14349240751156153
# Offset 12180 → Imputed value = -0.5759368948668472
# Offset 12181 → Imputed value = -0.7720627364459676
# Offset 12182 → Imputed value = -0.7969439961869954
# Offset 12183 → Imputed value = -0.761482727868857
# Offset 12184 → Imputed value = -0.6725910192454553
# Offset 12185 → Imputed value = -0.8170403982855179
# Offset 12186 → Imputed value = -0.5088955661081735
# Offset 12187 → Imputed value = -0.4429178524051986
# Offset 12188 → Imputed value = -0.5748732798111484
# Offset 12189 → Imputed value = -0.4390366445275954
# Offset 12190 → Imputed value = -0.3720486375325206
# Offset 12191 → Imputed value = -0.05922559123986857
# Offset 12192 → Imputed value = 0.026901846325227685
# Offset 12193 → Imputed value = 0.05566431394385866
# Offset 12194 → Imputed value = 0.14365237280235818
# Offset 12195 → Imputed value = 0.14365237280235818
# Offset 12196 → Imputed value = 0.08538375309099078
# Offset 12197 → Imputed value = 0.11978140635343033
# Offset 12198 → Imputed value = 0.20022033651111912
# Offset 12199 → Imputed value = 0.20883308026762865
# Offset 12200 → Imputed value = 0.12743717858143894
# Offset 12201 → Imputed value = 0.16183483184387856
# Offset 12202 → Imputed value = 0.01350424492621266
# Offset 12203 → Imputed value = -0.04588131160445249
# Offset 12204 → Imputed value = 0.09670744614220692
# Offset 12205 → Imputed value = 0.09670744614220692
# Offset 12206 → Imputed value = 0.06129949958766732
# Offset 12207 → Imputed value = 0.18288820547090198
# Offset 12208 → Imputed value = 0.06129949958766732
# Offset 12209 → Imputed value = 0.1800172908853988
# Offset 12210 → Imputed value = 0.37146491834921164
# Offset 12211 → Imputed value = 0.14173842974535603
# Offset 12212 → Imputed value = 0.11590019847582714
# Offset 12213 → Imputed value = 0.038385504667240555
# Offset 12214 → Imputed value = 0.003084201639898787
# Offset 12215 → Imputed value = -0.24955628188438359
# Offset 12216 → Imputed value = -0.3844892674030344
# Offset 12217 → Imputed value = -0.5883242029737624
# Offset 12218 → Imputed value = -0.48874584224605205
# Offset 12219 → Imputed value = -0.3797044097605292
# Offset 12220 → Imputed value = -0.6237321495283018
# Offset 12221 → Imputed value = -0.48497127789564676
# Offset 12222 → Imputed value = -0.4256390431285803
# Offset 12223 → Imputed value = -0.29267332243053057
# Offset 12224 → Imputed value = -0.2791690775043179
# Offset 12225 → Imputed value = -0.13849426281466076
# Offset 12226 → Imputed value = 0.4078831581958511
# Offset 12227 → Imputed value = 0.30070234700373144
# Offset 12228 → Imputed value = 0.19921004321901903
# Offset 12229 → Imputed value = 0.10053533225621111
# Offset 12230 → Imputed value = 0.09670744614220692
# Offset 12231 → Imputed value = 0.019246074097219158
# Offset 12232 → Imputed value = 0.019246074097219158
# Offset 12233 → Imputed value = -0.07645107875288779
# Offset 12234 → Imputed value = 0.13216871446034534
# Offset 12235 → Imputed value = 0.11696381353152589
# Offset 12236 → Imputed value = 0.06438370122756597
# Offset 12237 → Imputed value = -0.13961119963395846
# Offset 12238 → Imputed value = 0.08049225192128759
# Offset 12239 → Imputed value = 0.0
# Offset 12240 → Imputed value = 0.0
# Offset 12241 → Imputed value = 0.05178310606625545
# Offset 12242 → Imputed value = -0.092719594737406
# Offset 12243 → Imputed value = -0.016001907166523846
# Offset 12244 → Imputed value = -0.18825678229671636
# Offset 12245 → Imputed value = -0.242910802948475
# Offset 12246 → Imputed value = -0.03136677338613986
# Offset 12247 → Imputed value = -0.08304323592519754
# Offset 12248 → Imputed value = -0.1118057035438285
# Offset 12249 → Imputed value = -0.27730845621091466
# Offset 12250 → Imputed value = -0.10026872343821683
# Offset 12251 → Imputed value = -0.11366632483723178
# Offset 12252 → Imputed value = -0.07262319263888353
# Offset 12253 → Imputed value = -0.2706629772750061
# Offset 12254 → Imputed value = -0.21616892191404397
# Offset 12255 → Imputed value = -0.3481776710835926
# Offset 12256 → Imputed value = -0.4658318473256253
# Offset 12257 → Imputed value = -0.4428645306415997
# Offset 12258 → Imputed value = -0.5012397938801649
# Offset 12259 → Imputed value = -0.6418612868062233
# Offset 12260 → Imputed value = -0.30995213170714875
# Offset 12261 → Imputed value = -0.1387075498690562
# Offset 12262 → Imputed value = -0.4381863165262921
# Offset 12263 → Imputed value = -0.7835997165515792
# Offset 12264 → Imputed value = -0.8706841256451765
# Offset 12265 → Imputed value = -0.9376721326402515
# Offset 12266 → Imputed value = -0.6458491382110241
# Offset 12267 → Imputed value = -0.6228818215269984
# Offset 12268 → Imputed value = -1.6543371639603546
# Offset 12269 → Imputed value = -1.12327128740586
# Offset 12270 → Imputed value = -0.7414396475339333
# Offset 12271 → Imputed value = -0.7146444447359034
# Offset 12272 → Imputed value = -0.6209145567063975
# Offset 12273 → Imputed value = -0.42664933642068037
# Offset 12274 → Imputed value = -0.7060317009793939
# Offset 12275 → Imputed value = -0.3740692241167204
# Offset 12276 → Imputed value = -0.24774898235457926
# Offset 12277 → Imputed value = -0.15784698043907758
# Offset 12278 → Imputed value = -0.16933063878109045
# Offset 12279 → Imputed value = -0.13386937046295194
# Offset 12280 → Imputed value = 0.33318605720916883
# Offset 12281 → Imputed value = 0.2796489733767077
# Offset 12282 → Imputed value = 0.4969348321100494
# Offset 12283 → Imputed value = 0.6854582232247601
# Offset 12284 → Imputed value = 0.654835134312726
# Offset 12285 → Imputed value = 0.9304429345210338
# Offset 12286 → Imputed value = 0.7906717695962789
# Offset 12287 → Imputed value = 0.8222518300368142
# Offset 12288 → Imputed value = 0.7992845133527885
# Offset 12289 → Imputed value = 0.8682397851684645
# Offset 12290 → Imputed value = 1.22231925071386
# Offset 12291 → Imputed value = 1.0079576283296203
# Offset 12292 → Imputed value = 0.35243213130638795
# Offset 12293 → Imputed value = 0.5371276363070941
# Offset 12294 → Imputed value = 0.5266009494935826
# Offset 12295 → Imputed value = 0.7409625718778223
# Offset 12296 → Imputed value = 0.2853908025477144
# Offset 12297 → Imputed value = 0.5763634689756382
# Offset 12298 → Imputed value = 0.4815699658904333
# Offset 12299 → Imputed value = 0.16667301124998274
# Offset 12300 → Imputed value = 0.408893451487951
# Offset 12301 → Imputed value = 0.4375492755793842
# Offset 12302 → Imputed value = 0.11972808458983138
# Offset 12303 → Imputed value = 0.45387111332750135
# Offset 12304 → Imputed value = 0.18969364969760724
# Offset 12305 → Imputed value = 0.05481398594255528
# Offset 12306 → Imputed value = -0.06767836970558158
# Offset 12307 → Imputed value = -0.06097956900607415
# Offset 12308 → Imputed value = 0.050932778064952125
# Offset 12309 → Imputed value = 0.08442678156248963
# Offset 12310 → Imputed value = -0.27539451315391256
# Offset 12311 → Imputed value = -0.27252359856840924
# Offset 12312 → Imputed value = -0.816987076521919
# Offset 12313 → Imputed value = -0.9088563432580216
# Offset 12314 → Imputed value = -0.9557479481545741
# Offset 12315 → Imputed value = -0.8064603897084073
# Offset 12316 → Imputed value = -0.803589475122904
# Offset 12317 → Imputed value = -0.9174690870145314
# Offset 12318 → Imputed value = -0.7203329521433111
# Offset 12319 → Imputed value = -1.0179510975071435
# Offset 12320 → Imputed value = -0.9720164641390922
# Offset 12321 → Imputed value = -0.8112985691145115
# Offset 12322 → Imputed value = -0.9050284571440175
# Offset 12323 → Imputed value = -0.9490491474550666
# Offset 12324 → Imputed value = -0.9978546954086213
# Offset 12325 → Imputed value = -1.0246498982066512
# Offset 12326 → Imputed value = -1.1538410545542956
# Offset 12327 → Imputed value = -0.9701025210820899
# Offset 12328 → Imputed value = -0.9882849801236105
# Offset 12329 → Imputed value = -1.1720235135958155
# Offset 12330 → Imputed value = -0.9777582933100986
# Offset 12331 → Imputed value = -0.7356978183629269
# Offset 12332 → Imputed value = -0.6180436421208944
# Offset 12333 → Imputed value = -0.600818154607875
# Offset 12334 → Imputed value = -0.7452675336479377
# Offset 12335 → Imputed value = -0.8715344536464797
# Offset 12336 → Imputed value = -0.4036820197366547
# Offset 12337 → Imputed value = -0.4935840216521564
# Offset 12338 → Imputed value = -0.5490350485416196
# Offset 12339 → Imputed value = -0.446692416755604
# Offset 12340 → Imputed value = -0.5136804237506789
# Offset 12341 → Imputed value = -0.5414859198408087
# Offset 12342 → Imputed value = -0.5462174557197153
# Offset 12343 → Imputed value = -0.1644924593749862
# Offset 12344 → Imputed value = -0.0028175928219043643
# Offset 12345 → Imputed value = -0.22377137237845365
# Offset 12346 → Imputed value = -0.406552934322158
# Offset 12347 → Imputed value = -0.41521899984226646
# Offset 12348 → Imputed value = -0.4707233484953285
# Offset 12349 → Imputed value = -0.6658388967823489
# Offset 12350 → Imputed value = -0.6228284997633997
# Offset 12351 → Imputed value = -0.354929793546699
# Offset 12352 → Imputed value = -0.48598157118774665
# Offset 12353 → Imputed value = -0.22286772261355142
# Offset 12354 → Imputed value = -0.30038241642213814
# Offset 12355 → Imputed value = -0.5109161526923733
# Offset 12356 → Imputed value = -0.3587576796607033
# Offset 12357 → Imputed value = -0.627613357405905
# Offset 12358 → Imputed value = -0.6085272485994825
# Offset 12359 → Imputed value = -0.6056030122503804
# Offset 12360 → Imputed value = -0.9443709333397589
# Offset 12361 → Imputed value = -1.745249459167956
# Offset 12362 → Imputed value = -1.879225473158106
# Offset 12363 → Imputed value = -1.5854885356718769
# Offset 12364 → Imputed value = -1.4314161195832047
# Offset 12365 → Imputed value = -1.4189754897126907
# Offset 12366 → Imputed value = -1.4027069737281725
# Offset 12367 → Imputed value = -0.9214036166557331
# Offset 12368 → Imputed value = -0.9376721326402515
# Offset 12369 → Imputed value = -0.9261884742982385
# Offset 12370 → Imputed value = -1.1500664902038902
# Offset 12371 → Imputed value = -0.5644532365248344
# Offset 12372 → Imputed value = -1.0897239621447237
# Offset 12373 → Imputed value = -0.4228214503066761
# Offset 12374 → Imputed value = -0.7184190090863088
# Offset 12375 → Imputed value = -0.81895434134252
# Offset 12376 → Imputed value = -0.3932086546867418
# Offset 12377 → Imputed value = -0.7022038148653895
# Offset 12378 → Imputed value = -0.5691847724037409
# Offset 12379 → Imputed value = -0.3932086546867418
# Offset 12380 → Imputed value = -0.26688841292460064
# Offset 12381 → Imputed value = -0.4534445392187104
# Offset 12382 → Imputed value = -0.41808991442776955
# Offset 12383 → Imputed value = -0.40176807667965264
# Offset 12384 → Imputed value = -0.774880329267872
# Offset 12385 → Imputed value = -0.46965973343962963
# Offset 12386 → Imputed value = -0.37970440976052905
# Offset 12387 → Imputed value = -0.07076257134548024
# Offset 12388 → Imputed value = -0.07937531510198992
# Offset 12389 → Imputed value = -0.25923264069659213
# Offset 12390 → Imputed value = -0.4706700267317296
# Offset 12391 → Imputed value = -0.37784378846712585
# Offset 12392 → Imputed value = -0.22573863719905463
# Offset 12393 → Imputed value = -0.2678453844531018
# Offset 12394 → Imputed value = -0.46870276191112853
# Offset 12395 → Imputed value = -0.8418683362629468
# Offset 12396 → Imputed value = -0.5136804237506788
# Offset 12397 → Imputed value = -0.6370764291637181
# Offset 12398 → Imputed value = -0.6734413472467586
# Offset 12399 → Imputed value = -0.5079385945796725
# Offset 12400 → Imputed value = -0.8093313042939105
# Offset 12401 → Imputed value = -0.5749266015747473
# Offset 12402 → Imputed value = -0.8858890265739958
# Offset 12403 → Imputed value = -0.4629609327401221
# ...
# Offset 14277 → Imputed value = -0.4908197505938509
# Offset 14278 → Imputed value = -0.9338442465262473
# Offset 14279 → Imputed value = -0.4544548325108102
# Offset 14280 → Imputed value = -1.6122304167063077
# Offset 14281 → Imputed value = -0.6075702770709814
# Offset 14282 → Imputed value = -0.9127908728992237
# Offset 14283 → Imputed value = -0.5367543839619022
# Offset 14284 → Imputed value = -0.8553725811891596
# Offset 14285 → Imputed value = -0.5941726756719664
# Offset 14286 → Imputed value = -0.5348404409049001
# Offset 14287 → Imputed value = -0.5721623305164418
# Offset 14288 → Imputed value = -1.1595828837253017
# Offset 14289 → Imputed value = -0.6630213039604446
# Offset 14290 → Imputed value = -1.079250597094811
# Offset 14291 → Imputed value = -0.8974260066796077
# Offset 14292 → Imputed value = -0.5395719767838066
# Offset 14293 → Imputed value = -0.654355238440336
# Offset 14294 → Imputed value = -0.6897631849948757
# Offset 14295 → Imputed value = -0.7203862739069098
# Offset 14296 → Imputed value = -0.5845496386233568
# Offset 14297 → Imputed value = -0.6783328484164617
# Offset 14298 → Imputed value = -1.0409184141911694
# Offset 14299 → Imputed value = -0.5022500871722648
# Offset 14300 → Imputed value = -0.5758835731032483
# Offset 14301 → Imputed value = -0.6285170071708073
# Offset 14302 → Imputed value = -0.6553122099688371
# Offset 14303 → Imputed value = -0.9988116669371223
# Offset 14304 → Imputed value = -0.7261281030779163
# Offset 14305 → Imputed value = -0.19995372769312464
# Offset 14306 → Imputed value = -0.6333551865769114
# Offset 14307 → Imputed value = -0.5337768258492013
# Offset 14308 → Imputed value = -0.31569396087815516
# Offset 14309 → Imputed value = -0.38938076857273757
# Offset 14310 → Imputed value = -0.3204254967570616
# Offset 14311 → Imputed value = -0.3233497331061638
# Offset 14312 → Imputed value = -0.13487966375505195
# Offset 14313 → Imputed value = -0.1454063505685637
# Offset 14314 → Imputed value = -0.27837207126661345
# Offset 14315 → Imputed value = -0.21526527214914176
# Offset 14316 → Imputed value = -0.23435138095556426
# Offset 14317 → Imputed value = -0.5826356955663547
# Offset 14318 → Imputed value = -0.5615290001757323
# Offset 14319 → Imputed value = -0.3931553329231429
# Offset 14320 → Imputed value = -0.27837207126661345
# Offset 14321 → Imputed value = -0.3606716227177055
# Offset 14322 → Imputed value = -0.5960332969653697
# Offset 14323 → Imputed value = -0.46211060473881876
# Offset 14324 → Imputed value = -0.35014493590419365
# Offset 14325 → Imputed value = -0.7423966190624344
# Offset 14326 → Imputed value = -0.8065137114720061
# Offset 14327 → Imputed value = -0.3109091032356498
# Offset 14328 → Imputed value = -0.18751309782261075
# Offset 14329 → Imputed value = -0.5060779732862691
# Offset 14330 → Imputed value = -0.4697663769668273
# Offset 14331 → Imputed value = -0.6295273004629072
# Offset 14332 → Imputed value = -0.7462245051764388
# Offset 14333 → Imputed value = -0.28507087196612096
# Offset 14334 → Imputed value = -0.35780070813220227
# Offset 14335 → Imputed value = -0.5635495867599322
# Offset 14336 → Imputed value = -0.5578077575889256
# Offset 14337 → Imputed value = -0.6428182583347243
# Offset 14338 → Imputed value = -0.19697616958042372
# Offset 14339 → Imputed value = -0.05061284748335896
# Offset 14340 → Imputed value = -0.46588516908922417
# Offset 14341 → Imputed value = -0.3185648754636584
# Offset 14342 → Imputed value = -0.5510556351258196
# Offset 14343 → Imputed value = -0.326220647691667
# Offset 14344 → Imputed value = -0.5242071105641907
# Offset 14345 → Imputed value = -0.2812429858521167
# Offset 14346 → Imputed value = -0.42473539336367827
# Offset 14347 → Imputed value = -0.5289919682066959
# Offset 14348 → Imputed value = -0.624689121056803
# Offset 14349 → Imputed value = -0.7701487933889655
# Offset 14350 → Imputed value = -0.6715807259533554
# Offset 14351 → Imputed value = -0.586463581680359
# Offset 14352 → Imputed value = -0.4993791725867617
# Offset 14353 → Imputed value = -0.2965545303081338
# Offset 14354 → Imputed value = -0.5892811745022632
# Offset 14355 → Imputed value = -0.6285170071708072
# Offset 14356 → Imputed value = -0.44578876699070175
# Offset 14357 → Imputed value = -0.31856487546365836
# Offset 14358 → Imputed value = -0.30995213170714875
# Offset 14359 → Imputed value = -0.15306212279657222
# Offset 14360 → Imputed value = -0.15210515126807117
# Offset 14361 → Imputed value = -0.3185648754636584
# Offset 14362 → Imputed value = -0.25343748976198677
# Offset 14363 → Imputed value = -0.35764074284140557
# Offset 14364 → Imputed value = -0.3232430895789659
# Offset 14365 → Imputed value = -0.6840213558238692
# Offset 14366 → Imputed value = -0.2831569289091188
# Offset 14367 → Imputed value = -0.1013856602575145
# Offset 14368 → Imputed value = -0.3816716745811301
# Offset 14369 → Imputed value = -0.37592984541012375
# Offset 14370 → Imputed value = 0.0
# Offset 14371 → Imputed value = -0.19516887005061928
# Offset 14372 → Imputed value = -0.13487966375505195
# Offset 14373 → Imputed value = -0.3750261956452215
# Offset 14374 → Imputed value = -0.4103808204361622
# Offset 14375 → Imputed value = -0.6151194057717921
# Offset 14376 → Imputed value = -0.8036427968865029
# Offset 14377 → Imputed value = -0.38650985398723436
# Offset 14378 → Imputed value = -0.4008644269147504
# Offset 14379 → Imputed value = -0.3999074553862493
# Offset 14380 → Imputed value = -0.546270777483314
# Offset 14381 → Imputed value = -0.27932904279511456
# Offset 14382 → Imputed value = -0.5070349448147702
# Offset 14383 → Imputed value = -0.6017751261363761
# Offset 14384 → Imputed value = -0.9088563432580218
# Offset 14385 → Imputed value = -0.6400539872764189
# Offset 14386 → Imputed value = -0.6859886206444702
# Offset 14387 → Imputed value = -0.4467990602828017
# Offset 14388 → Imputed value = -0.23052349484155998
# Offset 14389 → Imputed value = -0.4381863165262921
# Offset 14390 → Imputed value = -0.46301425450372113
# Offset 14391 → Imputed value = -0.40660625608575673
# Offset 14392 → Imputed value = -0.019086108806422506
# Offset 14393 → Imputed value = -0.42765962971278026
# Offset 14394 → Imputed value = -0.40852019914275883
# Offset 14395 → Imputed value = -0.44100390934819644
# Offset 14396 → Imputed value = -1.0122092683361372
# Offset 14397 → Imputed value = -0.6868389486457736
# Offset 14398 → Imputed value = -0.47922944872464035
# Offset 14399 → Imputed value = -0.7682348503319634
# Offset 14400 → Imputed value = -0.15880395196757865
# Offset 14401 → Imputed value = -0.4371760232341922
# Offset 14402 → Imputed value = -0.2859745217310231
# Offset 14403 → Imputed value = -0.31851155370005946
# Offset 14404 → Imputed value = -0.6581831245543402
# Offset 14405 → Imputed value = -0.3807147030526291
# Offset 14406 → Imputed value = -0.32802794722147127
# Offset 14407 → Imputed value = -0.3117594312369532
# Offset 14408 → Imputed value = -0.21797622144384832
# Offset 14409 → Imputed value = -0.09458021603080928
# Offset 14410 → Imputed value = 0.00781573751880511
# Offset 14411 → Imputed value = -0.011430336578413976
# Offset 14412 → Imputed value = -0.01238730810691506
# Offset 14413 → Imputed value = -0.1549760658535744
# Offset 14414 → Imputed value = 0.0
# Offset 14415 → Imputed value = -0.19607251981552154
# Offset 14416 → Imputed value = 0.0
# Offset 14417 → Imputed value = 0.0
# Offset 14418 → Imputed value = 0.0
# Offset 14419 → Imputed value = 0.0
# Offset 14420 → Imputed value = -0.1731585248950947
# Offset 14421 → Imputed value = -0.0821929079238943
# Offset 14422 → Imputed value = -0.28698481502312306
# Offset 14423 → Imputed value = -0.34046857709198525
# Offset 14424 → Imputed value = -0.6906668347597779
# Offset 14425 → Imputed value = -0.8409113647344458
# Offset 14426 → Imputed value = -0.9299097168850452
# Offset 14427 → Imputed value = -0.6553122099688371
# Offset 14428 → Imputed value = -0.6304309502278093
# Offset 14429 → Imputed value = -0.7318166104853239
# Offset 14430 → Imputed value = -0.6332485430497137
# Offset 14431 → Imputed value = -0.7394723827133325
# Offset 14432 → Imputed value = -0.5595617353551313
# Offset 14433 → Imputed value = -0.6409043152777223
# Offset 14434 → Imputed value = -0.5538199061841249
# Offset 14435 → Imputed value = -0.6992795785162874
# Offset 14436 → Imputed value = -0.27635148468241366
# Offset 14437 → Imputed value = 0.02121333891782008
# Offset 14438 → Imputed value = -0.24003988836297188
# Offset 14439 → Imputed value = -0.17411549642359578
# Offset 14440 → Imputed value = -0.32999521204207233
# Offset 14441 → Imputed value = -0.1443960572764637
# Offset 14442 → Imputed value = 0.0
# Offset 14443 → Imputed value = 0.0
# Offset 14444 → Imputed value = 0.0
# Offset 14445 → Imputed value = -0.01238730810691506
# Offset 14446 → Imputed value = -0.01238730810691506
# Offset 14447 → Imputed value = -0.01238730810691506
# Offset 14448 → Imputed value = -0.01238730810691506
# Offset 14449 → Imputed value = -0.07549410722438678
# Offset 14450 → Imputed value = -0.08889170862340173
# Offset 14451 → Imputed value = -0.07453713569588569
# Offset 14452 → Imputed value = -0.01238730810691506
# Offset 14453 → Imputed value = 0.0
# Offset 14454 → Imputed value = 0.0
# Offset 14455 → Imputed value = 0.0
# Offset 14456 → Imputed value = 0.0
# Offset 14457 → Imputed value = 0.0
# Offset 14458 → Imputed value = 0.09096561697120041
# Offset 14459 → Imputed value = 0.09096561697120041
# Offset 14460 → Imputed value = 0.09096561697120041
# Offset 14461 → Imputed value = 0.09096561697120041
# Offset 14462 → Imputed value = 0.0
# Offset 14463 → Imputed value = -0.3892741250455398
# Offset 14464 → Imputed value = -0.4791761269610415
# Offset 14465 → Imputed value = -0.7672245570398634
# Offset 14466 → Imputed value = -0.6419146085698222
# Offset 14467 → Imputed value = -0.554776877712626
# Offset 14468 → Imputed value = -0.7299026674283218
# Offset 14469 → Imputed value = -0.3654031585966119
# Offset 14470 → Imputed value = -0.42080086372247616
# Offset 14471 → Imputed value = -0.5194755746852842
# Offset 14472 → Imputed value = -0.4706700267317296
# Offset 14473 → Imputed value = -0.11669720471353162
# Offset 14474 → Imputed value = -0.4113911137282621
# Offset 14475 → Imputed value = -0.5692380941673398
# Offset 14476 → Imputed value = -0.4467457385192028
# Offset 14477 → Imputed value = -0.43239116559168683
# Offset 14478 → Imputed value = -0.1664064024319884
# Offset 14479 → Imputed value = -0.6581831245543404
# Offset 14480 → Imputed value = -0.749999069526844
# Offset 14481 → Imputed value = -0.611291519657788
# Offset 14482 → Imputed value = -0.66679586831085
# Offset 14483 → Imputed value = -0.9366085175845527
# Offset 14484 → Imputed value = -0.6821607345304659
# Offset 14485 → Imputed value = -0.2735872136241081
# Offset 14486 → Imputed value = -0.16257851631798403
# Offset 14487 → Imputed value = -0.4256923648921793
# Offset 14488 → Imputed value = -0.4400469378196954
# Offset 14489 → Imputed value = -0.1798040038310033
# Offset 14490 → Imputed value = -0.21425497885704176
# Offset 14491 → Imputed value = -0.019086108806422506
# Offset 14492 → Imputed value = -0.10707416766492206
# Offset 14493 → Imputed value = -0.14349240751156153
# Offset 14494 → Imputed value = -0.21425497885704176
# Offset 14495 → Imputed value = -0.202771320515029
# Offset 14496 → Imputed value = -0.26688841292460064
# Offset 14497 → Imputed value = -0.40469231302875464
# Offset 14498 → Imputed value = -0.6400539872764188
# Offset 14499 → Imputed value = -0.6745049623024574
# Offset 14500 → Imputed value = -0.9347478962911495
# Offset 14501 → Imputed value = -0.6515376456184316
# Offset 14502 → Imputed value = -0.4334014588837867
# Offset 14503 → Imputed value = -0.6323982150484103
# Offset 14504 → Imputed value = -0.5682811226388387
# Offset 14505 → Imputed value = -0.49268037188725416
# Offset 14506 → Imputed value = -0.4353154019407889
# Offset 14507 → Imputed value = -0.07841834357348884
# Offset 14508 → Imputed value = -0.04779525466145459
# Offset 14509 → Imputed value = 0.0
# Offset 14510 → Imputed value = -0.04779525466145459
# Offset 14511 → Imputed value = -0.25636172611108893
# Offset 14512 → Imputed value = -0.38363893940173116
# Offset 14513 → Imputed value = -0.4658851690892242
# Offset 14514 → Imputed value = -0.2085664714496343
# Offset 14515 → Imputed value = -0.6266563858774038
# Offset 14516 → Imputed value = -0.22765258025605672
# Offset 14517 → Imputed value = -0.3155873173509574
# Offset 14518 → Imputed value = -0.5949696819096708
# Offset 14519 → Imputed value = -0.6055496904867815
# Offset 14520 → Imputed value = -0.6716340477169542
# Offset 14521 → Imputed value = -0.48890580753684876
# Offset 14522 → Imputed value = -0.5798181027444503
# Offset 14523 → Imputed value = -0.4678524339098253
# Offset 14524 → Imputed value = -0.41426202831376535
# Offset 14525 → Imputed value = -1.0151335046852392
# Offset 14526 → Imputed value = -1.1596362054889007
# Offset 14527 → Imputed value = -0.46593849085282313
# Offset 14528 → Imputed value = -0.49273369365085296
# Offset 14529 → Imputed value = -0.4879488360083476
# Offset 14530 → Imputed value = -0.5874205532088601
# Offset 14531 → Imputed value = -0.28219995738061776
# Offset 14532 → Imputed value = -0.06980559981697923
# Offset 14533 → Imputed value = -0.3013393879506392
# Offset 14534 → Imputed value = -0.24966292541158136
# Offset 14535 → Imputed value = -0.2783720712666135
# Offset 14536 → Imputed value = -0.07841834357348884
# Offset 14537 → Imputed value = -0.26497446986759854
# Offset 14538 → Imputed value = -0.2678453844531017
# Offset 14539 → Imputed value = -0.07841834357348884
# Offset 14540 → Imputed value = -0.0659777137029749
# Offset 14541 → Imputed value = -0.18368521170860647
# Offset 14542 → Imputed value = -0.4639712260322222
# Offset 14543 → Imputed value = -0.4984755228218594
# Offset 14544 → Imputed value = -0.5950763254368686
# Offset 14545 → Imputed value = -0.6467527879759263
# Offset 14546 → Imputed value = -0.6362261011624145
# Offset 14547 → Imputed value = -0.5042173519928659
# Offset 14548 → Imputed value = -0.6802467914734638
# Offset 14549 → Imputed value = -0.6419679303334209
# Offset 14550 → Imputed value = -0.6084739268358836
# Offset 14551 → Imputed value = -0.6314412435199092
# Offset 14552 → Imputed value = -0.4075632276142578
# Offset 14553 → Imputed value = -0.6486667310329285
# Offset 14554 → Imputed value = -0.6036890691933782
# Offset 14555 → Imputed value = -0.4200038574847718
# Offset 14556 → Imputed value = -0.6419679303334211
# Offset 14557 → Imputed value = -0.20760949992113323
# Offset 14558 → Imputed value = -0.4133050567852643
# Offset 14559 → Imputed value = -0.7529233058759461
# Offset 14560 → Imputed value = -0.5759368948668472
# Offset 14561 → Imputed value = -0.6582364463179393
# Offset 14562 → Imputed value = -0.44961665310470594
# Offset 14563 → Imputed value = -0.4333481371201879
# Offset 14564 → Imputed value = -0.38363893940173116
# Offset 14565 → Imputed value = -0.34344613520468625
# Offset 14566 → Imputed value = -0.3673704234172129
# Offset 14567 → Imputed value = -0.5424428913693098
# Offset 14568 → Imputed value = -0.6228284997633997
# Offset 14569 → Imputed value = -0.6371830726909157
# Offset 14570 → Imputed value = -0.7568045137535492
# Offset 14571 → Imputed value = -0.5749799233383461
# Offset 14572 → Imputed value = -0.7835463947879804
# Offset 14573 → Imputed value = -0.4802397420167403
# Offset 14574 → Imputed value = -0.6122484911862889
# Offset 14575 → Imputed value = -0.1454063505685637
# Offset 14576 → Imputed value = -0.16071789502458084
# Offset 14577 → Imputed value = -0.22005012979164712
# Offset 14578 → Imputed value = -0.49172340035875306
# Offset 14579 → Imputed value = -0.8543622878970597
# Offset 14580 → Imputed value = -0.34440310673318725
# Offset 14581 → Imputed value = -0.6294739786993082
# Offset 14582 → Imputed value = -0.3740692241167205
# Offset 14583 → Imputed value = -0.22292104437715038
# Offset 14584 → Imputed value = -0.6295273004629072
# Offset 14585 → Imputed value = -0.616129699063892
# Offset 14586 → Imputed value = -0.3970365408007461
# Offset 14587 → Imputed value = -0.4410572311117954
# Offset 14588 → Imputed value = -0.6410109588049199
# Offset 14589 → Imputed value = -0.4314875158267847
# Offset 14590 → Imputed value = -0.42191780054177397
# Offset 14591 → Imputed value = -0.22387801590565135
# Offset 14592 → Imputed value = -0.22387801590565135

# %% [markdown]
# # ---------------------------------------------------------
# # 🔹 STEP 5: Evaluating all imputation methods (END Block)
# # ---------------------------------------------------------

# %%
results_block = []

# 🎯 True values for the missing block
true_vals = true_target_array[start_idx:end_idx]
missing_indices = np.arange(start_idx, end_idx)

# ✅ Helper to evaluate predictions against true values

def evaluate_direct(name, imputed_array):
    try:
        predicted = imputed_array[start_idx:end_idx]
        
        # Core Errors
        mae = np.mean(np.abs(predicted - true_vals))
        rmse = np.sqrt(np.mean((predicted - true_vals) ** 2))
        me = np.mean(predicted - true_vals)  # Mean Error (signed)

        # Bias-Variance
        bias = np.mean(predicted) - np.mean(true_vals)
        bias_sq = bias ** 2
        variance = np.mean((predicted - np.mean(predicted)) ** 2)

        results_block.append({
            "Method": name,
            "MAE": round(mae, 4),
            "RMSE": round(rmse, 4),
            "ME": round(me, 4),
            "Bias^2": round(bias_sq, 4),
            "Variance": round(variance, 4),
            "First Imputed": round(predicted[0], 4),
            "Last Imputed": round(predicted[-1], 4),
            "First True": round(true_vals[0], 4),
            "Last True": round(true_vals[-1], 4),
            "Missing Block": "END"
        })
    except Exception as e:
        results_block.append({
            "Method": name,
            "MAE": "NaN",
            "RMSE": "NaN",
            "ME": "NaN",
            "Bias^2": "NaN",
            "Variance": "NaN",
            "First Imputed": "NaN",
            "Last Imputed": "NaN",
            "First True": round(true_vals[0], 4),
            "Last True": round(true_vals[-1], 4),
            "Missing Block": "END"
        })

# ✅ TKCM (loop over all missing indices)
try:
    tkcm_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_imputed = TKCM(k=k, l=l).impute(tkcm_imputed, offset=offset, ref_ts=ref_matrix)
    evaluate_direct("TKCM", tkcm_imputed)
except Exception as e:
    print(" TKCM failed:", e)
    evaluate_direct("TKCM", np.full_like(true_vals, np.nan))
    
# ✅ TKCM_PLUS (loop over all missing indices)
try:
    tkcm_plus_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_plus_imputed = TKCM_PLUS(k=k, l=l, alpha=0.5, beta=0.5).impute(
            tkcm_plus_imputed, offset=offset, ref_ts=ref_matrix
        )
    evaluate_direct("TKCM_PLUS", tkcm_plus_imputed)
except Exception as e:
    print(" TKCM_PLUS failed:", e)
    evaluate_direct("TKCM_PLUS", np.full_like(true_vals, np.nan))


# ✅ TKCM_Weighted (loop over all missing indices)
try:
    tkcm_weighted_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_weighted_imputed = TKCM_Weighted(k=k, l=l).impute(tkcm_weighted_imputed, offset=offset, ref_ts=ref_matrix)
    evaluate_direct("TKCM_Weighted", tkcm_weighted_imputed)
except Exception as e:
    print(" TKCM_Weighted failed:", e)
    evaluate_direct("TKCM_Weighted", np.full_like(true_vals, np.nan))
    
# ✅ TKCM_PRO (loop over all missing indices)
try:
    tkcm_pro_imputed = masked_target_array.copy()
    for offset in missing_indices:
        tkcm_pro_imputed = TKCM_PRO(k=k, l=l).impute(
            tkcm_pro_imputed, offset=offset, ref_ts=ref_matrix
        )
    evaluate_direct("TKCM_PRO", tkcm_pro_imputed)
except Exception as e:
    print(" TKCM_PRO failed:", e)
    evaluate_direct("TKCM_PRO", np.full_like(true_vals, np.nan))
    



# ✅ Other models (no change needed)
evaluate_direct("CDRec", cdrec_imputed)
evaluate_direct("DynaMMo", dynammo_imputed)
evaluate_direct("SoftImpute", soft_imputed)
evaluate_direct("SVDImpute", svd_imputed)

# ✅ ST_MVL — remove NaNs from references
try:
    X_stmv = X_stacked.copy()
    X_stmv[1:, :] = np.nan_to_num(X_stmv[1:, :])
    st_mvl_model = ST_MVL()
    st_mvl_imputed = st_mvl_model.impute(X_stmv)[0]
    evaluate_direct("ST_MVL", st_mvl_imputed)
except Exception as e:
    print(" ST_MVL failed:", e)
    evaluate_direct("ST_MVL", np.full_like(true_vals, np.nan))

# ✅ TRMF — fixed implementation
try:
    X_trmf_input = X_stacked.T.copy()
    observed_mask = ~np.isnan(X_stacked.T)
    X_trmf_input = np.nan_to_num(X_trmf_input, nan=0.0).astype(np.float64)
    trmf_model = TRMFImputer(rank=rank, lag_idx=[1, 2, 3])
    trmf_model.fit(X_trmf_input, observed_mask)
    X_trmf_output = trmf_model.transform()
    trmf_imputed = X_trmf_output[:, 0]
    evaluate_direct("TRMF", trmf_imputed)
except Exception as e:
    print(" TRMF failed:", e)
    evaluate_direct("TRMF", np.full_like(true_vals, np.nan))
    
evaluate_direct("Zero", zero_imputed)
evaluate_direct("Min", min_imputed)
evaluate_direct("Interpolation", interp_imputed)


# ✅ Final Results Display
results_df = pd.DataFrame(results_block)
display(results_df.style.background_gradient(cmap="YlGnBu", subset=["MAE", "RMSE", "ME", "Bias^2", "Variance"]))
# Out:
# <style type="text/css">
# #T_3dbdf_row0_col1, #T_3dbdf_row2_col1 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_3dbdf_row0_col2 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_3dbdf_row0_col3 {
#   background-color: #0d2163;
#   color: #f1f1f1;
# }
# #T_3dbdf_row0_col4, #T_3dbdf_row1_col5, #T_3dbdf_row2_col4, #T_3dbdf_row3_col4, #T_3dbdf_row4_col1, #T_3dbdf_row4_col2, #T_3dbdf_row4_col4, #T_3dbdf_row5_col1, #T_3dbdf_row5_col4, #T_3dbdf_row6_col1, #T_3dbdf_row6_col2, #T_3dbdf_row6_col4, #T_3dbdf_row7_col1, #T_3dbdf_row7_col4, #T_3dbdf_row8_col4, #T_3dbdf_row10_col5, #T_3dbdf_row11_col3, #T_3dbdf_row11_col5, #T_3dbdf_row12_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_3dbdf_row0_col5, #T_3dbdf_row2_col5, #T_3dbdf_row9_col1 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_3dbdf_row1_col1, #T_3dbdf_row10_col1 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_3dbdf_row1_col2, #T_3dbdf_row10_col2 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_3dbdf_row1_col3, #T_3dbdf_row3_col5, #T_3dbdf_row10_col3, #T_3dbdf_row11_col1, #T_3dbdf_row11_col2, #T_3dbdf_row11_col4 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_3dbdf_row1_col4, #T_3dbdf_row5_col2, #T_3dbdf_row7_col2, #T_3dbdf_row9_col4, #T_3dbdf_row10_col4 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_3dbdf_row2_col2 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_3dbdf_row2_col3, #T_3dbdf_row4_col3, #T_3dbdf_row5_col3, #T_3dbdf_row6_col3, #T_3dbdf_row7_col3 {
#   background-color: #0e2265;
#   color: #f1f1f1;
# }
# #T_3dbdf_row3_col1 {
#   background-color: #259ac1;
#   color: #f1f1f1;
# }
# #T_3dbdf_row3_col2 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_3dbdf_row3_col3 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
# }
# #T_3dbdf_row4_col5, #T_3dbdf_row5_col5 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_3dbdf_row6_col5 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_3dbdf_row7_col5, #T_3dbdf_row12_col5 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_3dbdf_row8_col1 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_3dbdf_row8_col2 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_3dbdf_row8_col3 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_3dbdf_row8_col5 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_3dbdf_row9_col2 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_3dbdf_row9_col3 {
#   background-color: #0a1e5c;
#   color: #f1f1f1;
# }
# #T_3dbdf_row9_col5 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_3dbdf_row12_col1 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_3dbdf_row12_col2 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_3dbdf_row12_col3 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3dbdf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dbdf_level0_col0" class="col_heading level0 col0" >Method</th>
#       <th id="T_3dbdf_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3dbdf_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3dbdf_level0_col3" class="col_heading level0 col3" >ME</th>
#       <th id="T_3dbdf_level0_col4" class="col_heading level0 col4" >Bias^2</th>
#       <th id="T_3dbdf_level0_col5" class="col_heading level0 col5" >Variance</th>
#       <th id="T_3dbdf_level0_col6" class="col_heading level0 col6" >First Imputed</th>
#       <th id="T_3dbdf_level0_col7" class="col_heading level0 col7" >Last Imputed</th>
#       <th id="T_3dbdf_level0_col8" class="col_heading level0 col8" >First True</th>
#       <th id="T_3dbdf_level0_col9" class="col_heading level0 col9" >Last True</th>
#       <th id="T_3dbdf_level0_col10" class="col_heading level0 col10" >Missing Block</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dbdf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3dbdf_row0_col0" class="data row0 col0" >TKCM</td>
#       <td id="T_3dbdf_row0_col1" class="data row0 col1" >0.408300</td>
#       <td id="T_3dbdf_row0_col2" class="data row0 col2" >0.507900</td>
#       <td id="T_3dbdf_row0_col3" class="data row0 col3" >0.133100</td>
#       <td id="T_3dbdf_row0_col4" class="data row0 col4" >0.017700</td>
#       <td id="T_3dbdf_row0_col5" class="data row0 col5" >0.507300</td>
#       <td id="T_3dbdf_row0_col6" class="data row0 col6" >1.318000</td>
#       <td id="T_3dbdf_row0_col7" class="data row0 col7" >-0.675100</td>
#       <td id="T_3dbdf_row0_col8" class="data row0 col8" >1.354400</td>
#       <td id="T_3dbdf_row0_col9" class="data row0 col9" >-0.746200</td>
#       <td id="T_3dbdf_row0_col10" class="data row0 col10" >END</td>
#     </tr>
#     <tr>
#       <th id="T_3dbdf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3dbdf_row1_col0" class="data row1 col0" >TKCM_PLUS</td>
#       <td id="T_3dbdf_row1_col1" class="data row1 col1" >0.724300</td>
#       <td id="T_3dbdf_row1_col2" class="data row1 col2" >0.867700</td>
#       <td id="T_3dbdf_row1_col3" class="data row1 col3" >0.205600</td>
#       <td id="T_3dbdf_row1_col4" class="data row1 col4" >0.042300</td>
#       <td id="T_3dbdf_row1_col5" class="data row1 col5" >0.000600</td>
#       <td id="T_3dbdf_row1_col6" class="data row1 col6" >0.528500</td>
#       <td id="T_3dbdf_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_3dbdf_row1_col8" class="data row1 col8" >1.354400</td>
#       <td id="T_3dbdf_row1_col9" class="data row1 col9" >-0.746200</td>
#       <td id="T_3dbdf_row1_col10" class="data row1 col10" >END</td>
#     </tr>
#     <tr>
#       <th id="T_3dbdf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3dbdf_row2_col0" class="data row2 col0" >TKCM_Weighted</td>
#       <td id="T_3dbdf_row2_col1" class="data row2 col1" >0.410800</td>
#       <td id="T_3dbdf_row2_col2" class="data row2 col2" >0.512700</td>
#       <td id="T_3dbdf_row2_col3" class="data row2 col3" >0.132000</td>
#       <td id="T_3dbdf_row2_col4" class="data row2 col4" >0.017400</td>
#       <td id="T_3dbdf_row2_col5" class="data row2 col5" >0.507300</td>
#       <td id="T_3dbdf_row2_col6" class="data row2 col6" >1.323100</td>
#       <td id="T_3dbdf_row2_col7" class="data row2 col7" >-0.647800</td>
#       <td id="T_3dbdf_row2_col8" class="data row2 col8" >1.354400</td>
#       <td id="T_3dbdf_row2_col9" class="data row2 col9" >-0.746200</td>
#       <td id="T_3dbdf_row2_col10" class="data row2 col10" >END</td>
#     </tr>
#     <tr>
#       <th id="T_3dbdf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3dbdf_row3_col0" class="data row3 col0" >TKCM_PRO</td>
#       <td id="T_3dbdf_row3_col1" class="data row3 col1" >1.618000</td>
#       <td id="T_3dbdf_row3_col2" class="data row3 col2" >1.896800</td>
#       <td id="T_3dbdf_row3_col3" class="data row3 col3" >-0.064300</td>
#       <td id="T_3dbdf_row3_col4" class="data row3 col4" >0.004100</td>
#       <td id="T_3dbdf_row3_col5" class="data row3 col5" >6.740400</td>
#       <td id="T_3dbdf_row3_col6" class="data row3 col6" >4.328100</td>
#       <td id="T_3dbdf_row3_col7" class="data row3 col7" >-2.407500</td>
#       <td id="T_3dbdf_row3_col8" class="data row3 col8" >1.354400</td>
#       <td id="T_3dbdf_row3_col9" class="data row3 col9" >-0.746200</td>
#       <td id="T_3dbdf_row3_col10" class="data row3 col10" >END</td>
#     </tr>
#     <tr>
#       <th id="T_3dbdf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3dbdf_row4_col0" class="data row4 col0" >CDRec</td>
#       <td id="T_3dbdf_row4_col1" class="data row4 col1" >0.358400</td>
#       <td id="T_3dbdf_row4_col2" class="data row4 col2" >0.447800</td>
#       <td id="T_3dbdf_row4_col3" class="data row4 col3" >0.127400</td>
#       <td id="T_3dbdf_row4_col4" class="data row4 col4" >0.016200</td>
#       <td id="T_3dbdf_row4_col5" class="data row4 col5" >0.824200</td>
#       <td id="T_3dbdf_row4_col6" class="data row4 col6" >1.505300</td>
#       <td id="T_3dbdf_row4_col7" class="data row4 col7" >-0.808300</td>
#       <td id="T_3dbdf_row4_col8" class="data row4 col8" >1.354400</td>
#       <td id="T_3dbdf_row4_col9" class="data row4 col9" >-0.746200

# %%
# ---------------------------------------------------------
# 📊 Plot Imputation Comparison Across Algorithms
# ---------------------------------------------------------

# Build dictionary of series (true + masked + all imputations)
imputed_data = {
    "True": true_target_array,
    "Masked": masked_target_array,
    "TKCM": tkcm_imputed,
    "TKCM_Weighted": tkcm_weighted_imputed,
    "TKCM_PLUS": tkcm_plus_imputed,
    "TKCM_PRO": tkcm_pro_imputed,
    "CDRec": cdrec_imputed,
    "DynaMMo": dynammo_imputed,
    "SoftImpute": soft_imputed,
    "SVDImpute": svd_imputed,
    "ST_MVL": st_mvl_imputed,
    "TRMF": trmf_imputed,
    "Zero": zero_imputed,
    "Min": min_imputed,
    "Interpolation": interp_imputed
}

# Create time axis from dataframe index
time = np.arange(len(true_target_array))

# Plotting
fig, ax = plt.subplots(figsize=(16, 8))

for method, series in imputed_data.items():
    linestyle = "-" if method == "True" else "--"
    linewidth = 2 if method == "True" else 1.5
    ax.plot(time, series, label=method, linestyle=linestyle, linewidth=linewidth)

# Highlight missing block
ax.axvspan(start_idx, end_idx, color="gray", alpha=0.2, label="Missing Block")

ax.set_title("Imputation Comparison Across Algorithms", fontsize=14)
ax.set_xlabel("Time", fontsize=12)
ax.set_ylabel("Sensor Value", fontsize=12)
ax.grid(True, alpha=0.3)
ax.legend(loc="best", fontsize=9)
fig.tight_layout()


import os

# Ensure output folder exists
os.makedirs("plots", exist_ok=True)

# Save high-resolution PDF & PNG
fig.savefig("plots/valley_end_block_comparison_1month.pdf", format="pdf", dpi=300, bbox_inches="tight")
fig.savefig("plots/valley_end_block_comparison_1month.png", format="png", dpi=300, bbox_inches="tight")

plt.show()

# %%
from matplotlib.ticker import MaxNLocator

def plot_zoom_last_block(true_target_array,
                         masked_target_array,
                         series_dict,
                         start_idx, end_idx,
                         pad=200,
                         out_base="plots/valley_end_block_zoom"):
    """
    Zooms into the missing block at the end of the series.
    - series_dict: {"MethodName": imputed_array, ...} (no True/Masked in dict)
    - pad: how many points of context to show before the block
    """
    os.makedirs(os.path.dirname(out_base), exist_ok=True)

    # window indices (safe bounds)
    n = len(true_target_array)
    i0 = max(0, start_idx - pad)
    i1 = min(n, end_idx + pad)

    t = np.arange(i0, i1)

    fig, ax = plt.subplots(figsize=(16, 6))
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.yaxis.set_major_locator(MaxNLocator(nbins=6))
    ax.grid(True, alpha=0.25)

    # main series
    ax.plot(t, true_target_array[i0:i1], label="True", linewidth=2.4)
    ax.plot(t, masked_target_array[i0:i1], "--", label="Masked", linewidth=2.0)

    # imputations
    for name, arr in series_dict.items():
        ax.plot(t, arr[i0:i1], "--", linewidth=1.6, label=name)

    # highlight the missing block
    ax.axvspan(start_idx, end_idx, color="0.8", alpha=0.35, label="Missing Block")

    ax.set_title("Zoomed View: End-Block Imputation Comparison")
    ax.set_xlabel("Time")
    ax.set_ylabel("Sensor Value")

    ax.legend(loc="upper left", ncol=2, frameon=True, framealpha=0.9, fontsize=9)
    fig.tight_layout()

    fig.savefig(f"{out_base}.pdf")
    fig.savefig(f"{out_base}.png", dpi=300)
    plt.show()
    plt.close(fig)

# call with your arrays
series_dict_zoom = {
    "TKCM": tkcm_imputed,
    "TKCM_Weighted": tkcm_weighted_imputed,
    "TKCM_PLUS": tkcm_plus_imputed,
    "TKCM_PRO": tkcm_pro_imputed,
    "CDRec": cdrec_imputed,
    "DynaMMo": dynammo_imputed,
    "SoftImpute": soft_imputed,
    "SVDImpute": svd_imputed,
    "ST_MVL": st_mvl_imputed,
    "TRMF": trmf_imputed,
    "Zero": zero_imputed,
    "Min": min_imputed,
    "Interpolation": interp_imputed,
}

plot_zoom_last_block(
    true_target_array=true_target_array,
    masked_target_array=masked_target_array,
    series_dict=series_dict_zoom,
    start_idx=start_idx,
    end_idx=end_idx,
    pad=200,  # adjust for more/less context
    out_base="plots/valley_end_block_zoom_1month"
)

# %%
# Check the shape of each series in imputed_data to find the mismatch
series_shapes = {k: np.array(v).shape for k, v in imputed_data.items()}
series_shapes_df = pd.DataFrame(list(series_shapes.items()), columns=["Method", "Shape"])

series_shapes_df
# Out:
#            Method     Shape
# 0            True  (14593,)
# 1          Masked  (14593,)
# 2            TKCM  (14593,)
# 3   TKCM_Weighted  (14593,)
# 4       TKCM_PLUS  (14593,)
# 5        TKCM_PRO  (14593,)
# 6           CDRec  (14593,)
# 7         DynaMMo  (14593,)
# 8      SoftImpute  (14593,)
# 9       SVDImpute  (14593,)
# 10         ST_MVL  (14593,)
# 11           TRMF  (14593,)
# 12           Zero  (14593,)
# 13            Min  (14593,)
# 14  Interpolation  (14593,)

# %%
linestyles = {
    "TKCM": "-",
    "TKCM_Weighted": "-.",
    "TKCM_PLUS": "-",
    "TKCM_PRO": "-.",
    "CDRec": "--",
    "DynaMMo": "--",
    "SoftImpute": "--",
    "SVDImpute": "--",
    "ST_MVL": "-",
    "TRMF": "--",
    "True": "-",
    "Masked": ":"
}

colors = {
    "TKCM": "#1f77b4",
    "TKCM_Weighted": "#ff7f0e",
    "TKCM_PLUS": "#8c564b",
    "TKCM_PRO": "#7f7f7f",
    "CDRec": "#17becf",
    "DynaMMo": "#1a55FF",
    "SoftImpute": "#FF55AA",
    "SVDImpute": "#FFAA00",
    "ST_MVL": "#66c2a5",
    "TRMF": "#a65628",
    "True": "black",
    "Masked": "red"
}

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# ==== choose methods & order (match your screenshot order) ====
methods = [
    "TKCM",
    "TKCM_Weighted",
    "TKCM_PLUS",
    "TKCM_PRO",
    "CDRec",
    "DynaMMo",
    "SoftImpute",
    "SVDImpute",
    "ST_MVL",
    "TRMF",
]

# map names to your arrays
series_map = {
    "TKCM": tkcm_imputed,
    "TKCM_Weighted": tkcm_weighted_imputed,
    "TKCM_PLUS": tkcm_plus_imputed,
    "TKCM_PRO": tkcm_pro_imputed,
    "CDRec": cdrec_imputed,
    "DynaMMo": dynammo_imputed,
    "SoftImpute": soft_imputed,
    "SVDImpute": svd_imputed,
    "ST_MVL": st_mvl_imputed,
    "TRMF": trmf_imputed,
}

# ==== slice to the end block ====
i0, i1 = start_idx, end_idx
t_block = np.arange(i0, i1)
true_block = np.asarray(true_target_array)[i0:i1]
block_map = {m: np.asarray(series_map[m])[i0:i1] for m in methods}

# ==== styling ====
palette = [
    "#1f77b4","#ff7f0e","#2ca02c","#d62728","#9467bd",
    "#8c564b","#e377c2","#7f7f7f","#bcbd22","#17becf"
]

# ==== grid figure (3 x 4) like the sample ====
rows, cols = 3, 4
fig, axes = plt.subplots(rows, cols, figsize=(18, 10), sharex=True, sharey=True)
axes = axes.flatten()

for i, method in enumerate(methods):
    ax = axes[i]
    ax.plot(t_block, true_block, color="#111111", linewidth=2.2, label="True")
    ax.plot(t_block, block_map[method],
            linestyle="--", linewidth=1.6, color=palette[i % len(palette)],
            label=method)
    ax.set_title(f"{method} vs True", fontsize=12.5)
    ax.grid(True, linestyle="--", alpha=0.35)
    ax.legend(loc="upper right", fontsize=9, frameon=True, framealpha=0.9)

# remove unused panels
for j in range(len(methods), rows*cols):
    fig.delaxes(axes[j])

# global labels + tidy look
for spine in ("top","right"):
    [ax.spines[spine].set_visible(False) for ax in fig.axes if hasattr(ax, "spines")]

fig.suptitle("True vs Predicted (Overlay) for Each Imputation Method [End Block]", fontsize=16, y=0.98)
fig.text(0.5, 0.04, "Time Index", ha="center", fontsize=12)
fig.text(0.06, 0.5, "Sensor Value", va="center", rotation="vertical", fontsize=12)

fig.tight_layout(rect=[0.06, 0.06, 1, 0.95])
os.makedirs("plots", exist_ok=True)
fig.savefig("plots/valley_end_block_overlays_1month.pdf")
fig.savefig("plots/valley_end_block_overlays_1month.png", dpi=300)
plt.show(); plt.close(fig)

# %% [markdown]
# 🔄 Enhanced Logic Summary:
# - When imputing a missing value in the target series, combine:
# - The reference time series (as in original TKCM)
# - The past values in the same target series, up to but not including the missing value (i.e. before the offset)
#
# -> ✅ What I’ll Do in TKCM_PLUS:
# - Still use the sliding-window approach and dynamic programming to find top-k similar patterns in the reference series.
# - Then enhance each distance computation by also comparing the candidate window with the past known values of the target.
# - The distance formula becomes a hybrid dissimilarity:
# - distance = alpha * distance_with_ref + beta * distance_with_target_past
# - I can set alpha and beta (e.g., both 0.5) to weight how much to rely on external reference vs internal target pattern.
#
# 📌 Notes:
#    ------
# - The new class TKCM_PLUS allows us to control the balance with alpha (ref series) and beta (target’s past).
# - tkcm still assume only one NaN in the target per call.
# - It preserves the original logic and adds extra pattern context for robustness.

# %% [markdown]
# ✅ TKCM_PRO – Use Summed Reference Series
# 🔧 What changes in TKCM_PRO?
# -> we still slide over the reference matrix to find the top-k similar windows.
# - But when imputing, instead of:
# - using each individual reference series separately (as in original TKCM),
# we:
# - sum up the values across all reference series (i.e., row-wise sum at each mod(pos, L))
# - then average those summed values for top-k matches.

# %%
# 📈 Line Chart (MAE & RMSE)
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=results_df["Method"], y=results_df["MAE"], mode='lines+markers', name='MAE'))
fig.add_trace(go.Scatter(x=results_df["Method"], y=results_df["RMSE"], mode='lines+markers', name='RMSE'))

fig.update_layout(title="Line Plot: MAE & RMSE by Method", xaxis_title="Method", yaxis_title="Error")
fig.show()

# %%
# 🌊 Area Chart (Stacked MAE & RMSE)

fig = go.Figure()
fig.add_trace(go.Scatter(x=results_df["Method"], y=results_df["MAE"], fill='tozeroy', name='MAE'))
fig.add_trace(go.Scatter(x=results_df["Method"], y=results_df["RMSE"], fill='tonexty', name='RMSE'))

fig.update_layout(title="Area Chart: MAE and RMSE", xaxis_title="Method", yaxis_title="Error")
fig.show()

# %%
# 🧱 Waterfall Chart (MAE)

fig = go.Figure(go.Waterfall(
    x=results_df["Method"],
    y=results_df["MAE"],
    measure=["relative"] * len(results_df),
    text=results_df["MAE"].round(2),
    name="MAE"
))

fig.update_layout(title="Waterfall Chart: MAE Differences Across Methods", xaxis_title="Method", yaxis_title="MAE")
fig.show()

# %%
#🌲 Treemap (MAE & RMSE Combined Size)

import numpy as np

fig = go.Figure(go.Treemap(
    labels=results_df["Method"],
    parents=[""] * len(results_df),
    values=np.sqrt(results_df["MAE"]**2 + results_df["RMSE"]**2),  # Combined magnitude
    text=[f"MAE: {mae}<br>RMSE: {rmse}" for mae, rmse in zip(results_df["MAE"], results_df["RMSE"])],
    hoverinfo="label+text+value"
))
fig.update_layout(title="Treemap: Method Error Magnitude (MAE & RMSE)")
fig.show()

# %%
import plotly.graph_objects as go
import numpy as np
import plotly.io as pio

# ✅ Ensure kaleido is installed for static export
# pip install -U kaleido

fig = go.Figure(go.Treemap(
    labels=results_df["Method"],
    parents=[""] * len(results_df),
    values=np.sqrt(results_df["MAE"]**2 + results_df["RMSE"]**2),  # Combined magnitude
    text=[f"MAE: {mae}<br>RMSE: {rmse}" for mae, rmse in zip(results_df["MAE"], results_df["RMSE"])],
    hoverinfo="label+text+value"
))
fig.update_layout(title="Treemap: Method Error Magnitude (MAE & RMSE)")

# 📁 Create output folder
import os
os.makedirs("plots", exist_ok=True)

# 1️⃣ Save static high-res PNG & PDF
fig.write_image("plots/treemap_error_magnitude_1month.png", scale=3)   # PNG
fig.write_image("plots/treemap_error_magnitude_1month.pdf")            # PDF (vector)

# 2️⃣ Save interactive HTML
fig.write_html("plots/treemap_error_magnitude.html")

print("✅ Treemap saved as PNG, PDF, and HTML in 'plots/' folder.")
# Out:
# ✅ Treemap saved as PNG, PDF, and HTML in 'plots/' folder.

# %%
#🔻 Funnel Pyramid (Descending MAE)

import plotly.graph_objects as go

# Sort by MAE descending
sorted_df = results_df.sort_values(by="MAE", ascending=False)

# Make sure MAE is numeric
sorted_df["MAE"] = pd.to_numeric(sorted_df["MAE"], errors="coerce")

# Create Funnelarea chart
fig = go.Figure(go.Funnelarea(
    labels=sorted_df["Method"],
    values=sorted_df["MAE"],
    textinfo="label+value+percent"  # ✅ valid format
))

fig.update_layout(title="Funnel Pyramid: MAE Distribution")
fig.show()
